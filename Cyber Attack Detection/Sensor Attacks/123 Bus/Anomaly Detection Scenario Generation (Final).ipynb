# %%
import os
import math
import csv
import pickle
import statistics
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from random import sample,choices,choice,uniform, randint,shuffle
from DSSCircuit_Interface import *

# %%
#Read the .gml graph and load it into notebook, get the node list
FolderName=os.path.dirname(os.path.realpath("__file__"))
G_original = nx.read_gml(""+ FolderName+ r"\123busEx.gml")
#nodes=list(G_original.nodes())
#edges=list(G_original.edges())
source_node = 'sourcebus'

# %%
DSSfile=r""+ FolderName+ "\IEEE123Master.dss"

# %%
list(G_original.edges(data=True))
# Out:
# [('150',
#   '150r',
#   {'label': 'reg1a',
#    'device': 'Transformer',
#    'resistance': 1.7305600000000006e-05,
#    'reactance': 0.0034611200000000007,
#    'phases': 3,
#    'maxcap': 1040.8959180101426,
#    'cap': 533.9026310621159,
#    'residue': 506.9932869480267}),
#  ('150r',
#   '149',
#   {'label': 'sw1',
#    'device': 'Line',
#    'resistance': 1e-06,
#    'reactance': 0.0,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 514.604945143053,
#    'residue': 85.39505485694701}),
#  ('149',
#   '1',
#   {'label': 'l115',
#    'device': 'Line',
#    'resistance': 0.023186868666666666,
#    'reactance': 0.047502525333333344,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 514.6049454232303,
#    'residue': 85.39505457676967}),
#  ('1',
#   '2',
#   {'label': 'l1',
#    'device': 'Line',
#    'resistance': 0.014684974733333333,
#    'reactance': 0.014887152758333333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 8.995957406868438,
#    'residue': 591.0040425931315}),
#  ('1',
#   '3',
#   {'label': 'l2',
#    'device': 'Line',
#    'resistance': 0.020978535333333336,
#    'reactance': 0.021267361083333335,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 46.56954809141109,
#    'residue': 553.4304519085889}),
#  ('1',
#   '7',
#   {'label': 'l3',
#    'device': 'Line',
#    'resistance': 0.0173901515,
#    'reactance': 0.035626894000000006,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 490.2753761948522,
#    'residue': 109.72462380514781}),
#  ('3',
#   '4',
#   {'label': 'l4',
#    'device': 'Line',
#    'resistance': 0.01678282826666667,
#    'reactance': 0.01701388886666667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.140201486047797,
#    'residue': 581.8597985139522}),
#  ('3',
#   '5',
#   {'label': 'l5',
#    'device': 'Line',
#    'resistance': 0.027272095933333337,
#    'reactance': 0.027647569408333336,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 28.429584002754194,
#    'residue': 571.5704159972458}),
#  ('7',
#   '8',
#   {'label': 'l7',
#    'device': 'Line',
#    'resistance': 0.011593434333333333,
#    'reactance': 0.023751262666666672,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 487.238725309686,
#    'residue': 112.761274690314}),
#  ('5',
#   '6',
#   {'label': 'l6',
#    'device': 'Line',
#    'resistance': 0.020978535333333336,
#    'reactance': 0.021267361083333335,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 19.112996813314318,
#    'residue': 580.8870031866857}),
#  ('8',
#   '12',
#   {'label': 'l8',
#    'device': 'Line',
#    'resistance': 0.018880681800000004,
#    'reactance': 0.019140624975000003,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.021384923056836,
#    'residue': 590.9786150769431}),
#  ('8',
#   '9',
#   {'label': 'l9',
#    'device': 'Line',
#    'resistance': 0.018880681800000004,
#    'reactance': 0.019140624975000003,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 46.5415342545475,
#    'residue': 553.4584657454525}),
#  ('8',
#   '13',
#   {'label': 'l10',
#    'device': 'Line',
#    'resistance': 0.0173901515,
#    'reactance': 0.035626894000000006,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 468.8658883378817,
#    'residue': 131.1341116621183}),
#  ('9',
#   '9r',
#   {'label': 'reg2a',
#    'device': 'Transformer',
#    'resistance': 1.4424010000000004e-05,
#    'reactance': 0.028848020000000005,
#    'phases': 1,
#    'maxcap': 1248.9592006661114,
#    'cap': 28.071044661840894,
#    'residue': 1220.8881560042705}),
#  ('13',
#   '34',
#   {'label': 'l12',
#    'device': 'Line',
#    'resistance': 0.0125871212,
#    'reactance': 0.01276041665,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 46.49755514782739,
#    'residue': 553.5024448521726}),
#  ('13',
#   '18',
#   {'label': 'l13',
#    'device': 'Line',
#    'resistance': 0.04782291717500001,
#    'reactance': 0.0979739585,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 179.4876843450404,
#    'residue': 420.5123156549596}),
#  ('13',
#   '152',
#   {'label': 'sw2',
#    'device': 'Line',
#    'resistance': 1e-06,
#    'reactance': 0.0,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 282.037825863474,
#    'residue': 317.962174136526}),
#  ('9r',
#   '14',
#   {'label': 'l11',
#    'device': 'Line',
#    'resistance': 0.03566351006666667,
#    'reactance': 0.036154513841666666,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 28.07104466050578,
#    'residue': 571.9289553394942}),
#  ('14',
#   '11',
#   {'label': 'l14',
#    'device': 'Line',
#    'resistance': 0.020978535333333336,
#    'reactance': 0.021267361083333335,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.75467552959999,
#    'residue': 581.2453244704}),
#  ('14',
#   '10',
#   {'label': 'l15',
#    'device': 'Line',
#    'resistance': 0.020978535333333336,
#    'reactance': 0.021267361083333335,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.316763077276068,
#    'residue': 590.683236922724}),
#  ('34',
#   '15',
#   {'label': 'l34',
#    'device': 'Line',
#    'resistance': 0.008391414133333336,
#    'reactance': 0.008506944433333335,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 27.6185717915324,
#    'residue': 572.3814282084676}),
#  ('18',
#   '19',
#   {'label': 'l18',
#    'device': 'Line',
#    'resistance': 0.020978535333333336,
#    'reactance': 0.021267361083333335,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 37.41912655790724,
#    'residue': 562.5808734420928}),
#  ('18',
#   '21',
#   {'label': 'l19',
#    'device': 'Line',
#    'resistance': 0.017390151700000002,
#    'reactance': 0.03562689399999999,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 43.60769707000788,
#    'residue': 556.3923029299921}),
#  ('18',
#   '135',
#   {'label': 'sw3',
#    'device': 'Line',
#    'resistance': 1e-06,
#    'reactance': 0.0,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 123.54056720097657,
#    'residue': 476.45943279902343}),
#  ('15',
#   '16',
#   {'label': 'l16',
#    'device': 'Line',
#    'resistance': 0.031467803,
#    'reactance': 0.031901041625,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.415703765534047,
#    'residue': 581.5842962344659}),
#  ('15',
#   '17',
#   {'label': 'l17',
#    'device': 'Line',
#    'resistance': 0.029369949466666666,
#    'reactance': 0.029774305516666665,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.20296126860625,
#    'residue': 590.7970387313937}),
#  ('19',
#   '20',
#   {'label': 'l20',
#    'device': 'Line',
#    'resistance': 0.027272095933333337,
#    'reactance': 0.027647569408333336,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.633848778154658,
#    'residue': 581.3661512218454}),
#  ('21',
#   '22',
#   {'label': 'l21',
#    'device': 'Line',
#    'resistance': 0.044054924200000005,
#    'reactance': 0.044661458275,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 19.10666076474785,
#    'residue': 580.8933392352521}),
#  ('21',
#   '23',
#   {'label': 'l22',
#    'device': 'Line',
#    'resistance': 0.014491793083333336,
#    'reactance': 0.02968907833333333,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 37.24138257001695,
#    'residue': 562.758617429983}),
#  ('23',
#   '24',
#   {'label': 'l23',
#    'device': 'Line',
#    'resistance': 0.046152777733333344,
#    'reactance': 0.04678819438333334,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.57688036696768,
#    'residue': 581.4231196330323}),
#  ('23',
#   '25',
#   {'label': 'l24',
#    'device': 'Line',
#    'resistance': 0.01594097239166667,
#    'reactance': 0.03265798616666667,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 31.04910393865984,
#    'residue': 568.9508960613401}),
#  ('25',
#   '28',
#   {'label': 'l26',
#    'device': 'Line',
#    'resistance': 0.011593434466666663,
#    'reactance': 0.023751262666666672,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 18.564155091798867,
#    'residue': 581.4358449082011}),
#  ('25',
#   '25r',
#   {'label': 'reg3c',
#    'device': 'Transformer',
#    'resistance': 1.4424010000000004e-05,
#    'reactance': 0.028848020000000005,
#    'phases': 1,
#    'maxcap': 1248.9592006661114,
#    'cap': 18.5885992126573,
#    'residue': 1230.3706014534541}),
#  ('25r',
#   '26',
#   {'label': 'l25',
#    'device': 'Line',
#    'resistance': 0.016916666666666667,
#    'reactance': 0.03884911625,
#    'phases': 2,
#    'maxcap': 600.0,
#    'cap': 18.610989193513312,
#    'residue': 581.3890108064867}),
#  ('26',
#   '27',
#   {'label': 'l27',
#    'device': 'Line',
#    'resistance': 0.013291666666666665,
#    'reactance': 0.030524305625,
#    'phases': 2,
#    'maxcap': 600.0,
#    'cap': 9.31719076649495,
#    'residue': 590.682809233505}),
#  ('26',
#   '31',
#   {'label': 'l28',
#    'device': 'Line',
#    'resistance': 0.018880681800000004,
#    'reactance': 0.019140624975000003,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.589558317280485,
#    'residue': 581.4104416827195}),
#  ('28',
#   '29',
#   {'label': 'l30',
#    'device': 'Line',
#    'resistance': 0.017390151700000002,
#    'reactance': 0.03562689399999999,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 12.352738735064193,
#    'residue': 587.6472612649358}),
#  ('27',
#   '33',
#   {'label': 'l29',
#    'device': 'Line',
#    'resistance': 0.04195707066666667,
#    'reactance': 0.04253472216666667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.63387268845656,
#    'residue': 581.3661273115434}),
#  ('31',
#   '32',
#   {'label': 'l33',
#    'device': 'Line',
#    'resistance': 0.0251742424,
#    'reactance': 0.0255208333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.29652789706497,
#    'residue': 590.703472102935}),
#  ('29',
#   '30',
#   {'label': 'l31',
#    'device': 'Line',
#    'resistance': 0.02028851031666666,
#    'reactance': 0.04156470966666667,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 6.1974881442372185,
#    'residue': 593.8025118557628}),
#  ('30',
#   '250',
#   {'label': 'l32',
#    'device': 'Line',
#    'resistance': 0.011593434466666663,
#    'reactance': 0.023751262666666672,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 0.0006361723419440567,
#    'residue': 599.999363827658}),
#  ('35',
#   '36',
#   {'label': 'l35',
#    'device': 'Line',
#    'resistance': 0.03141666666666667,
#    'reactance': 0.07214835874999999,
#    'phases': 2,
#    'maxcap': 600.0,
#    'cap': 18.425026361742873,
#    'residue': 581.5749736382571}),
#  ('35',
#   '40',
#   {'label': 'l36',
#    'device': 'Line',
#    'resistance': 0.014491792916666666,
#    'reactance': 0.029689078333333344,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 105.08994895480662,
#    'residue': 494.91005104519337}),
#  ('35',
#   '135',
#   {'label': 'l114',
#    'device': 'Line',
#    'resistance': 0.021737689375,
#    'reactance': 0.0445336175,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 123.54056709242154,
#    'residue': 476.45943290757845}),
#  ('36',
#   '37',
#   {'label': 'l37',
#    'device': 'Line',
#    'resistance': 0.0251742424,
#    'reactance': 0.0255208333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.424789538055208,
#    'residue': 581.5752104619448}),
#  ('36',
#   '38',
#   {'label': 'l38',
#    'device': 'Line',
#    'resistance': 0.020978535333333336,
#    'reactance': 0.021267361083333335,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.426777446365744,
#    'residue': 581.5732225536343}),
#  ('40',
#   '41',
#   {'label': 'l40',
#    'device': 'Line',
#    'resistance': 0.027272095933333337,
#    'reactance': 0.027647569408333336,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.277291327661986,
#    'residue': 590.7227086723381}),
#  ('40',
#   '42',
#   {'label': 'l41',
#    'device': 'Line',
#    'resistance': 0.014491792916666666,
#    'reactance': 0.029689078333333344,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 102.01399013512041,
#    'residue': 497.9860098648796}),
#  ('38',
#   '39',
#   {'label': 'l39',
#    'device': 'Line',
#    'resistance': 0.027272095933333337,
#    'reactance': 0.027647569408333336,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.1100794822532,
#    'residue': 590.8899205177468}),
#  ('42',
#   '43',
#   {'label': 'l42',
#    'device': 'Line',
#    'resistance': 0.04195707066666667,
#    'reactance': 0.04253472216666667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 19.01725805415259,
#    'residue': 580.9827419458475}),
#  ('42',
#   '44',
#   {'label': 'l43',
#    'device': 'Line',
#    'resistance': 0.011593434333333333,
#    'reactance': 0.023751262666666672,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 92.61294824728617,
#    'residue': 507.38705175271383}),
#  ('44',
#   '45',
#   {'label': 'l44',
#    'device': 'Line',
#    'resistance': 0.01678282826666667,
#    'reactance': 0.01701388886666667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.772189107836926,
#    'residue': 581.2278108921631}),
#  ('44',
#   '47',
#   {'label': 'l45',
#    'device': 'Line',
#    'resistance': 0.014491792916666666,
#    'reactance': 0.029689078333333344,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 86.40461291140416,
#    'residue': 513.5953870885959}),
#  ('45',
#   '46',
#   {'label': 'l46',
#    'device': 'Line',
#    'resistance': 0.0251742424,
#    'reactance': 0.0255208333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.45530245027251,
#    'residue': 590.5446975497275}),
#  ('47',
#   '48',
#   {'label': 'l47',
#    'device': 'Line',
#    'resistance': 0.00869507575,
#    'reactance': 0.017813447,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 35.867726603406,
#    'residue': 564.132273396594}),
#  ('47',
#   '49',
#   {'label': 'l48',
#    'device': 'Line',
#    'resistance': 0.01449179291666667,
#    'reactance': 0.02968907833333333,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 32.69788297906823,
#    'residue': 567.3021170209317}),
#  ('49',
#   '50',
#   {'label': 'l49',
#    'device': 'Line',
#    'resistance': 0.01449179291666667,
#    'reactance': 0.02968907833333333,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 9.357521983519053,
#    'residue': 590.6424780164809}),
#  ('50',
#   '51',
#   {'label': 'l50',
#    'device': 'Line',
#    'resistance': 0.01449179291666667,
#    'reactance': 0.02968907833333333,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 3.1551767743070296,
#    'residue': 596.844823225693}),
#  ('51',
#   '151',
#   {'label': 'l51',
#    'device': 'Line',
#    'resistance': 0.02898358583333334,
#    'reactance': 0.05937815666666666,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 0.0014670803587603452,
#    'residue': 599.9985329196412}),
#  ('151',
#   '300_open',
#   {'label': 'sw7',
#    'device': 'Line',
#    'resistance': 1e-06,
#    'reactance': 0.0,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 0.0,
#    'residue': 600.0}),
#  ('52',
#   '53',
#   {'label': 'l52',
#    'device': 'Line',
#    'resistance': 0.011593434333333333,
#    'reactance': 0.023751262666666672,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 276.0193780468912,
#    'residue': 323.9806219531088}),
#  ('52',
#   '152',
#   {'label': 'l116',
#    'device': 'Line',
#    'resistance': 0.023186868666666666,
#    'reactance': 0.047502525333333344,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 282.03782578854,
#    'residue': 317.96217421146}),
#  ('53',
#   '54',
#   {'label': 'l53',
#    'device': 'Line',
#    'resistance': 0.007245896458333333,
#    'reactance': 0.014844539166666672,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 270.0166179775377,
#    'residue': 329.9833820224623}),
#  ('54',
#   '55',
#   {'label': 'l54',
#    'device': 'Line',
#    'resistance': 0.01594097220833333,
#    'reactance': 0.03265798616666668,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 6.100661487209536,
#    'residue': 593.8993385127905}),
#  ('54',
#   '57',
#   {'label': 'l55',
#    'device': 'Line',
#    'resistance': 0.02028851008333333,
#    'reactance': 0.04156470966666667,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 264.22744008077876,
#    'residue': 335.77255991922124}),
#  ('54',
#   '94_open',
#   {'label': 'sw8',
#    'device': 'Line',
#    'resistance': 3.333333333333333e-07,
#    'reactance': 0.0,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.0,
#    'residue': 600.0}),
#  ('55',
#   '56',
#   {'label': 'l56',
#    'device': 'Line',
#    'resistance': 0.01594097220833333,
#    'reactance': 0.03265798616666668,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 3.0209293154865633,
#    'residue': 596.9790706845134}),
#  ('57',
#   '58',
#   {'label': 'l57',
#    'device': 'Line',
#    'resistance': 0.020978535333333336,
#    'reactance': 0.021267361083333335,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.40872606407634,
#    'residue': 581.5912739359237}),
#  ('57',
#   '60',
#   {'label': 'l58',
#    'device': 'Line',
#    'resistance': 0.04347537875,
#    'reactance': 0.089067235,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 258.49859864070226,
#    'residue': 341.50140135929774}),
#  ('58',
#   '59',
#   {'label': 'l59',
#    'device': 'Line',
#    'resistance': 0.020978535333333336,
#    'reactance': 0.021267361083333335,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.092019119130839,
#    'residue': 590.9079808808692}),
#  ('60',
#   '61',
#   {'label': 'l60',
#    'device': 'Line',
#    'resistance': 0.03188194441666666,
#    'reactance': 0.06531597233333333,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 0.0017220368631547364,
#    'residue': 599.9982779631368}),
#  ('60',
#   '62',
#   {'label': 'l61',
#    'device': 'Line',
#    'resistance': 0.0480224115,
#    'reactance': 0.022880366166666666,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 59.39093760879084,
#    'residue': 540.6090623912091}),
#  ('60',
#   '160',
#   {'label': 'sw4',
#    'device': 'Line',
#    'resistance': 1e-06,
#    'reactance': 0.0,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 202.73690246392948,
#    'residue': 397.2630975360705}),
#  ('61',
#   '61s',
#   {'label': 'sw6',
#    'device': 'Line',
#    'resistance': 1e-06,
#    'reactance': 0.0,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 1.3935519976208195e-05,
#    'residue': 599.99998606448}),
#  ('62',
#   '63',
#   {'label': 'l62',
#    'device': 'Line',
#    'resistance': 0.033615688049999995,
#    'reactance': 0.01601625631666666,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 53.199903564195125,
#    'residue': 546.8000964358049}),
#  ('63',
#   '64',
#   {'label': 'l63',
#    'device': 'Line',
#    'resistance': 0.06723137609999999,
#    'reactance': 0.03203251263333332,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 47.07676288669173,
#    'residue': 552.9232371133082}),
#  ('64',
#   '65',
#   {'label': 'l64',
#    'device': 'Line',
#    'resistance': 0.08163809954999998,
#    'reactance': 0.03889662248333334,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 35.65386848056048,
#    'residue': 564.3461315194395}),
#  ('65',
#   '66',
#   {'label': 'l65',
#    'device': 'Line',
#    'resistance': 0.06242913495,
#    'reactance': 0.02974447601666667,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 11.61756107286197,
#    'residue': 588.3824389271381}),
#  ('67',
#   '68',
#   {'label': 'l66',
#    'device': 'Line',
#    'resistance': 0.01678282826666667,
#    'reactance': 0.01701388886666667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 53.85377722562133,
#    'residue': 546.1462227743787}),
#  ('67',
#   '72',
#   {'label': 'l67',
#    'device': 'Line',
#    'resistance': 0.01594097220833333,
#    'reactance': 0.03265798616666668,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 125.78953251698344,
#    'residue': 474.21046748301654}),
#  ('67',
#   '97',
#   {'label': 'l68',
#    'device': 'Line',
#    'resistance': 0.01449179291666667,
#    'reactance': 0.029689078333333344,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 66.85698110304038,
#    'residue': 533.1430188969596}),
#  ('67',
#   '160r',
#   {'label': 'l117',
#    'device': 'Line',
#    'resistance': 0.02028851008333333,
#    'reactance': 0.04156470966666667,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 194.25762802622978,
#    'residue': 405.7423719737702}),
#  ('68',
#   '69',
#   {'label': 'l69',
#    'device': 'Line',
#    'resistance': 0.023076388866666672,
#    'reactance': 0.02339409719166667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 44.89809024882365,
#    'residue': 555.1019097511763}),
#  ('72',
#   '73',
#   {'label': 'l72',
#    'device': 'Line',
#    'resistance': 0.023076388866666672,
#    'reactance': 0.02339409719166667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 55.34684265400363,
#    'residue': 544.6531573459964}),
#  ('72',
#   '76',
#   {'label': 'l73',
#    'device': 'Line',
#    'resistance': 0.01159343433333333,
#    'reactance': 0.023751262666666672,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 114.81988858993618,
#    'residue': 485.18011141006383}),
#  ('97',
#   '98',
#   {'label': 'l96',
#    'device': 'Line',
#    'resistance': 0.01594097220833333,
#    'reactance': 0.03265798616666668,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 18.333876295216,
#    'residue': 581.666123704784}),
#  ('97',
#   '197',
#   {'label': 'sw5',
#    'device': 'Line',
#    'resistance': 1e-06,
#    'reactance': 0.0,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 48.523532854114826,
#    'residue': 551.4764671458852}),
#  ('69',
#   '70',
#   {'label': 'l70',
#    'device': 'Line',
#    'resistance': 0.027272095933333337,
#    'reactance': 0.027647569408333336,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 26.956482154864467,
#    'residue': 573.0435178451355}),
#  ('70',
#   '71',
#   {'label': 'l71',
#    'device': 'Line',
#    'resistance': 0.023076388866666672,
#    'reactance': 0.02339409719166667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 17.975144171005116,
#    'residue': 582.0248558289949}),
#  ('73',
#   '74',
#   {'label': 'l74',
#    'device': 'Line',
#    'resistance': 0.029369949466666666,
#    'reactance': 0.029774305516666665,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 37.30150264681026,
#    'residue': 562.6984973531897}),
#  ('76',
#   '77',
#   {'label': 'l76',
#    'device': 'Line',
#    'resistance': 0.02318686866666666,
#    'reactance': 0.047502525333333344,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 77.95282232707326,
#    'residue': 522.0471776729268}),
#  ('76',
#   '86',
#   {'label': 'l77',
#    'device': 'Line',
#    'resistance': 0.04057702016666666,
#    'reactance': 0.08312941933333334,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 36.88646565090567,
#    'residue': 563.1135343490944}),
#  ('74',
#   '75',
#   {'label': 'l75',
#    'device': 'Line',
#    'resistance': 0.03356565653333334,
#    'reactance': 0.03402777773333334,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.09551679789561,
#    'residue': 581.9044832021044}),
#  ('77',
#   '78',
#   {'label': 'l78',
#    'device': 'Line',
#    'resistance': 0.005796717166666665,
#    'reactance': 0.011875631333333336,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 78.86143403182611,
#    'residue': 521.1385659681739}),
#  ('86',
#   '87',
#   {'label': 'l86',
#    'device': 'Line',
#    'resistance': 0.02608522725000001,
#    'reactance': 0.05344034100000001,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 34.11237021169021,
#    'residue': 565.8876297883098}),
#  ('78',
#   '79',
#   {'label': 'l79',
#    'device': 'Line',
#    'resistance': 0.013042613625000005,
#    'reactance': 0.026720170500000005,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 6.4809172360185014,
#    'residue': 593.5190827639815}),
#  ('78',
#   '80',
#   {'label': 'l80',
#    'device': 'Line',
#    'resistance': 0.027534406541666667,
#    'reactance': 0.05640924883333333,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 79.78402519160613,
#    'residue': 520.2159748083939}),
#  ('80',
#   '81',
#   {'label': 'l81',
#    'device': 'Line',
#    'resistance': 0.010144255041666665,
#    'reactance': 0.020782354833333336,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 81.9018523945817,
#    'residue': 518.0981476054183}),
#  ('81',
#   '82',
#   {'label': 'l82',
#    'device': 'Line',
#    'resistance': 0.01449179291666667,
#    'reactance': 0.029689078333333344,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 83.71932298914358,
#    'residue': 516.2806770108564}),
#  ('81',
#   '84',
#   {'label': 'l83',
#    'device': 'Line',
#    'resistance': 0.05664204540000001,
#    'reactance': 0.057421874925000005,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 27.028579201093972,
#    'residue': 572.971420798906}),
#  ('82',
#   '83',
#   {'label': 'l84',
#    'device': 'Line',
#    'resistance': 0.01449179291666667,
#    'reactance': 0.029689078333333344,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 85.8414699431334,
#    'residue': 514.1585300568665}),
#  ('84',
#   '85',
#   {'label': 'l85',
#    'device': 'Line',
#    'resistance': 0.03985921713333333,
#    'reactance': 0.04040798605833333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.02636175435768,
#    'residue': 581.9736382456423}),
#  ('87',
#   '88',
#   {'label': 'l87',
#    'device': 'Line',
#    'resistance': 0.014684974733333333,
#    'reactance': 0.014887152758333333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 21.035580008822514,
#    'residue': 578.9644199911775}),
#  ('87',
#   '89',
#   {'label': 'l88',
#    'device': 'Line',
#    'resistance': 0.01594097220833333,
#    'reactance': 0.03265798616666668,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 24.021191747394155,
#    'residue': 575.9788082526059}),
#  ('89',
#   '90',
#   {'label': 'l89',
#    'device': 'Line',
#    'resistance': 0.020978535333333336,
#    'reactance': 0.021267361083333335,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 21.338023309529728,
#    'residue': 578.6619766904703}),
#  ('89',
#   '91',
#   {'label': 'l90',
#    'device': 'Line',
#    'resistance': 0.013042613625000005,
#    'reactance': 0.026720170500000005,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 18.952563892766857,
#    'residue': 581.0474361072331}),
#  ('91',
#   '92',
#   {'label': 'l91',
#    'device': 'Line',
#    'resistance': 0.0251742424,
#    'reactance': 0.0255208333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 21.01581795490845,
#    'residue': 578.9841820450915}),
#  ('91',
#   '93',
#   {'label': 'l92',
#    'device': 'Line',
#    'resistance': 0.013042613625000005,
#    'reactance': 0.026720170500000005,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 11.947585553543304,
#    'residue': 588.0524144464567}),
#  ('93',
#   '94',
#   {'label': 'l93',
#    'device': 'Line',
#    'resistance': 0.023076388866666672,
#    'reactance': 0.02339409719166667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 17.931507387176147,
#    'residue': 582.0684926128239}),
#  ('93',
#   '95',
#   {'label': 'l94',
#    'device': 'Line',
#    'resistance': 0.017390151500000003,
#    'reactance': 0.03562689399999999,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 5.970782276899507,
#    'residue': 594.0292177231005}),
#  ('95',
#   '96',
#   {'label': 'l95',
#    'device': 'Line',
#    'resistance': 0.01678282826666667,
#    'reactance': 0.01701388886666667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 8.95636124685994,
#    'residue': 591.04363875314}),
#  ('98',
#   '99',
#   {'label': 'l97',
#    'device': 'Line',
#    'resistance': 0.03188194441666666,
#    'reactance': 0.06531597233333336,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 12.367849562963277,
#    'residue': 587.6321504370367}),
#  ('99',
#   '100',
#   {'label': 'l98',
#    'device': 'Line',
#    'resistance': 0.0173901515,
#    'reactance': 0.035626894,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 6.419664956327511,
#    'residue': 593.5803350436724}),
#  ('100',
#   '450',
#   {'label': 'l99',
#    'device': 'Line',
#    'resistance': 0.04637373733333332,
#    'reactance': 0.09500505066666669,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 0.0026295290275807123,
#    'residue': 599.9973704709724}),
#  ('197',
#   '101',
#   {'label': 'l118',
#    'device': 'Line',
#    'resistance': 0.01449179291666667,
#    'reactance': 0.029689078333333344,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 48.52353281886523,
#    'residue': 551.4764671811348}),
#  ('101',
#   '102',
#   {'label': 'l100',
#    'device': 'Line',
#    'resistance': 0.018880681800000004,
#    'reactance': 0.019140624975000003,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 45.21742162574314,
#    'residue': 554.7825783742569}),
#  ('101',
#   '105',
#   {'label': 'l101',
#    'device': 'Line',
#    'resistance': 0.01594097220833333,
#    'reactance': 0.03265798616666668,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 33.45402756597551,
#    'residue': 566.5459724340245}),
#  ('102',
#   '103',
#   {'label': 'l102',
#    'device': 'Line',
#    'resistance': 0.027272095933333337,
#    'reactance': 0.027647569408333336,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 36.191871917558316,
#    'residue': 563.8081280824417}),
#  ('105',
#   '106',
#   {'label': 'l104',
#    'device': 'Line',
#    'resistance': 0.018880681800000004,
#    'reactance': 0.019140624975000003,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 35.74132858994489,
#    'residue': 564.2586714100551}),
#  ('105',
#   '108',
#   {'label': 'l105',
#    'device': 'Line',
#    'resistance': 0.018839330791666664,
#    'reactance': 0.03859580183333332,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 21.542500650120974,
#    'residue': 578.4574993498791}),
#  ('103',
#   '104',
#   {'label': 'l103',
#    'device': 'Line',
#    'resistance': 0.05873989893333333,
#    'reactance': 0.05954861103333333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 18.11151331809928,
#    'residue': 581.8884866819008}),
#  ('106',
#   '107',
#   {'label': 'l106',
#    'device': 'Line',
#    'resistance': 0.04825063126666667,
#    'reactance': 0.04891493049166667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 17.882955777273583,
#    'residue': 582.1170442227265}),
#  ('108',
#   '109',
#   {'label': 'l107',
#    'device': 'Line',
#    'resistance': 0.03776136360000001,
#    'reactance': 0.038281249950000006,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 64.61998547024811,
#    'residue': 535.3800145297519}),
#  ('108',
#   '300',
#   {'label': 'l108',
#    'device': 'Line',
#    'resistance': 0.05796717166666668,
#    'reactance': 0.11875631333333338,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 0.003284986708166213,
#    'residue': 599.9967150132918}),
#  ('109',
#   '110',
#   {'label': 'l109',
#    'device': 'Line',
#    'resistance': 0.0251742424,
#    'reactance': 0.0255208333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 46.58371601038623,
#    'residue': 553.4162839896138}),
#  ('110',
#   '111',
#   {'label': 'l110',
#    'device': 'Line',
#    'resistance': 0.04825063126666667,
#    'reactance': 0.04891493049166667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.041539862734172,
#    'residue': 590.9584601372658}),
#  ('110',
#   '112',
#   {'label': 'l111',
#    'device': 'Line',
#    'resistance': 0.010489267666666668,
#    'reactance': 0.010633680541666668,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 37.54246244641792,
#    'residue': 562.457537553582}),
#  ('112',
#   '113',
#   {'label': 'l112',
#    'device': 'Line',
#    'resistance': 0.044054924200000005,
#    'reactance': 0.044661458275,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 28.22558245282035,
#    'residue': 571.7744175471796}),
#  ('113',
#   '114',
#   {'label': 'l113',
#    'device': 'Line',
#    'resistance': 0.027272095933333337,
#    'reactance': 0.027647569408333336,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.063241307547514,
#    'residue': 590.9367586924525}),
#  ('160r',
#   '160',
#   {'label': 'reg4c',
#    'device': 'Transformer',
#    'resistance': 1.4424010000000004e-05,
#    'reactance': 0.028848020000000005,
#    'phases': 1,
#    'maxcap': 1248.9592006661114,
#    'cap': 192.14074378321314,
#    'residue': 1056.8184568828983}),
#  ('61s',
#   '610',
#   {'label': 'xfm1',
#    'device': 'Transformer',
#    'resistance': 0.97536,
#    'reactance': 4.17792,
#    'phases': 3,
#    'maxcap': 31.226877540304276,
#    'cap': 1.388048084063821e-05,
#    'residue': 31.226863659823437})]

# %%
d_obj= DSS(DSSfile) #create a circuit object
d_obj.compile_ckt_dss() #compiling the circuit
d_obj.dssText.command = "Set Maxiterations=200" 
d_obj.dssText.command = "Set maxcontroliter=200"
d_obj.AllowForms=False 
d_obj.dssText.command = "Set controlmode=OFF"

# %%
#Loading Original Loadshape File
LoadShape = []
with open('Loadshape_multload.csv') as csvfile:
    data = list(csv.reader(csvfile))

for x in range(len(data)):
    value = float(data[x][1])
    LoadShape.append(value)

# %%
#Creating Array of Loadshapes
Loadshapes = []
Loadshapes.append(LoadShape)
std = statistics.stdev(LoadShape)
mean = statistics.mean(LoadShape)
length = len(LoadShape)
Nsc_N = 200 
for i in range(Nsc_N):
    noise = np.random.normal(mean,std,length)
    Loadshapes.append(list(noise))

# %%
#Generating Normal Voltage signals
buses=list(G_original.nodes())
edge_dict=list(G_original.edges(data=True)) 
Prelim_Dataset = []
d_obj.dssText.command='redirect LoadShape.dss'
d_obj.dssCircuit.Loadshapes.First
for i in range(len(Loadshapes)):
    d_obj.dssText.command = 'New LoadShape.Lshape'+str(i) + ' npts=24 interval=1 mult='+str(Loadshapes[i])
    d_obj.dssCircuit.Loadshapes.Name = 'Lshape'+str(i)
    d_obj.dssText.command ='Batchedit Load..* Daily=Lshape'+str(i)
    d_obj.dssText.command = "Set mode=Daily"
    d_obj.dssText.command = "Set stepsize=1h"
    d_obj.dssText.command = "Set number=1"
    d_obj.dssCircuit.Loadshapes.Next
    Normal_Data = []
    TimeSeries_Data = []
    dsstime = 0
    for b in buses:
        d_obj.dssCircuit.SetActiveBus(b) #Setting Active Bus
        while dsstime<24: 
            d_obj.dssText.Command= 'Solve'
            dsstime = d_obj.dssSolution.dblHour
            V=np.array(d_obj.dssBus.puVmagAngle)
            ctidx = 2 * np.array(range(0, min(int(V.size/ 2), 3)))
            TimeSeries_Data.append({'Time Step':dsstime, 'Voltage Magnitude':V[ctidx]})
        Normal_Data.append({'Bus Name':b,'Time Series Data':TimeSeries_Data})
    Scenario_Info={'Scaling Factor':'Nil', 'Anomaly_Duration':'Nil', 'targeted_bus': 'Nil', 'Scenario_Info': Normal_Data}
    Prelim_Dataset.append(Scenario_Info)

# %%
len(Prelim_Dataset)
# Out:
# 201

# %%
#Injecting Anomalies
Nsc_A = 299 #Number of Anomalous Scenarios
Ttot = 24 
for a in range (Nsc_A):
    Anomaly_Data = []
    selected_bus = choice(buses) #random sampling of buses with replacement
    lamda = uniform(-1.0,0.5) #Anomaly Scaling Factor
    time_range = randint(0,5) #Duration of Anomaly in hours
    anom_start = randint(0,19) #Anomaly Start Time
    for j in range(len(buses)):
        NewTimeSeries_Data = []
        for m in range(Ttot):
            if Prelim_Dataset[0]['Scenario_Info'][j]['Bus Name'] == selected_bus and Prelim_Dataset[0]['Scenario_Info'][j]['Time Series Data'][m]['Time Step'] > anom_start and Prelim_Dataset[0]['Scenario_Info'][j]['Time Series Data'][m]['Time Step'] <= anom_start+time_range:
                New_VM = (1+lamda)*Prelim_Dataset[0]['Scenario_Info'][j]['Time Series Data'][m]['Voltage Magnitude']
            else:
                New_VM = Prelim_Dataset[0]['Scenario_Info'][j]['Time Series Data'][m]['Voltage Magnitude']      
            NewTimeSeries_Data.append({'Time Step':Prelim_Dataset[0]['Scenario_Info'][j]['Time Series Data'][m]['Time Step'], 'Voltage Magnitude':New_VM})
        Anomaly_Data.append({'Bus Name':Prelim_Dataset[0]['Scenario_Info'][j]['Bus Name'],'Time Series Data': NewTimeSeries_Data})          
    Scenario_Info = {'Scaling Factor':lamda, 'Anomaly_Duration':time_range, 'targeted_bus': selected_bus, 'Scenario_Info': Anomaly_Data}
    Prelim_Dataset.append(Scenario_Info)

# %%
#Restructuring Dataset into multi-dimensional array
Dataset = []
dim_x = len(NewTimeSeries_Data)
dim_y = len(buses)

for d in range (len(Prelim_Dataset)):
    array_3d = np.zeros((dim_x,dim_y,3))
    array_2d = np.zeros((dim_y,3))
    for t in range(len(NewTimeSeries_Data)):
        for s in range(len(buses)): 
            array_2d[s,:] = Prelim_Dataset[d]['Scenario_Info'][s]['Time Series Data'][t]['Voltage Magnitude']
        array_3d[t,:,:]=array_2d
        if d>Nsc_N+1 and np.any(array_3d<0.95) or np.any(array_3d>1.05):
            Anomaly_Check = 'Yes' 
        else:
            Anomaly_Check = 'No'              
    Scenario_Data = {'Anomaly Check':Anomaly_Check,'targeted_bus':Prelim_Dataset[d]['targeted_bus'],'TimeSeries_Voltage':array_3d}
    Dataset.append(Scenario_Data)

# %%
Dataset[0]
# Out:
# {'Anomaly Check': 'No',
#  'targeted_bus': 'Nil',
#  'TimeSeries_Voltage': array([[[0.99999144, 0.99999391, 0.99999384],
#          [0.99999144, 0.99999391, 0.99999384],
#          [0.99999144, 0.99999391, 0.99999384],
#          ...,
#          [0.99999144, 0.99999391, 0.99999384],
#          [0.99999144, 0.99999391, 0.99999384],
#          [0.99999144, 0.99999391, 0.99999384]],
#
#         [[0.99999215, 0.9999944 , 0.99999436],
#          [0.99999215, 0.9999944 , 0.99999436],
#          [0.99999215, 0.9999944 , 0.99999436],
#          ...,
#          [0.99999215, 0.9999944 , 0.99999436],
#          [0.99999215, 0.9999944 , 0.99999436],
#          [0.99999215, 0.9999944 , 0.99999436]],
#
#         [[0.99999239, 0.99999457, 0.99999453],
#          [0.99999239, 0.99999457, 0.99999453],
#          [0.99999239, 0.99999457, 0.99999453],
#          ...,
#          [0.99999239, 0.99999457, 0.99999453],
#          [0.99999239, 0.99999457, 0.99999453],
#          [0.99999239, 0.99999457, 0.99999453]],
#
#         ...,
#
#         [[0.99998859, 0.99999195, 0.99999172],
#          [0.99998859, 0.99999195, 0.99999172],
#          [0.99998859, 0.99999195, 0.99999172],
#          ...,
#          [0.99998859, 0.99999195, 0.99999172],
#          [0.99998859, 0.99999195, 0.99999172],
#          [0.99998859, 0.99999195, 0.99999172]],
#
#         [[0.99998929, 0.99999243, 0.99999225],
#          [0.99998929, 0.99999243, 0.99999225],
#          [0.99998929, 0.99999243, 0.99999225],
#          ...,
#          [0.99998929, 0.99999243, 0.99999225],
#          [0.99998929, 0.99999243, 0.99999225],
#          [0.99998929, 0.99999243, 0.99999225]],
#
#         [[0.99999033, 0.99999314, 0.99999302],
#          [0.99999033, 0.99999314, 0.99999302],
#          [0.99999033, 0.99999314, 0.99999302],
#          ...,
#          [0.99999033, 0.99999314, 0.99999302],
#          [0.99999033, 0.99999314, 0.99999302],
#          [0.99999033, 0.99999314, 0.99999302]]])}

# %%
Prelim_Dataset[300]
# Out:
# {'Scaling Factor': -0.8491016986936497,
#  'Anomaly_Duration': 1,
#  'targeted_bus': '707',
#  'Scenario_Info': [{'Bus Name': 'sourcebus',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '799',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '709',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '775',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '701',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '702',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '705',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '713',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '703',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '727',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '730',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '704',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '714',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '720',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '742',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '712',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '706',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '725',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '707',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.15089644, 0.15089699, 0.15089695])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '724',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '722',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
# ...
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '734',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '737',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '738',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '728',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '729',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '799r',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]}]}

# %%
#Shuffling Dataset and Shuffle Check
shuffle(Dataset)
for i in range(len(Dataset)):
    print(Dataset[i]['Anomaly Check'])
# Out:
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# Yes
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# No
# No
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# Yes
# No
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# Yes
# No
# Yes
# No
# No
# Yes
# No
# No
# No
# No
# No
# No
# Yes
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# No
# No
# No
# Yes
# No
# No
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# Yes
# No
# No
# No
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# No
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# No
# No
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# No
# No
# Yes
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# Yes
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# No
# No
# Yes
# Yes
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# Yes
# No
# No
# No
# Yes
# Yes
# Yes
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# Yes
# No
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# Yes
# Yes
# Yes
# No
# No
# No
# No
# Yes
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# No
# Yes
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# Yes
# Yes
# Yes
# No
# No
# No
# No
# No
# Yes
# Yes
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# No
# Yes
# No
# Yes
# No
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# No

# %%
#Loading .pkl file
a = open('fullanomalydataset.pkl', 'wb')
pickle.dump(Dataset,a)
a.close()
