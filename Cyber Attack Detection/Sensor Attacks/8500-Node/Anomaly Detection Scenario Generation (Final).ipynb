# %%
import os
import math
import csv
import pickle
import statistics
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from random import sample,choices,choice,uniform, randint,shuffle
from DSSCircuit_Interface import *

# %%
#Read the .gml graph and load it into notebook, get the node list
FolderName=os.path.dirname(os.path.realpath("__file__"))
G_original = nx.read_gml(""+ FolderName+ r"\8500busEx.gml")
#nodes=list(G_original.nodes())
#edges=list(G_original.edges())
# source_node = 'sourcebus'

# %%
DSSfile=r""+ FolderName+ "\Master.dss"

# %%
list(G_original.edges(data=True))
# Out:
# [('_hvmv_sub_lsb',
#   'hvmv_sub_48332',
#   {'label': 'hvmv_sub_connector',
#    'device': 'Line',
#    'resistance': 1e-06,
#    'reactance': 9.999999999999999e-06,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 528.5517435318036,
#    'residue': 71.4482564681964}),
#  ('_hvmv_sub_lsb',
#   'regxfmr_hvmv_sub_lsb',
#   {'label': 'feeder_regc',
#    'device': 'Transformer',
#    'resistance': 0.0009425454545454546,
#    'reactance': 0.18850909090909093,
#    'phases': 1,
#    'maxcap': 5729.166666666667,
#    'cap': 501.91729481344134,
#    'residue': 5227.249371853226}),
#  ('hvmv_sub_48332',
#   'd5710794-3_int',
#   {'label': 'ln5710794-3',
#    'device': 'Line',
#    'resistance': 0.0030582314252429995,
#    'reactance': 0.0071560770870680015,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 528.5517435846572,
#    'residue': 71.44825641534283}),
#  ('m1009763',
#   'l2673322',
#   {'label': 'ln5502549-1',
#    'device': 'Line',
#    'resistance': 0.01796107068886,
#    'reactance': 0.010023346961759999,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.8847523828396167,
#    'residue': 598.1152476171604}),
#  ('m1009763',
#   'l2689691',
#   {'label': 'ln5712507-1',
#    'device': 'Line',
#    'resistance': 0.128250844722689,
#    'reactance': 0.04132284233549334,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 0.9004001339058688,
#    'residue': 599.0995998660941}),
#  ('m1009763',
#   'e182733',
#   {'label': 'ln6019480-1',
#    'device': 'Line',
#    'resistance': 0.12748710588833398,
#    'reactance': 0.04107676318095999,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 0.0022487021148526894,
#    'residue': 599.9977512978852}),
#  ('m1009763',
#   'l2766730',
#   {'label': 'ln6138616-1',
#    'device': 'Line',
#    'resistance': 0.013896611697540001,
#    'reactance': 0.00775513682064,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.8090423719266556,
#    'residue': 599.1909576280733}),
#  ('l2673322',
#   'l2859391',
#   {'label': 'ln5818176-1',
#    'device': 'Line',
#    'resistance': 0.018472436994000002,
#    'reactance': 0.014753671911366666,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.3454342817400609,
#    'residue': 598.65456571826}),
#  ('l2673322',
#   'x2673322b',
#   {'label': 't5355358b',
#    'device': 'Transformer',
#    'resistance': 1.728,
#    'reactance': 2.9375999999999998,
#    'phases': 1,
#    'maxcap': 2.0833333333333335,
#    'cap': 5.707274354330486,
#    'residue': -3.6239410209971523}),
#  ('m1069148',
#   'l2673309',
#   {'label': 'ln6259988-1',
#    'device': 'Line',
#    'resistance': 0.05986020813759999,
#    'reactance': 0.0334055606016,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4473346082962506,
#    'residue': 598.5526653917037}),
#  ('m1069148',
#   'l2785518',
#   {'label': 'ln5865231-1',
#    'device': 'Line',
#    'resistance': 0.01536354519648,
#    'reactance': 0.00857377306368,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4437216980554035,
#    'residue': 598.5562783019446}),
#  ('m1069148',
#   'm1069149',
#   {'label': 'ln5532742-1',
#    'device': 'Line',
#    'resistance': 0.03455834125666,
#    'reactance': 0.01928561224656,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.890776296139992,
#    'residue': 597.10922370386}),
#  ('l2673309',
#   'x2673309c',
#   {'label': 't5138472c',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 15.331454754618903,
#    'residue': -10.123121421285571}),
#  ('m1069588',
#   'l2804270',
#   {'label': 'ln6077796-1',
#    'device': 'Line',
#    'resistance': 0.00638957647302,
#    'reactance': 0.00356576414832,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.6779732408170243,
#    'residue': 598.322026759183}),
#  ('m1069588',
#   'm1069590',
#   {'label': 'ln5803283-1',
#    'device': 'Line',
#    'resistance': 0.0616491692648,
#    'reactance': 0.034403907436799996,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 25.853893502763313,
#    'residue': 574.1461064972367}),
#  ('m1069588',
#   'l3082983',
#   {'label': 'ln6228303-1',
#    'device': 'Line',
#    'resistance': 0.01290191054802,
#    'reactance': 0.007200034348319999,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 27.531763208071276,
#    'residue': 572.4682367919287}),
#  ('l2804270',
#   'l3104145',
#   {'label': 'ln5593244-1',
#    'device': 'Line',
#    'resistance': 0.049629456765720004,
#    'reactance': 0.027696192131519998,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.8388213225078852,
#    'residue': 599.1611786774921}),
#  ('l2804270',
#   'x2804270b',
#   {'label': 't5339013b',
#    'device': 'Transformer',
#    'resistance': 1.1520000000000001,
#    'reactance': 1.9584000000000001,
#    'phases': 1,
#    'maxcap': 3.125,
#    'cap': 8.885048466045777,
#    'residue': -5.760048466045777}),
#  ('m3036164',
#   'l2935553',
#   {'label': 'ln5835135-2',
#    'device': 'Line',
#    'resistance': 0.026655917131479998,
#    'reactance': 0.014875589023679999,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 15.685380038486892,
#    'residue': 584.3146199615131}),
#  ('m3036164',
#   'l3085397',
#   {'label': 'ln5593224-2',
#    'device': 'Line',
#    'resistance': 0.09424242372740001,
#    'reactance': 0.0525928842384,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.3505931216439588,
#    'residue': 598.649406878356}),
#  ('m3036164',
#   'l3048207',
#   {'label': 'ln6505939-4',
#    'device': 'Line',
#    'resistance': 0.00163080567858,
#    'reactance': 0.0009100866772799999,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 17.035958628131766,
#    'residue': 582.9640413718682}),
#  ('l2935553',
#   'm1026987',
#   {'label': 'ln5593223-1',
#    'device': 'Line',
#    'resistance': 0.0732531041115,
#    'reactance': 0.04072309704555,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 14.334057636055276,
#    'residue': 585.6659423639447}),
#  ('l2935553',
#   'x2935553b',
#   {'label': 't5323247b',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 14.301640443690907,
#    'residue': -9.093307110357575}),
#  ('m1209749',
#   'l2748840',
#   {'label': 'ln5896826-1',
#    'device': 'Line',
#    'resistance': 0.076010143035,
#    'reactance': 0.060708216930916666,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.8284547287940444,
#    'residue': 599.1715452712059}),
#  ('m1209749',
#   'm1209750',
#   {'label': 'ln6351512-1',
#    'device': 'Line',
#    'resistance': 0.0031895395641000006,
#    'reactance': 0.002547439749955,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.8284154929394502,
#    'residue': 599.1715845070605}),
#  ('l2748840',
#   'x2748840b',
#   {'label': 't5157717b',
#    'device': 'Transformer',
#    'resistance': 1.1520000000000001,
#    'reactance': 1.9584000000000001,
#    'phases': 1,
#    'maxcap': 3.125,
#    'cap': 8.779631149223496,
#    'residue': -5.654631149223496}),
#  ('m1108264',
#   'm1108263',
#   {'label': 'ln5714038-1',
#    'device': 'Line',
#    'resistance': 0.05590448048874333,
#    'reactance': 0.031078595396570333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.2036515945804105,
#    'residue': 597.7963484054196}),
#  ('m1108264',
#   'm1108265',
#   {'label': 'ln5926296-1',
#    'device': 'Line',
#    'resistance': 0.5409862860636,
#    'reactance': 0.30190256141759997,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.1994222784346795,
#    'residue': 597.8005777215653}),
#  ('m1108263',
#   'n1142112',
#   {'label': 'ln5686078-2',
#    'device': 'Line',
#    'resistance': 0.0642999500538,
#    'reactance': 0.0352952737797,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.2040947899608385,
#    'residue': 597.7959052100391}),
#  ('l3085398',
#   'm1026891',
#   {'label': 'ln5653457-1',
#    'device': 'Line',
#    'resistance': 0.13214513956469803,
#    'reactance': 0.04257759689178666,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 25.397505953422424,
#    'residue': 574.6024940465776}),
#  ('l3085398',
#   'm1026907',
#   {'label': 'ln6138604-1',
#    'device': 'Line',
#    'resistance': 0.08647054613291599,
#    'reactance': 0.027861093252373344,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 25.84808816201566,
#    'residue': 574.1519118379844}),
#  ('l3085398',
#   'x3085398b',
#   {'label': 't5355777b',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 14.312875673813773,
#    'residue': -9.104542340480439}),
#  ('m1026891',
#   'n1147863',
#   {'label': 'ln6169249-2',
#    'device': 'Line',
#    'resistance': 0.005265553612540001,
#    'reactance': 0.0029384924606399997,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4332668856672106,
#    'residue': 598.5667331143328}),
#  ('m1026891',
#   'l3160102',
#   {'label': 'ln6017292-1',
#    'device': 'Line',
#    'resistance': 0.13455755550257203,
#    'reactance': 0.04335488521034668,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 24.920350529768132,
#    'residue': 575.0796494702319}),
#  ('l3216367',
#   'm1069468',
#   {'label': 'ln5835173-1',
#    'device': 'Line',
#    'resistance': 0.02149749346942,
#    'reactance': 0.020054971830986663,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 45.57875568111518,
#    'residue': 554.4212443188849}),
#  ('l3216367',
#   'l2991939',
#   {'label': 'ln5774495-1',
#    'device': 'Line',
#    'resistance': 0.048746395549878994,
#    'reactance': 0.04547542210005066,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 46.02681393614495,
#    'residue': 553.9731860638551}),
#  ('l3216367',
#   'x3216367b',
#   {'label': 't5337648b',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 14.243694506111671,
#    'residue': -9.035361172778337}),
#  ('m1069468',
#   'p827506',
#   {'label': 'ln5898057-1',
#    'device': 'Line',
#    'resistance': 0.00475277104588,
#    'reactance': 0.00265232925408,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.0574242005081733,
#    'residue': 597.9425757994918}),
#  ('m1069468',
#   'm1069464',
#   {'label': 'ln5532785-1',
#    'device': 'Line',
#    'resistance': 0.038018655067431,
#    'reactance': 0.03546753287837601,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 44.89327549177682,
#    'residue': 555.1067245082231}),
#  ('m1142800',
#   'm1142799',
#   {'label': 'ln6321415-1',
#    'device': 'Line',
#    'resistance': 0.0349046032929,
#    'reactance': 0.02787780872372833,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4150099757524839,
#    'residue': 598.5849900242475}),
#  ('m1142800',
#   'l2767409',
#   {'label': 'ln6412352-1',
#    'device': 'Line',
#    'resistance': 0.03488796744000001,
#    'reactance': 0.027864521905333336,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4145970486792043,
#    'residue': 598.5854029513208}),
#  ('m1142799',
#   'm1142798',
#   {'label': 'ln5896831-1',
#    'device': 'Line',
#    'resistance': 0.03770137526700001,
#    'reactance': 0.030111550602516666,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.41542487167558,
#    'residue': 598.5845751283244}),
#  ('m1047592',
#   'p827512',
#   {'label': 'ln5565092-1',
#    'device': 'Line',
#    'resistance': 0.00204093661122,
#    'reactance': 0.00113896415952,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.151150746249636,
#    'residue': 597.8488492537504}),
#  ('m1047592',
#   'm3763619',
#   {'label': 'ln5532748-5',
#    'device': 'Line',
#    'resistance': 0.020844702941197002,
#    'reactance': 0.019445984756578667,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 82.07100386727281,
#    'residue': 517.9289961327272}),
#  ('m1047592',
#   'm1047577',
#   {'label': 'ln5619489-1',
#    'device': 'Line',
#    'resistance': 0.053556080177029994,
#    'reactance': 0.04996236797821333,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 82.7872294408417,
#    'residue': 517.2127705591583}),
#  ('p827512',
#   'n1136994',
#   {'label': 'ln6201696-2',
#    'device': 'Line',
#    'resistance': 0.0089747625123,
#    'reactance': 0.005008451896799999,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.1511675245748187,
#    'residue': 597.8488324754252}),
#  ('m1047339',
#   'p895104',
#   {'label': 'ln6073648-1',
#    'device': 'Line',
#    'resistance': 0.00420762572992,
#    'reactance': 0.002221872095962667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 3.1519820104708356,
#    'residue': 596.8480179895291}),
#  ('m1047339',
#   'l2991922',
#   {'label': 'ln6047583-1',
#    'device': 'Line',
#    'resistance': 0.10819546875075467,
#    'reactance': 0.033301718730176,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 38.643199130533354,
#    'residue': 561.3568008694666}),
#  ('m1047339',
#   'l2860491',
#   {'label': 'ln5472370-1',
#    'device': 'Line',
#    'resistance': 0.127781133506238,
#    'reactance': 0.04117149984272,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 37.59303247065959,
#    'residue': 562.4069675293404}),
#  ('p895104',
#   'n1139537',
#   {'label': 'ln5528572-2',
#    'device': 'Line',
#    'resistance': 0.0077366115132,
#    'reactance': 0.00408538266991,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 3.1520155427688117,
#    'residue': 596.8479844572312}),
#  ('m1026915',
#   'm1026920',
#   {'label': 'ln5774457-1',
#    'device': 'Line',
#    'resistance': 0.0479657768926,
#    'reactance': 0.020379487498399997,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 25.47147970558736,
#    'residue': 574.5285202944126}),
#  ('m1026915',
#   'm1026916',
#   {'label': 'ln5502529-1',
#    'device': 'Line',
#    'resistance': 0.0011406241662,
#    'reactance': 0.0009110002501433334,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.0245973923776326,
#    'residue': 597.9754026076224}),
#  ('m1026915',
#   'm1026907',
#   {'label': 'ln5774458-1',
#    'device': 'Line',
#    'resistance': 0.08692519916483199,
#    'reactance': 0.036932394812287994,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 26.145810012840702,
#    'residue': 573.8541899871593}),
#  ('m1026920',
#   'l2729408',
#   {'label': 'ln6320338-1',
#    'device': 'Line',
#    'resistance': 0.009066889988100001,
#    'reactance': 0.007241595691155,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.3530041149576975,
#    'residue': 598.6469958850423}),
#  ('m1026920',
#   'm1026926',
#   {'label': 'ln6047565-1',
#    'device': 'Line',
#    'resistance': 0.11029099364225599,
#    'reactance': 0.046859950400703995,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 25.020774725934945,
#    'residue': 574.979225274065}),
#  ('n1138596',
#   'l3254207',
#   {'label': 'ln5534966-3',
#    'device': 'Line',
#    'resistance': 0.01367156195522,
#    'reactance': 0.00762954566352,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 11.232986374452631,
#    'residue': 588.7670136255474}),
#  ('n1138596',
#   'e182722',
#   {'label': 'ln5534966-2',
#    'device': 'Line',
#    'resistance': 0.0074558844094800006,
#    'reactance': 0.0041608274716799995,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 11.232927095821124,
#    'residue': 588.7670729041789}),
#  ('l3254207',
#   'm1069390',
#   {'label': 'ln5532739-1',
#    'device': 'Line',
#    'resistance': 0.039572068988139995,
#    'reactance': 0.02208357087024,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 10.460299509961295,
#    'residue': 589.5397004900387}),
#  ('l3254207',
#   'x3254207a',
#   {'label': 't5337671a',
#    'device': 'Transformer',
#    'resistance': 1.1520000000000001,
#    'reactance': 1.9584000000000001,
#    'phases': 1,
#    'maxcap': 3.125,
#    'cap': 8.177312440666467,
#    'residue': -5.0523124406664675}),
#  ('m1069464',
#   'p873787',
#   {'label': 'ln5859996-1',
#    'device': 'Line',
#    'resistance': 0.0023327177586,
#    'reactance': 0.0018631083967633334,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.6900606514078453,
#    'residue': 597.3099393485921}),
#  ('m1069464',
#   'm1069461',
#   {'label': 'ln5593251-1',
#    'device': 'Line',
#    'resistance': 0.041769370750263005,
#    'reactance': 0.038966568590247996,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 43.997165929692535,
#    'residue': 556.0028340703075}),
#  ('p873787',
#   'm1069463',
#   {'label': 'ln6163946-1',
#    'device': 'Line',
#    'resistance': 0.005526581170500001,
#    'reactance': 0.004414001542275,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.690090966248589,
#    'residue': 597.3099090337514}),
#  ('n1144665',
#   'm1047515',
#   {'label': 'ln6138610-2',
#    'device': 'Line',
#    'resistance': 0.04222758361797334,
#    'reactance': 0.013605849857440002,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 103.5720514490903,
#    'residue': 496.4279485509097}),
#  ('n1144665',
#   'l2897777',
#   {'label': 'ln6138610-3',
#    'device': 'Line',
#    'resistance': 0.041807970776450674,
#    'reactance': 0.013470649383464003,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 103.57185666083608,
#    'residue': 496.4281433391639}),
#  ('m1047515',
#   'm1047513',
#   {'label': 'ln5593236-6',
#    'device': 'Line',
#    'resistance': 0.17374153058939001,
#    'reactance': 0.055980090354933336,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 103.5722480567033,
#    'residue': 496.4277519432967}),
#  ('n1137002',
#   'm1047707',
#   {'label': 'ln6258435-3',
#    'device': 'Line',
#    'resistance': 0.034597129006500006,
#    'reactance': 0.02763223339740833,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.559887100454749,
#    'residue': 597.4401128995453}),
#  ('n1137002',
#   'm1047702',
#   {'label': 'ln6258435-2',
#    'device': 'Line',
#    'resistance': 0.007085210460900001,
#    'reactance': 0.005658856522128334,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.5598001039236387,
#    'residue': 597.4401998960764}),
#  ('m1047707',
#   'l3159645',
#   {'label': 'ln5511594-1',
#    'device': 'Line',
#    'resistance': 0.0008762013078000001,
#    'reactance': 0.0006998094852233333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.560312474260217,
#    'residue': 597.4396875257398}),
#  ('l2729406',
#   'l2897768',
#   {'label': 'ln5804790-1',
#    'device': 'Line',
#    'resistance': 0.10872596635420001,
#    'reactance': 0.060675563467199996,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.469105330499948,
#    'residue': 598.5308946695001}),
#  ('l2729406',
#   'm1089177',
#   {'label': 'ln6199512-1',
#    'device': 'Line',
#    'resistance': 0.07688918930680001,
#    'reactance': 0.0429087461088,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.34823850237636,
#    'residue': 597.6517614976236}),
#  ('l2729406',
#   'x2729406c',
#   {'label': 't5337633c',
#    'device': 'Transformer',
#    'resistance': 1.1520000000000001,
#    'reactance': 1.9584000000000001,
#    'phases': 1,
#    'maxcap': 3.125,
#    'cap': 9.317798017603467,
#    'residue': -6.192798017603467}),
#  ('l2897768',
#   'x2897768c',
#   {'label': 't5337634c',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 15.569481397468962,
#    'residue': -10.36114806413563}),
#  ('l3649301',
#   'l3649302',
#   {'label': 'ln6900591-14',
#    'device': 'Line',
#    'resistance': 0.0235909319277,
#    'reactance': 0.018841740797801664,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 4.629296066443885,
#    'residue': 595.3707039335561}),
#  ('l3649301',
#   'l3649300',
#   {'label': 'ln6900591-12',
#    'device': 'Line',
#    'resistance': 0.0228854100039,
#    'reactance': 0.018278250501778334,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 6.559467196879918,
#    'residue': 593.44053280312}),
#  ('l3649301',
#   'x3649301a',
#   {'label': 't2224237643a',
#    'device': 'Transformer',
#    'resistance': 0.4608,
#    'reactance': 0.7833600000000001,
#    'phases': 1,
#    'maxcap': 7.8125,
#    'cap': 20.42614171511587,
#    'residue': -12.613641715115872}),
#  ('l3649302',
#   'l3649304',
#   {'label': 'ln6900591-20',
#    'device': 'Line',
#    'resistance': 0.023478737093100003,
#    'reactance': 0.018752132383905,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.6990305154358114,
#    'residue': 597.3009694845642}),
#  ('l3649302',
#   'x3649302a',
#   {'label': 't2224237653a',
#    'device': 'Transformer',
#    'resistance': 0.4608,
#    'reactance': 0.7833600000000001,
#    'phases': 1,
#    'maxcap': 7.8125,
#    'cap': 20.427250007811043,
#    'residue': -12.614750007811043}),
#  ('l2970842',
#   'm1089113',
#   {'label': 'ln6409873-1',
#    'device': 'Line',
#    'resistance': 0.04012347088906,
#    'reactance': 0.022391285964959998,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 10.609972620505799,
#    'residue': 589.3900273794942}),
#  ('l2970842',
#   'n1139546',
#   {'label': 'ln5955074-2',
#    'device': 'Line',
#    'resistance': 0.0477660592344,
#    'reactance': 0.026656305350399995,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 10.60959185467807,
#    'residue': 589.3904081453219}),
#  ('m1089113',
#   'l2691946',
#   {'label': 'ln5835141-1',
#    'device': 'Line',
#    'resistance': 0.028436652968700002,
#    'reactance': 0.022711949067351665,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.8255290420316898,
#    'residue': 599.1744709579683}),
#  ('m1089113',
#   'm1089103',
#   {'label': 'ln6046042-1',
#    'device': 'Line',
#    'resistance': 0.2462503908644,
#    'reactance': 0.1374223814304,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.784777507683692,
#    'residue': 590.2152224923163}),
#  ('m1047312',
#   'p893163',
#   {'label': 'ln6014135-1',
#    'device': 'Line',
#    'resistance': 0.0022536385345066664,
#    'reactance': 0.0012419838381306665,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.91796184506288,
#    'residue': 590.0820381549371}),
#  ('m1047312',
#   'l3216370',
#   {'label': 'ln6199560-1',
#    'device': 'Line',
#    'resistance': 0.15553765166246664,
#    'reactance': 0.05011468226179999,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 34.17377483015493,
#    'residue': 565.8262251698451}),
#  ('m1047312',
#   'n1137960',
#   {'label': 'ln6320367-3',
#    'device': 'Line',
#    'resistance': 0.023387878544977335,
#    'reactance': 0.007535642267524,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 30.868481134845002,
#    'residue': 569.131518865155}),
#  ('p893163',
#   'm1047314',
#   {'label': 'ln5741249-1',
#    'device': 'Line',
#    'resistance': 0.0021347956318,
#    'reactance': 0.001176489322405,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.917979758134802,
#    'residue': 590.0820202418652}),
#  ('l2822871',
#   'm1026872',
#   {'label': 'ln6077784-1',
#    'device': 'Line',
#    'resistance': 0.031270982230535004,
#    'reactance': 0.029172641389693336,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 55.870599210465855,
#    'residue': 544.1294007895342}),
#  ('l2822871',
#   'l3235257',
#   {'label': 'ln5804805-1',
#    'device': 'Line',
#    'resistance': 0.057441566134509986,
#    'reactance': 0.05358713062962665,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 56.32273475589118,
#    'residue': 543.6772652441089}),
#  ('l2822871',
#   'x2822871b',
#   {'label': 't5355840b',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 14.377250664508098,
#    'residue': -9.168917331174764}),
#  ('m1026872',
#   'd5502543-2_int',
#   {'label': 'ln5502543-2',
#    'device': 'Line',
#    'resistance': 0.047423844465523994,
#    'reactance': 0.04424161664363733,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 55.87107041115152,
#    'residue': 544.1289295888485}),
#  ('m1026312',
#   'l2973163',
#   {'label': 'ln5744338-1',
#    'device': 'Line',
#    'resistance': 0.029903353237683335,
#    'reactance': 0.016623966597128333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 27.432800233229816,
#    'residue': 572.5671997667702}),
#  ('m1026312',
#   'm4118754',
#   {'label': 'ln6380821-3',
#    'device': 'Line',
#    'resistance': 0.07571734633516666,
#    'reactance': 0.04209302636711667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 27.4322176238357,
#    'residue': 572.5677823761642}),
#  ('l2973163',
#   'm1026309',
#   {'label': 'ln5895782-1',
#    'device': 'Line',
#    'resistance': 0.04794140116038,
#    'reactance': 0.02675415658608,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 26.85084933058627,
#    'residue': 573.1491506694138}),
#  ('l2973163',
#   'x2973163b',
#   {'label': 't5391753b',
#    'device': 'Transformer',
#    'resistance': 1.728,
#    'reactance': 2.9375999999999998,
#    'phases': 1,
#    'maxcap': 2.0833333333333335,
#    'cap': 6.167482805784258,
#    'residue': -4.084149472450925}),
#  ('l3728038',
#   'l3728039',
#   {'label': 'ln6991381-4',
#    'device': 'Line',
#    'resistance': 0.0295946076915,
#    'reactance': 0.023636790985825,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 5.153039809746469,
#    'residue': 594.8469601902535}),
#  ('l3728038',
#   'm3949154',
#   {'label': 'ln6991381-2',
#    'device': 'Line',
#    'resistance': 0.0014165408730000002,
#    'reactance': 0.0011313709878166668,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 6.439451575559973,
#    'residue': 593.5605484244401}),
#  ('l3728038',
#   'x3728038a',
#   {'label': 't2224387019a',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 13.611813320008736,
#    'residue': -8.403479986675404}),
#  ('l3728039',
#   'l3728040',
#   {'label': 'ln6991381-6',
#    'device': 'Line',
#    'resistance': 0.0225760648434,
#    'reactance': 0.018031180935003333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 3.2198009413185584,
#    'residue': 596.7801990586814}),
#  ('l3728039',
#   'x3728039a',
#   {'label': 't2224387053a',
#    'device': 'Transformer',
#    'resistance': 0.4608,
#    'reactance': 0.7833600000000001,
#    'phases': 1,
#    'maxcap': 7.8125,
#    'cap': 20.460012317462724,
#    'residue': -12.647512317462724}),
#  ('m1069567',
#   'm1069582',
#   {'label': 'ln5774480-1',
#    'device': 'Line',
#    'resistance': 0.085382763388,
#    'reactance': 0.04764866620799999,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 31.731358768990834,
#    'residue': 568.2686412310092}),
#  ('m1069567',
#   'm1069560',
#   {'label': 'ln5773046-1',
#    'device': 'Line',
#    'resistance': 0.045454859851959996,
#    'reactance': 0.025366518471359997,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 34.540740766745756,
#    'residue': 565.4592592332542}),
#  ('m1069567',
#   'l2691966',
#   {'label': 'ln5472385-1',
#    'device': 'Line',
#    'resistance': 0.045800195956320004,
#    'reactance': 0.02555923658112,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.809747992197564,
#    'residue': 597.1902520078024}),
#  ('m1069582',
#   'l2973171',
#   {'label': 'ln5895802-1',
#    'device': 'Line',
#    'resistance': 0.0098109464565,
#    'reactance': 0.007835862978241665,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4001772706437865,
#    'residue': 598.5998227293562}),
#  ('m1069582',
#   'd6231996-1_int',
#   {'label': 'ln6231996-1',
#    'device': 'Line',
#    'resistance': 0.013777461871420002,
#    'reactance': 0.00768864412272,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 28.93234056872786,
#    'residue': 571.0676594312721}),
#  ('m1069582',
#   'l2933165',
#   {'label': 'ln5833720-1',
#    'device': 'Line',
#    'resistance': 0.0352099414147,
#    'reactance': 0.019649243935199998,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.3995285911229884,
#    'residue': 598.600471408877}),
#  ('n1140830',
#   'l3216351',
#   {'label': 'ln5986938-3',
#    'device': 'Line',
#    'resistance': 0.004878647423,
#    'reactance': 0.002722575768,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 5.513245918389778,
#    'residue': 594.4867540816102}),
#  ('n1140830',
#   'm1026690',
#   {'label': 'ln5986938-2',
#    'device': 'Line',
#    'resistance': 0.00656526672828,
#    'reactance': 0.0036638097724799993,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 5.51319513557466,
#    'residue': 594.4868048644254}),
#  ('l3216351',
#   'l2879081',
#   {'label': 'ln5986937-1',
#    'device': 'Line',
#    'resistance': 0.01769432191254,
#    'reactance': 0.00987448526064,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 4.201755974993139,
#    'residue': 595.7982440250069}),
#  ('l3216351',
#   'x3216351a',
#   {'label': 't21398815a',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 13.881836425086968,
#    'residue': -8.673503091753634}),
#  ('l2952007',
#   'l2861158',
#   {'label': 'ln5894230-1',
#    'device': 'Line',
#    'resistance': 0.0706407760656,
#    'reactance': 0.03942175944959999,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4471867436044972,
#    'residue': 598.5528132563956}),
#  ('l2952007',
#   'm1166407',
#   {'label': 'ln5985365-1',
#    'device': 'Line',
#    'resistance': 0.08400972081840001,
#    'reactance': 0.046882426694399994,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.8941979565608076,
#    'residue': 597.1058020434392}),
#  ('l2952007',
#   'x2952007c',
#   {'label': 't5251859c',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 15.330080992533475,
#    'residue': -10.121747659200143}),
#  ('l2861158',
#   'x2861158c',
#   {'label': 't5251858c',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 15.330803790072196,
#    'residue': -10.122470456738863}),
#  ('n1140827',
#   'm1026726',
#   {'label': 'ln5683858-3',
#    'device': 'Line',
#    'resistance': 0.026625353759995,
#    'reactance': 0.00857877620946667,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 3.2104052246057075,
#    'residue': 596.7895947753943}),
#  ('n1140827',
#   'l3216368',
#   {'label': 'ln5683858-2',
#    'device': 'Line',
#    'resistance': 0.042702977063815,
#    'reactance': 0.013759039110266666,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 3.2102123347531353,
#    'residue': 596.7897876652469}),
#  ('m1026726',
#   'l2916610',
#   {'label': 'ln6506308-1',
#    'device': 'Line',
#    'resistance': 0.0367934982449,
#    'reactance': 0.02044578261530033,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.3602216340180955,
#    'residue': 598.6397783659819}),
#  ('m1026726',
#   'l2814529',
#   {'label': 'ln6286965-1',
#    'device': 'Line',
#    'resistance': 0.039202308605365666,
#    'reactance': 0.019787579928798336,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 2.757234499619963,
#    'residue': 597.2427655003801}),
#  ('m1026726',
#   'l2876847',
#   {'label': 'ln5833721-1',
#    'device': 'Line',
#    'resistance': 0.040683951680060004,
#    'reactance': 0.02270406762096,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.0013509826254108222,
#    'residue': 599.9986490173745}),
#  ('l2730106',
#   'n1142099',
#   {'label': 'ln5920279-5',
#    'device': 'Line',
#    'resistance': 0.0035202518475599995,
#    'reactance': 0.008236903915295999,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 301.724765184584,
#    'residue': 298.275234815416}),
#  ('l2730106',
#   'm1108484',
#   {'label': 'ln5503480-1',
#    'device': 'Line',
#    'resistance': 0.016346416910716664,
#    'reactance': 0.038248361561479996,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 302.1890739261505,
#    'residue': 297.8109260738495}),
#  ('l2730106',
#   'x2730106c',
#   {'label': 't5356814c',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 15.147000228920474,
#    'residue': -9.93866689558714}),
#  ('n1142099',
#   'n1142100',
#   {'label': 'ln5920279-4',
#    'device': 'Line',
#    'resistance': 0.005488285257093335,
#    'reactance': 0.012841830721215997,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 301.72485074044647,
#    'residue': 298.27514925955353}),
#  ('m1026658',
#   'l3172805',
#   {'label': 'ln6439600-1',
#    'device': 'Line',
#    'resistance': 0.039909122676000004,
#    'reactance': 0.0318748469638,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.3114139007633407,
#    'residue': 598.6885860992367}),
#  ('m1026658',
#   'l2673319',
#   {'label': 'ln5591284-1',
#    'device': 'Line',
#    'resistance': 0.04987671038931999,
#    'reactance': 0.015351661208640002,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 2.840479166179085,
#    'residue': 597.1595208338209}),
#  ('m1026658',
#   'm1026655',
#   {'label': 'ln5591284-2',
#    'device': 'Line',
#    'resistance': 0.106991181618526,
#    'reactance': 0.032931048573552,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 2.4031646206935657,
#    'residue': 597.5968353793064}),
#  ('l3172805',
#   'x3172805a',
#   {'label': 't226964880a',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 13.885625470426367,
#    'residue': -8.677292137093033}),
#  ('p895112',
#   'l3048962',
#   {'label': 'ln5589097-1',
#    'device': 'Line',
#    'resistance': 0.009587818726336668,
#    'reactance': 0.008003808895082001,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.9769812729557512,
#    'residue': 598.0230187270442}),
#  ('p895112',
#   'm1142865',
#   {'label': 'ln5800724-1',
#    'device': 'Line',
#    'resistance': 0.0032690061092566663,
#    'reactance': 0.002728931462114,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.9769421816082395,
#    'residue': 598.0230578183917}),
#  ('l3048962',
#   'x3048962a',
#   {'label': 't5260555a',
#    'device': 'Transformer',
#    'resistance': 0.4608,
#    'reactance': 0.7833600000000001,
#    'phases': 1,
#    'maxcap': 7.8125,
#    'cap': 20.927705984732803,
#    'residue': -13.115205984732803}),
#  ('l2991914',
#   'm1047503',
#   {'label': 'ln5651975-1',
#    'device': 'Line',
#    'resistance': 0.05496529353265699,
#    'reactance': 0.017709997649413334,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 36.64524207258217,
#    'residue': 563.3547579274178}),
#  ('l2991914',
#   'n1140519',
#   {'label': 'ln5895780-3',
#    'device': 'Line',
#    'resistance': 0.08648298692518501,
#    'reactance': 0.0278651017164,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 36.93214337564511,
#    'residue': 563.0678566243549}),
#  ('l2991914',
#   'x2991914c',
#   {'label': 't5338941c',
#    'device': 'Transformer',
#    'resistance': 1.1520000000000001,
#    'reactance': 1.9584000000000001,
#    'phases': 1,
#    'maxcap': 3.125,
#    'cap': 9.125906598259776,
#    'residue': -6.0009065982597765}),
#  ('m1047503',
#   'l2841635',
#   {'label': 'ln5863706-1',
#    'device': 'Line',
#    'resistance': 0.036643025366778,
#    'reactance': 0.011806502820319998,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 36.64549077311286,
#    'residue': 563.3545092268871}),
#  ('m1047751',
#   'l2973154',
#   {'label': 'ln5865236-1',
#    'device': 'Line',
#    'resistance': 0.0051957554584,
#    'reactance': 0.0028995409343999996,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.572196667995134,
#    'residue': 597.4278033320048}),
#  ('m1047751',
#   'm1047755',
#   {'label': 'ln5623397-1',
#    'device': 'Line',
#    'resistance': 0.040896867952459996,
#    'reactance': 0.02282288757936,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.5718711757277273,
#    'residue': 597.4281288242722}),
#  ('l2973154',
#   'l2879069',
#   {'label': 'ln6229797-1',
#    'device': 'Line',
#    'resistance': 0.03577611660792,
#    'reactance': 0.019965203406720002,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.801219216489952,
#    'residue': 598.1987807835101}),
#  ('l2973154',
#   'x2973154a',
#   {'label': 't5338897a',
#    'device': 'Transformer',
#    'resistance': 1.1520000000000001,
#    'reactance': 1.9584000000000001,
#    'phases': 1,
#    'maxcap': 3.125,
#    'cap': 8.158207341756784,
#    'residue': -5.033207341756784}),
#  ('l3010565',
#   'l2897775',
#   {'label': 'ln5593232-1',
#    'device': 'Line',
#    'resistance': 0.05268299163600001,
#    'reactance': 0.04207715387846667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4477899151436817,
#    'residue': 598.5522100848564}),
#  ('l3010565',
#   'm1069201',
#   {'label': 'ln6199520-1',
#    'device': 'Line',
#    'resistance': 0.0806258470004,
#    'reactance': 0.0449940236064,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.0249821369488155,
#    'residue': 597.9750178630512}),
#  ('l3010565',
#   'x3010565c',
#   {'label': 't5138343c',
#    'device': 'Transformer',
#    'resistance': 1.728,
#    'reactance': 2.9375999999999998,
#    'phases': 1,
#    'maxcap': 2.0833333333333335,
#    'cap': 6.118886273238268,
#    'residue': -4.035552939904935}),
#  ('l2897775',
#   'x2897775c',
#   {'label': 't5138342c',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 15.338162798242701,
#    'residue': -10.129829464909367}),
#  ('m1125955',
#   'm1125957',
#   {'label': 'ln5740283-1',
#    'device': 'Line',
#    'resistance': 0.0037175504594666666,
#    'reactance': 0.002040623066533333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.7123476032806835,
#    'residue': 598.2876523967193}),
#  ('m1125955',
#   'p901936',
#   {'label': 'ln6258453-1',
#    'device': 'Line',
#    'resistance': 0.01941873166596,
#    'reactance': 0.01065925323474,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.568125845485601,
#    'residue': 597.4318741545144}),
#  ('m1125955',
#   'l3236004',
#   {'label': 'ln5625527-1',
#    'device': 'Line',
#    'resistance': 0.0614644881202,
#    'reactance': 0.0337388432513,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.8559416486574436,
#    'residue': 599.1440583513426}),
#  ('m1125957',
#   'l2936211',
#   {'label': 'ln5982822-1',
#    'device': 'Line',
#    'resistance': 0.020618863405273333,
#    'reactance': 0.011318024793276668,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.7123788873605972,
#    'residue': 598.2876211126394}),
#  ('m1069640',
#   'l2804269',
#   {'label': 'ln6106559-1',
#    'device': 'Line',
#    'resistance': 0.056461178646599997,
#    'reactance': 0.0315086997456,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 3.9300455261017255,
#    'residue': 596.0699544738983}),
#  ('m1069640',
#   'm1069629',
#   {'label': 'ln5894218-1',
#    'device': 'Line',
#    'resistance': 0.0816688196662,
#    'reactance': 0.04557606445919999,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 5.334545560293411,
#    'residue': 594.6654544397065}),
#  ('m1069640',
#   'l3160113',
#   {'label': 'ln6015793-1',
#    'device': 'Line',
#    'resistance': 0.0352188136239,
#    'reactance': 0.028128764032778333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4051514501933642,
#    'residue': 598.5948485498067}),
#  ('l2804269',
#   'l2989564',
#   {'label': 'ln5591703-1',
#    'device': 'Line',
#    'resistance': 0.034650125463720004,
#    'reactance': 0.01933683329952,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.5248040542834262,
#    'residue': 597.4751959457166}),
#  ('l2804269',
#   'x2804269b',
#   {'label': 't5323285b',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 14.883716892769812,
#    'residue': -9.67538355943648}),
#  ('m1026702',
#   'n1139551',
#   {'label': 'ln5714056-3',
#    'device': 'Line',
#    'resistance': 0.19848292714178667,
#    'reactance': 0.06395177451752,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 29.599157207537846,
#    'residue': 570.4008427924622}),
#  ('m1026702',
#   'l2729414',
#   {'label': 'ln5653470-1',
#    'device': 'Line',
#    'resistance': 0.04942615464879934,
#    'reactance': 0.024948122201976657,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 1.373395839527462,
#    'residue': 598.6266041604725}),
#  ('m1026702',
#   'n1139552',
#   {'label': 'ln5895789-2',
#    'device': 'Line',
#    'resistance': 0.135179794008351,
#    'reactance': 0.04355537249544001,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 30.971939912987438,
#    'residue': 569.0280600870126}),
#  ('n1139551',
#   'm1026695',
#   {'label': 'ln5714056-2',
#    'device': 'Line',
#    'resistance': 0.03482802773524134,
#    'reactance': 0.011221691501068002,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 29.600047652702244,
#    'residue': 570.3999523472978}),
#  ('n1136355',
#   'l2783231',
#   {'label': 'ln5985355-3',
#    'device': 'Line',
#    'resistance': 0.03945936765660667,
#    'reactance': 0.021659879726943332,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 55.36183969618644,
#    'residue': 544.6381603038136}),
#  ('n1136355',
#   '196-29521',
#   {'label': 'ln5985355-4',
#    'device': 'Line',
#    'resistance': 0.005581476034446666,
#    'reactance': 0.003063761706903333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 55.36179329691571,
#    'residue': 544.6382067030843}),
#  ('l2783231',
#   'l3254227',
#   {'label': 'ln5985355-1',
#    'device': 'Line',
#    'resistance': 0.0827472973064,
#    'reactance': 0.0454213185316,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 53.96994691341261,
#    'residue': 546.0300530865874}),
#  ('l2783231',
#   'x2783231b',
#   {'label': 't226193886b',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 14.738904011469048,
#    'residue': -9.530570678135714}),
#  ('l2748143',
#   'l3251854',
#   {'label': 'ln5531956-1',
#    'device': 'Line',
#    'resistance': 0.025085678779800002,
#    'reactance': 0.02003557378549,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.3441144443513335,
#    'residue': 598.6558855556486}),
#  ('l2748143',
#   'l3197652',
#   {'label': 'ln6138622-1',
#    'device': 'Line',
#    'resistance': 0.011420029117500001,
#    'reactance': 0.009121014345458334,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.6883655397571022,
#    'residue': 597.3116344602429}),
#  ('l2748143',
#   'x2748143a',
#   {'label': 't28121368a',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 14.234901917229587,
#    'residue': -9.026568583896253}),
#  ('l3251854',
#   'x3251854a',
#   {'label': 't226881700a',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 14.235150765450472,
#    'residue': -9.026817432117138}),
#  ('m1069610',
#   'm1069600',
#   {'label': 'ln5650048-1',
#    'device': 'Line',
#    'resistance': 0.022805025640500003,
#    'reactance': 0.018214048657441667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4029236873299353,
#    'residue': 598.5970763126701}),
#  ('m1069610',
#   'm1069620',
#   {'label': 'ln6074369-1',
#    'device': 'Line',
#    'resistance': 0.007447674828600002,
#    'reactance': 0.00594835164193,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.8060649977576317,
#    'residue': 597.1939350022424}),
#  ('m1069610',
#   'l2991929',
#   {'label': 'ln6074369-2',
#    'device': 'Line',
#    'resistance': 0.0171380847687,
#    'reactance': 0.013687943824018334,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.403232970504203,
#    'residue': 598.5967670294958}),
#  ('m1069600',
#   'l3102793',
#   {'label': 'ln5831676-1',
#    'device': 'Line',
#    'resistance': 0.0216649308258,
#    'reactance': 0.01730347119279,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4032034837260832,
#    'residue': 598.5967965162739}),
#  ('m1069424',
#   'l2935549',
#   {'label': 'ln6290203-1',
#    'device': 'Line',
#    'resistance': 0.046063965454954996,
#    'reactance': 0.04297298803401333,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 37.67544760022105,
#    'residue': 562.3245523997789}),
#  ('m1069424',
#   'n1139255',
#   {'label': 'ln5898055-2',
#    'device': 'Line',
#    'resistance': 0.003990576699900001,
#    'reactance': 0.003187216683245,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.5771935994659296,
#    'residue': 597.4228064005341}),
#  ('m1069424',
#   'm1069428',
#   {'label': 'ln6047604-1',
#    'device': 'Line',
#    'resistance': 0.039858385676934005,
#    'reactance': 0.037183814155664005,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 38.53391206325227,
#    'residue': 561.4660879367477}),
#  ('l2935549',
#   'm1069420',
#   {'label': 'ln5835131-1',
#    'device': 'Line',
#    'resistance': 0.04992505105060501,
#    'reactance': 0.046574987633079996,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 37.007205829641215,
#    'residue': 562.9927941703588}),
#  ('l2935549',
#   'x2935549b',
#   {'label': 't5337668b',
#    'device': 'Transformer',
#    'resistance': 0.4608,
#    'reactance': 0.7833600000000001,
#    'phases': 1,
#    'maxcap': 7.8125,
#    'cap': 21.231347319005792,
#    'residue': -13.418847319005792}),
#  ('p895089',
#   'l3235242',
#   {'label': 'ln6134414-1',
#    'device': 'Line',
#    'resistance': 0.0226356829158,
#    'reactance': 0.018078797038956665,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.8403125324850964,
#    'residue': 597.1596874675149}),
#  ('p895089',
#   'm1089213',
#   {'label': 'ln5861081-1',
#    'device': 'Line',
#    'resistance': 0.0034984137327,
#    'reactance': 0.0027941331422183333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.840268341565381,
#    'residue': 597.1597316584346}),
#  ('l3235242',
#   'm1089195',
#   {'label': 'ln5623391-1',
#    'device': 'Line',
#    'resistance': 0.051483290346,
#    'reactance': 0.0411189695723,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.419753122504587,
#    'residue': 598.5802468774954}),
#  ('l3235242',
#   'x3235242c',
#   {'label': 't21380500c',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 15.041566681258303,
#    'residue': -9.83323334792497}),
#  ('m1026795',
#   'n1140522',
#   {'label': 'ln6259998-2',
#    'device': 'Line',
#    'resistance': 0.005071864116900001,
#    'reactance': 0.004050825518261666,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.7290551900575717,
#    'residue': 598.2709448099424}),
#  ('m1026795',
#   'm1026796',
#   {'label': 'ln5498301-1',
#    'device': 'Line',
#    'resistance': 0.046889603542628,
#    'reactance': 0.015107983877653332,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 35.001144015202144,
#    'residue': 564.9988559847978}),
#  ('m1026795',
#   'm1026786',
#   {'label': 'ln6108144-1',
#    'device': 'Line',
#    'resistance': 0.11373057050384668,
#    'reactance': 0.03664431951578,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 34.42500854124508,
#    'residue': 565.5749914587549}),
#  ('n1140522',
#   'l2822870',
#   {'label': 'ln6259998-3',
#    'device': 'Line',
#    'resistance': 0.005893132580700001,
#    'reactance': 0.004706760924618333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.729118469972248,
#    'residue': 598.2708815300277}),
#  ('l3030199',
#   'm1125934',
#   {'label': 'ln6078767-1',
#    'device': 'Line',
#    'resistance': 0.004610166464773333,
#    'reactance': 0.010787153831104,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 129.46832551898876,
#    'residue': 470.53167448101124}),
#  ('l3030199',
#   'l2955074',
#   {'label': 'ln5594239-1',
#    'device': 'Line',
#    'resistance': 0.01403118415006,
#    'reactance': 0.032831036149296014,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 129.93080209863555,
#    'residue': 470.0691979013644}),
#  ('l3030199',
#   'x3030199c',
#   {'label': 't5260480c',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 15.184749164426288,
#    'residue': -9.976415831092954}),
#  ('m1125934',
#   'l2730163',
#   {'label': 'ln5503576-1',
#    'device': 'Line',
#    'resistance': 0.009973635217140002,
#    'reactance': 0.023336931142224,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 129.4682732059837,
#    'residue': 470.5317267940163}),
#  ('m1069189',
#   'l2860487',
#   {'label': 'ln6017300-1',
#    'device': 'Line',
#    'resistance': 0.04737377036759333,
#    'reactance': 0.026004222300356667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.8643656695894161,
#    'residue': 599.1356343304105}),
#  ('m1069189',
#   'm1069184',
#   {'label': 'ln6108136-1',
#    'device': 'Line',
#    'resistance': 0.038701366924020666,
#    'reactance': 0.011911944150487,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 70.17794718367132,
#    'residue': 529.8220528163287}),
#  ('m1069189',
#   'l3195356',
#   {'label': 'ln5501088-1',
#    'device': 'Line',
#    'resistance': 0.10831158366897266,
#    'reactance': 0.033337363459243,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 70.30824333322327,
#    'residue': 529.6917566667768}),
#  ('l2860487',
#   'x2860487c',
#   {'label': 't5138586c',
#    'device': 'Transformer',
#    'resistance': 1.1520000000000001,
#    'reactance': 1.9584000000000001,
#    'phases': 1,
#    'maxcap': 3.125,
#    'cap': 9.15676236819232,
#    'residue': -6.03176236819232}),
#  ('221-312488',
#   'm1089183',
#   {'label': 'ln8979257-2',
#    'device': 'Line',
#    'resistance': 0.007449863216176,
#    'reactance': 0.0027136995489399998,
#    'phases': 3,
#    'maxcap': 190.0,
#    'cap': 1.4135803349334084,
#    'residue': 188.5864196650666}),
#  ('221-312488',
#   'p850083',
#   {'label': 'ln8979257-1',
#    'device': 'Line',
#    'resistance': 0.003250805170648,
#    'reactance': 0.0011841436908699996,
#    'phases': 3,
#    'maxcap': 190.0,
#    'cap': 1.413386142646192,
#    'residue': 188.5866138573538}),
#  ('m1089183',
#   'l2990826',
#   {'label': 'ln8979256-1',
#    'device': 'Line',
#    'resistance': 0.028703264207864003,
#    'reactance': 0.01045549869491,
#    'phases': 3,
#    'maxcap': 190.0,
#    'cap': 1.4140268472832191,
#    'residue': 188.58597315271678}),
#  ('m1108464',
#   'l3102286',
#   {'label': 'ln81048109-1',
#    'device': 'Line',
#    'resistance': 0.03434860277277999,
#    'reactance': 0.019387707035773333,
#    'phases': 1,
#    'maxcap': 220.0,
#    'cap': 4.383485633174763,
#    'residue': 215.61651436682524}),
#  ('m1108464',
#   'l3233413',
#   {'label': 'ln81048107-4',
#    'device': 'Line',
#    'resistance': 0.014806574662019999,
#    'reactance': 0.00835741510796,
#    'phases': 1,
#    'maxcap': 220.0,
#    'cap': 4.382678392654723,
#    'residue': 215.61732160734527}),
#  ('l3102286',
#   'm1108433',
#   {'label': 'ln81048109-2',
#    'device': 'Line',
#    'resistance': 0.012481800804591998,
#    'reactance': 0.007045220991349334,
#    'phases': 1,
# ...
#    'device': 'Line',
#    'resistance': 0.019853743258500003,
#    'reactance': 0.01585690152000833,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 22.782588532688795,
#    'residue': 577.2174114673112}),
#  ('m1069356',
#   'm1069363',
#   {'label': 'ln6260025-1',
#    'device': 'Line',
#    'resistance': 0.025006210213200004,
#    'reactance': 0.019972103374993333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4558202878373534,
#    'residue': 598.5441797121626}),
#  ('m1069356',
#   'm1069348',
#   {'label': 'ln5744366-1',
#    'device': 'Line',
#    'resistance': 0.0362496480444,
#    'reactance': 0.02895207677922,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4553776056323044,
#    'residue': 598.5446223943677}),
#  ('m1069363',
#   'm1069364',
#   {'label': 'ln6290239-1',
#    'device': 'Line',
#    'resistance': 0.034651608441300004,
#    'reactance': 0.027675745344814998,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4561267822146136,
#    'residue': 598.5438732177854}),
#  ('p828359',
#   'l2878848',
#   {'label': 'ln8961800-1',
#    'device': 'Line',
#    'resistance': 0.056740873722639994,
#    'reactance': 0.03202678851205333,
#    'phases': 1,
#    'maxcap': 220.0,
#    'cap': 7.883811615421131,
#    'residue': 212.11618838457886}),
#  ('p828359',
#   'm1047613',
#   {'label': 'ln8961758-1',
#    'device': 'Line',
#    'resistance': 0.001446263654764,
#    'reactance': 0.0008163282862053335,
#    'phases': 1,
#    'maxcap': 220.0,
#    'cap': 7.883728107263697,
#    'residue': 212.1162718927363}),
#  ('l2878848',
#   'l2766499',
#   {'label': 'ln8961800-2',
#    'device': 'Line',
#    'resistance': 0.046189971034599986,
#    'reactance': 0.02607144262413333,
#    'phases': 1,
#    'maxcap': 220.0,
#    'cap': 5.737525303928791,
#    'residue': 214.2624746960712}),
#  ('l2878848',
#   'x2878848c',
#   {'label': 't22112168887c',
#    'device': 'Transformer',
#    'resistance': 0.4608,
#    'reactance': 0.7833600000000001,
#    'phases': 1,
#    'maxcap': 7.8125,
#    'cap': 22.75889992949891,
#    'residue': -14.94639992949891}),
#  ('m1047486',
#   'l3177665',
#   {'label': 'ln6437757-1',
#    'device': 'Line',
#    'resistance': 0.006848036403593334,
#    'reactance': 0.005716667809996,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.932405786747258,
#    'residue': 598.0675942132527}),
#  ('m1047486',
#   'p827502',
#   {'label': 'ln5928543-1',
#    'device': 'Line',
#    'resistance': 0.0057027950577,
#    'reactance': 0.0031824992232,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.052555663004866,
#    'residue': 597.9474443369951}),
#  ('m1047486',
#   'l3122821',
#   {'label': 'ln5532753-1',
#    'device': 'Line',
#    'resistance': 0.07170498923681,
#    'reactance': 0.06689345161709331,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 56.064351575357115,
#    'residue': 543.9356484246429}),
#  ('m1047486',
#   'm1047484',
#   {'label': 'ln6012046-1',
#    'device': 'Line',
#    'resistance': 0.051851451558152996,
#    'reactance': 0.04837212309768799,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 54.73712812965304,
#    'residue': 545.262871870347}),
#  ('l3177665',
#   'x3177665a',
#   {'label': 't227731863a',
#    'device': 'Transformer',
#    'resistance': 0.4608,
#    'reactance': 0.7833600000000001,
#    'phases': 1,
#    'maxcap': 7.8125,
#    'cap': 20.448056244886153,
#    'residue': -12.635556244886153}),
#  ('l2805036',
#   'x2805036b',
#   {'label': 't5275248b',
#    'device': 'Transformer',
#    'resistance': 1.728,
#    'reactance': 2.9375999999999998,
#    'phases': 1,
#    'maxcap': 2.0833333333333335,
#    'cap': 5.831940632720925,
#    'residue': -3.7486072993875914}),
#  ('l2692654',
#   'm1125929',
#   {'label': 'ln5957492-1',
#    'device': 'Line',
#    'resistance': 0.0008902699492533333,
#    'reactance': 0.0007397858083866667,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.963783076428305,
#    'residue': 598.0362169235717}),
#  ('l2692654',
#   'n1141476',
#   {'label': 'ln5686245-3',
#    'device': 'Line',
#    'resistance': 0.028668542484796666,
#    'reactance': 0.02382264041953833,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.7457814930033546,
#    'residue': 597.2542185069966}),
#  ('l2692654',
#   'x2692654a',
#   {'label': 't5260487a',
#    'device': 'Transformer',
#    'resistance': 1.1520000000000001,
#    'reactance': 1.9584000000000001,
#    'phases': 1,
#    'maxcap': 3.125,
#    'cap': 8.279982704209674,
#    'residue': -5.154982704209674}),
#  ('m1125929',
#   'l2842379',
#   {'label': 'ln6018332-1',
#    'device': 'Line',
#    'resistance': 0.06026275893,
#    'reactance': 0.04813100588816666,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.9637937244210983,
#    'residue': 598.0362062755789}),
#  ('m1047669',
#   'm1047672',
#   {'label': 'ln5956464-1',
#    'device': 'Line',
#    'resistance': 0.005086427171089334,
#    'reactance': 0.0015655580462179996,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 32.966745769598454,
#    'residue': 567.0332542304016}),
#  ('m1047672',
#   'n1136999',
#   {'label': 'ln5774455-2',
#    'device': 'Line',
#    'resistance': 0.0059956243836000005,
#    'reactance': 0.004788619665513333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.557691383383842,
#    'residue': 597.4423086166162}),
#  ('m1047672',
#   'l2822866',
#   {'label': 'ln6411372-1',
#    'device': 'Line',
#    'resistance': 0.05772036032802866,
#    'reactance': 0.017765824910610996,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 32.11421359000952,
#    'residue': 567.8857864099905}),
#  ('m1125919',
#   'p829961',
#   {'label': 'ln6171683-1',
#    'device': 'Line',
#    'resistance': 0.003921057285216666,
#    'reactance': 0.003258272994508333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.745690186418708,
#    'residue': 597.2543098135812}),
#  ('m1125919',
#   'm1125917',
#   {'label': 'ln5745347-1',
#    'device': 'Line',
#    'resistance': 0.006294366696881665,
#    'reactance': 0.014727950139644,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 127.91554756652913,
#    'residue': 472.08445243347086}),
#  ('m1125919',
#   'l2992624',
#   {'label': 'ln6170293-1',
#    'device': 'Line',
#    'resistance': 0.008034013845678332,
#    'reactance': 0.018798484587652004,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 128.7638378312234,
#    'residue': 471.23616216877656}),
#  ('p829961',
#   'n1141476',
#   {'label': 'ln5686245-2',
#    'device': 'Line',
#    'resistance': 0.0037120536078466665,
#    'reactance': 0.0030845976339633333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.7457370847893197,
#    'residue': 597.2542629152107}),
#  ('m1142819',
#   'p829960',
#   {'label': 'ln5625715-1',
#    'device': 'Line',
#    'resistance': 0.0014008988640399997,
#    'reactance': 0.00078178498464,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.975489483972762,
#    'residue': 598.0245105160272}),
#  ('m1142819',
#   'l2711226',
#   {'label': 'ln5654471-1',
#    'device': 'Line',
#    'resistance': 0.012301439298644997,
#    'reactance': 0.028783671711732003,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 135.7752965572962,
#    'residue': 464.2247034427038}),
#  ('m1142819',
#   'l2861219',
#   {'label': 'ln5684859-1',
#    'device': 'Line',
#    'resistance': 0.022744357843500002,
#    'reactance': 0.018165594153425,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4154481488459854,
#    'residue': 598.5845518511541}),
#  ('p829960',
#   'n1141478',
#   {'label': 'ln5928743-2',
#    'device': 'Line',
#    'resistance': 0.00987033048846,
#    'reactance': 0.00550823215536,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.975500394793678,
#    'residue': 598.0244996052063}),
#  ('p829979',
#   'm3036172',
#   {'label': 'ln5746706-2',
#    'device': 'Line',
#    'resistance': 0.012183482296800002,
#    'reactance': 0.00973077350884,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 6.075025693251646,
#    'residue': 593.9249743067484}),
#  ('p829979',
#   'm1186063',
#   {'label': 'ln6322801-1',
#    'device': 'Line',
#    'resistance': 0.0014650088949,
#    'reactance': 0.001170081705495,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 6.075007669000869,
#    'residue': 593.9249923309991}),
#  ('m3036172',
#   'l3086079',
#   {'label': 'ln6505952-4',
#    'device': 'Line',
#    'resistance': 0.00150901714652,
#    'reactance': 0.0008421214243200001,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.1027855264819355,
#    'residue': 598.897214473518}),
#  ('m3036172',
#   'm1209763',
#   {'label': 'ln6321419-2',
#    'device': 'Line',
#    'resistance': 0.0684000977322,
#    'reactance': 0.0381713275152,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 4.972397732845521,
#    'residue': 595.0276022671545}),
#  ('m1026883',
#   'm1026898',
#   {'label': 'ln5653491-1',
#    'device': 'Line',
#    'resistance': 0.0344013290426,
#    'reactance': 0.0191979900816,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.712494668114652,
#    'residue': 598.2875053318853}),
#  ('m1026883',
#   'l3342743',
#   {'label': 'ln6140775-3',
#    'device': 'Line',
#    'resistance': 0.1576521518858,
#    'reactance': 0.08797928837279999,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.7112078203640386,
#    'residue': 598.288792179636}),
#  ('m1026898',
#   'l3197661',
#   {'label': 'ln6229832-1',
#    'device': 'Line',
#    'resistance': 0.0010887922371000001,
#    'reactance': 0.0008696028277716668,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.712777265201263,
#    'residue': 598.2872227347988}),
#  ('m1089143',
#   'l3141400',
#   {'label': 'ln5472361-1',
#    'device': 'Line',
#    'resistance': 0.053119021167420004,
#    'reactance': 0.02964357685872,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.5316550421580233,
#    'residue': 599.468344957842}),
#  ('m1089143',
#   'm1089141',
#   {'label': 'ln5502533-1',
#    'device': 'Line',
#    'resistance': 0.21177834714376997,
#    'reactance': 0.06823567726213334,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 92.81330302854947,
#    'residue': 507.18669697145054}),
#  ('m1089143',
#   'l3029498',
#   {'label': 'ln5623403-1',
#    'device': 'Line',
#    'resistance': 0.135236615542405,
#    'reactance': 0.043573680579866665,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 99.29127154647061,
#    'residue': 500.7087284535294}),
#  ('l3141400',
#   'x3141400a',
#   {'label': 't5138313a',
#    'device': 'Transformer',
#    'resistance': 1.728,
#    'reactance': 2.9375999999999998,
#    'phases': 1,
#    'maxcap': 2.0833333333333335,
#    'cap': 5.6328820434601345,
#    'residue': -3.549548710126801}),
#  ('m1069481',
#   'p827507',
#   {'label': 'ln5565091-1',
#    'device': 'Line',
#    'resistance': 0.0036682431615000007,
#    'reactance': 0.0029297734843250003,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.7324278357483684,
#    'residue': 598.2675721642516}),
#  ('m1069481',
#   'm1069483',
#   {'label': 'ln6229793-1',
#    'device': 'Line',
#    'resistance': 0.026492229858367,
#    'reactance': 0.02471455215489866,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 47.72380449835766,
#    'residue': 552.2761955016423}),
#  ('p827507',
#   'n1137956',
#   {'label': 'ln6079949-2',
#    'device': 'Line',
#    'resistance': 0.004201066309500001,
#    'reactance': 0.003355331731725,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.7324732525203046,
#    'residue': 598.2675267474797}),
#  ('m1026377',
#   'l3048210',
#   {'label': 'ln5653466-1',
#    'device': 'Line',
#    'resistance': 0.06919282363933334,
#    'reactance': 0.03813227691968333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.009229022902356,
#    'residue': 597.9907709770977}),
#  ('m1026377',
#   'm1026378',
#   {'label': 'ln5562936-1',
#    'device': 'Line',
#    'resistance': 0.03157307486614667,
#    'reactance': 0.017399972579199664,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 9.228292483490334,
#    'residue': 590.7717075165097}),
#  ('m1026377',
#   'l3104131',
#   {'label': 'ln5835146-1',
#    'device': 'Line',
#    'resistance': 0.03323297901542667,
#    'reactance': 0.018314748438187665,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 11.237260163475474,
#    'residue': 588.7627398365245}),
#  ('l3048210',
#   'x3048210a',
#   {'label': 't5302412a',
#    'device': 'Transformer',
#    'resistance': 0.4608,
#    'reactance': 0.7833600000000001,
#    'phases': 1,
#    'maxcap': 7.8125,
#    'cap': 21.278956558659015,
#    'residue': -13.466456558659015}),
#  ('e182722',
#   'd6049822-1_int',
#   {'label': 'l5397_48332_sw',
#    'device': 'Line',
#    'resistance': 0.0003333333333333333,
#    'reactance': 0.0003333333333333333,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 11.232926323165273,
#    'residue': 588.7670736768347}),
#  ('m1026331',
#   'l3214055',
#   {'label': 'ln6409762-1',
#    'device': 'Line',
#    'resistance': 0.0340287674324,
#    'reactance': 0.0189900785184,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.8665510272000669,
#    'residue': 599.1334489727999}),
#  ('l3214055',
#   'x3214055c',
#   {'label': 't226192175c',
#    'device': 'Transformer',
#    'resistance': 1.1520000000000001,
#    'reactance': 1.9584000000000001,
#    'phases': 1,
#    'maxcap': 3.125,
#    'cap': 9.178972871702635,
#    'residue': -6.053972871702635}),
#  ('m1108295',
#   'l2936279',
#   {'label': 'ln6109158-1',
#    'device': 'Line',
#    'resistance': 0.12910812770731597,
#    'reactance': 0.04159906172170667,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 100.94821584449524,
#    'residue': 499.0517841555048}),
#  ('m1108295',
#   'l3011298',
#   {'label': 'ln6351524-1',
#    'device': 'Line',
#    'resistance': 0.12358431216662133,
#    'reactance': 0.039819223645047995,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 100.94853845979617,
#    'residue': 499.05146154020383}),
#  ('l2936279',
#   'l3179678',
#   {'label': 'ln5473449-1',
#    'device': 'Line',
#    'resistance': 0.15681113110717332,
#    'reactance': 0.05052500103064,
#    'phases': 3,
#    'maxcap': 600.0,
#    'cap': 100.51595284430107,
#    'residue': 499.48404715569893}),
#  ('l2936279',
#   'x2936279c',
#   {'label': 't5247184c',
#    'device': 'Transformer',
#    'resistance': 0.6912,
#    'reactance': 1.17504,
#    'phases': 1,
#    'maxcap': 5.208333333333333,
#    'cap': 15.29203625971328,
#    'residue': -10.083702926379946}),
#  ('m1026704',
#   'l2841634',
#   {'label': 'ln5835145-1',
#    'device': 'Line',
#    'resistance': 0.061330335581999997,
#    'reactance': 0.048983664130766665,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 2.041986986219773,
#    'residue': 597.9580130137803}),
#  ('m1026704',
#   'm1026699',
#   {'label': 'ln6327237-2',
#    'device': 'Line',
#    'resistance': 0.0196544556993,
#    'reactance': 0.015697733389381668,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 6.118065610621823,
#    'residue': 593.8819343893782}),
#  ('m1026704',
#   'l2991915',
#   {'label': 'ln5865247-1',
#    'device': 'Line',
#    'resistance': 0.0205591533264,
#    'reactance': 0.01642030247832,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 4.076328532615348,
#    'residue': 595.9236714673847}),
#  ('l2841634',
#   'x2841634b',
#   {'label': 't5392038b',
#    'device': 'Transformer',
#    'resistance': 0.4608,
#    'reactance': 0.7833600000000001,
#    'phases': 1,
#    'maxcap': 7.8125,
#    'cap': 21.61819387519535,
#    'residue': -13.805693875195349}),
#  ('m1047386',
#   'm1047379',
#   {'label': 'ln5774493-1',
#    'device': 'Line',
#    'resistance': 0.05178206071138,
#    'reactance': 0.028424003566970002,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 5.127106516523664,
#    'residue': 594.8728934834763}),
#  ('m1047386',
#   'l2785520',
#   {'label': 'ln5865232-1',
#    'device': 'Line',
#    'resistance': 0.07499433942780001,
#    'reactance': 0.0418513070448,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 23.79782556195823,
#    'residue': 576.2021744380418}),
#  ('m1047386',
#   'm1047388',
#   {'label': 'ln5562924-1',
#    'device': 'Line',
#    'resistance': 0.07464800857540001,
#    'reactance': 0.0416580338064,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 17.248469371117405,
#    'residue': 582.7515306288826}),
#  ('m1047386',
#   'l3254211',
#   {'label': 'ln5804795-1',
#    'device': 'Line',
#    'resistance': 0.030740569265800002,
#    'reactance': 0.01708222992268067,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 1.4228738536796564,
#    'residue': 598.5771261463203}),
#  ('m1047379',
#   'l3119793',
#   {'label': 'ln6102834-1',
#    'device': 'Line',
#    'resistance': 0.0194604631515,
#    'reactance': 0.015542794308824999,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 5.127520189607082,
#    'residue': 594.872479810393}),
#  ('m1089115',
#   'l2991911',
#   {'label': 'ln6199521-1',
#    'device': 'Line',
#    'resistance': 0.04015192346998,
#    'reactance': 0.022321384136086,
#    'phases': 1,
#    'maxcap': 600.0,
#    'cap': 0.8631232177934751,
#    'residue': 599.1368767822065}),
#  ...]

# %%
d_obj= DSS(DSSfile) #create a circuit object
d_obj.compile_ckt_dss() #compiling the circuit
d_obj.dssText.command = "Set Maxiterations=200" 
d_obj.dssText.command = "Set maxcontroliter=200"
d_obj.AllowForms=False 
d_obj.dssText.command = "Set controlmode=OFF"

# %%
#Loading Original Loadshape File
LoadShape = []
with open('Loadshape_multload.csv') as csvfile:
    data = list(csv.reader(csvfile))

for x in range(len(data)):
    value = float(data[x][1])
    LoadShape.append(value)

# %%
#Creating Array of Loadshapes
Loadshapes = []
Loadshapes.append(LoadShape)
std = statistics.stdev(LoadShape)
mean = statistics.mean(LoadShape)
length = len(LoadShape)
Nsc_N = 5 
for i in range(Nsc_N):
    noise = np.random.normal(mean,std,length)
    Loadshapes.append(list(noise))

# %%
#Generating Normal Voltage signals
buses=list(G_original.nodes())
edge_dict=list(G_original.edges(data=True)) 
Prelim_Dataset = []
d_obj.dssText.command='redirect LoadShape.dss'
d_obj.dssCircuit.Loadshapes.First
for i in range(len(Loadshapes)):
    d_obj.dssText.command = 'New LoadShape.Lshape'+str(i) + ' npts=24 interval=1 mult='+str(Loadshapes[i])
    d_obj.dssCircuit.Loadshapes.Name = 'Lshape'+str(i)
    d_obj.dssText.command ='Batchedit Load..* Daily=Lshape'+str(i)
    d_obj.dssText.command = "Set mode=Daily"
    d_obj.dssText.command = "Set stepsize=1h"
    d_obj.dssText.command = "Set number=1"
    d_obj.dssCircuit.Loadshapes.Next
    Normal_Data = []
    TimeSeries_Data = []
    dsstime = 0
    for b in buses:
        d_obj.dssCircuit.SetActiveBus(b) #Setting Active Bus
        while dsstime<24: 
            d_obj.dssText.Command= 'Solve'
            dsstime = d_obj.dssSolution.dblHour
            V=np.array(d_obj.dssBus.puVmagAngle)
            ctidx = 2 * np.array(range(0, min(int(V.size/ 2), 3)))
            TimeSeries_Data.append({'Time Step':dsstime, 'Voltage Magnitude':V[ctidx]})
        Normal_Data.append({'Bus Name':b,'Time Series Data':TimeSeries_Data})
    Scenario_Info={'Scaling Factor':'Nil', 'Anomaly_Duration':'Nil', 'targeted_bus': 'Nil', 'Scenario_Info': Normal_Data}
    Prelim_Dataset.append(Scenario_Info)

# %%
len(Prelim_Dataset)
# Out:
# 6

# %%
#Injecting Anomalies
Nsc_A = 5 #Number of Anomalous Scenarios
Ttot = 24 
for a in range (Nsc_A):
    Anomaly_Data = []
    selected_bus = choice(buses) #random sampling of buses with replacement
    lamda = uniform(-1.0,0.5) #Anomaly Scaling Factor
    time_range = randint(0,5) #Duration of Anomaly in hours
    anom_start = randint(0,19) #Anomaly Start Time
    for j in range(len(buses)):
        NewTimeSeries_Data = []
        for m in range(Ttot):
            if Prelim_Dataset[0]['Scenario_Info'][j]['Bus Name'] == selected_bus and Prelim_Dataset[0]['Scenario_Info'][j]['Time Series Data'][m]['Time Step'] > anom_start and Prelim_Dataset[0]['Scenario_Info'][j]['Time Series Data'][m]['Time Step'] <= anom_start+time_range:
                New_VM = (1+lamda)*Prelim_Dataset[0]['Scenario_Info'][j]['Time Series Data'][m]['Voltage Magnitude']
            else:
                New_VM = Prelim_Dataset[0]['Scenario_Info'][j]['Time Series Data'][m]['Voltage Magnitude']      
            NewTimeSeries_Data.append({'Time Step':Prelim_Dataset[0]['Scenario_Info'][j]['Time Series Data'][m]['Time Step'], 'Voltage Magnitude':New_VM})
        Anomaly_Data.append({'Bus Name':Prelim_Dataset[0]['Scenario_Info'][j]['Bus Name'],'Time Series Data': NewTimeSeries_Data})          
    Scenario_Info = {'Scaling Factor':lamda, 'Anomaly_Duration':time_range, 'targeted_bus': selected_bus, 'Scenario_Info': Anomaly_Data}
    Prelim_Dataset.append(Scenario_Info)

# %%
#Restructuring Dataset into multi-dimensional array
Dataset = []
dim_x = len(NewTimeSeries_Data)
dim_y = len(buses)

for d in range (len(Prelim_Dataset)):
    array_3d = np.zeros((dim_x,dim_y,3))
    array_2d = np.zeros((dim_y,3))
    for t in range(len(NewTimeSeries_Data)):
        for s in range(len(buses)): 
            array_2d[s,:] = Prelim_Dataset[d]['Scenario_Info'][s]['Time Series Data'][t]['Voltage Magnitude']
        array_3d[t,:,:]=array_2d
        if d>Nsc_N+1 and np.any(array_3d<0.95) or np.any(array_3d>1.05):
            Anomaly_Check = 'Yes' 
        else:
            Anomaly_Check = 'No'              
    Scenario_Data = {'Anomaly Check':Anomaly_Check,'targeted_bus':Prelim_Dataset[d]['targeted_bus'],'TimeSeries_Voltage':array_3d}
    Dataset.append(Scenario_Data)

# %%
Dataset[0]
# Out:
# {'Anomaly Check': 'No',
#  'targeted_bus': 'Nil',
#  'TimeSeries_Voltage': array([[[0.99999144, 0.99999391, 0.99999384],
#          [0.99999144, 0.99999391, 0.99999384],
#          [0.99999144, 0.99999391, 0.99999384],
#          ...,
#          [0.99999144, 0.99999391, 0.99999384],
#          [0.99999144, 0.99999391, 0.99999384],
#          [0.99999144, 0.99999391, 0.99999384]],
#
#         [[0.99999215, 0.9999944 , 0.99999436],
#          [0.99999215, 0.9999944 , 0.99999436],
#          [0.99999215, 0.9999944 , 0.99999436],
#          ...,
#          [0.99999215, 0.9999944 , 0.99999436],
#          [0.99999215, 0.9999944 , 0.99999436],
#          [0.99999215, 0.9999944 , 0.99999436]],
#
#         [[0.99999239, 0.99999457, 0.99999453],
#          [0.99999239, 0.99999457, 0.99999453],
#          [0.99999239, 0.99999457, 0.99999453],
#          ...,
#          [0.99999239, 0.99999457, 0.99999453],
#          [0.99999239, 0.99999457, 0.99999453],
#          [0.99999239, 0.99999457, 0.99999453]],
#
#         ...,
#
#         [[0.99998859, 0.99999195, 0.99999172],
#          [0.99998859, 0.99999195, 0.99999172],
#          [0.99998859, 0.99999195, 0.99999172],
#          ...,
#          [0.99998859, 0.99999195, 0.99999172],
#          [0.99998859, 0.99999195, 0.99999172],
#          [0.99998859, 0.99999195, 0.99999172]],
#
#         [[0.99998929, 0.99999243, 0.99999225],
#          [0.99998929, 0.99999243, 0.99999225],
#          [0.99998929, 0.99999243, 0.99999225],
#          ...,
#          [0.99998929, 0.99999243, 0.99999225],
#          [0.99998929, 0.99999243, 0.99999225],
#          [0.99998929, 0.99999243, 0.99999225]],
#
#         [[0.99999033, 0.99999314, 0.99999302],
#          [0.99999033, 0.99999314, 0.99999302],
#          [0.99999033, 0.99999314, 0.99999302],
#          ...,
#          [0.99999033, 0.99999314, 0.99999302],
#          [0.99999033, 0.99999314, 0.99999302],
#          [0.99999033, 0.99999314, 0.99999302]]])}

# %%
Prelim_Dataset[300]
# Out:
# {'Scaling Factor': -0.8491016986936497,
#  'Anomaly_Duration': 1,
#  'targeted_bus': '707',
#  'Scenario_Info': [{'Bus Name': 'sourcebus',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '799',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '709',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '775',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '701',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '702',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '705',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '713',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '703',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '727',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '730',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '704',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '714',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '720',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '742',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '712',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '706',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '725',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '707',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.15089644, 0.15089699, 0.15089695])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '724',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '722',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
# ...
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '734',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '737',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '738',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '728',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '729',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]},
#   {'Bus Name': '799r',
#    'Time Series Data': [{'Time Step': 1.0,
#      'Voltage Magnitude': array([0.99999144, 0.99999391, 0.99999384])},
#     {'Time Step': 2.0,
#      'Voltage Magnitude': array([0.99999215, 0.9999944 , 0.99999436])},
#     {'Time Step': 3.0,
#      'Voltage Magnitude': array([0.99999239, 0.99999457, 0.99999453])},
#     {'Time Step': 4.0,
#      'Voltage Magnitude': array([0.99999273, 0.99999481, 0.99999479])},
#     {'Time Step': 5.0,
#      'Voltage Magnitude': array([0.99999277, 0.99999484, 0.99999482])},
#     {'Time Step': 6.0,
#      'Voltage Magnitude': array([0.99999247, 0.99999463, 0.9999946 ])},
#     {'Time Step': 7.0,
#      'Voltage Magnitude': array([0.99999172, 0.9999941 , 0.99999405])},
#     {'Time Step': 8.0,
#      'Voltage Magnitude': array([0.99999045, 0.99999322, 0.99999311])},
#     {'Time Step': 9.0,
#      'Voltage Magnitude': array([0.99998923, 0.99999239, 0.99999221])},
#     {'Time Step': 10.0,
#      'Voltage Magnitude': array([0.99998853, 0.99999191, 0.99999168])},
#     {'Time Step': 11.0,
#      'Voltage Magnitude': array([0.99998763, 0.9999913 , 0.99999101])},
#     {'Time Step': 12.0,
#      'Voltage Magnitude': array([0.99998687, 0.9999908 , 0.99999043])},
#     {'Time Step': 13.0,
#      'Voltage Magnitude': array([0.99998693, 0.99999084, 0.99999048])},
#     {'Time Step': 14.0,
#      'Voltage Magnitude': array([0.999987  , 0.99999089, 0.99999053])},
#     {'Time Step': 15.0,
#      'Voltage Magnitude': array([0.99998686, 0.99999079, 0.99999042])},
#     {'Time Step': 16.0,
#      'Voltage Magnitude': array([0.99998672, 0.99999069, 0.99999032])},
#     {'Time Step': 17.0,
#      'Voltage Magnitude': array([0.99998671, 0.99999068, 0.99999031])},
#     {'Time Step': 18.0,
#      'Voltage Magnitude': array([0.99998736, 0.99999111, 0.9999908 ])},
#     {'Time Step': 19.0,
#      'Voltage Magnitude': array([0.99998769, 0.99999134, 0.99999105])},
#     {'Time Step': 20.0,
#      'Voltage Magnitude': array([0.99998804, 0.99999157, 0.99999131])},
#     {'Time Step': 21.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 22.0,
#      'Voltage Magnitude': array([0.99998859, 0.99999195, 0.99999172])},
#     {'Time Step': 23.0,
#      'Voltage Magnitude': array([0.99998929, 0.99999243, 0.99999225])},
#     {'Time Step': 24.0,
#      'Voltage Magnitude': array([0.99999033, 0.99999314, 0.99999302])}]}]}

# %%
#Dataset Balance Check
j = 0
for i in range(len(Dataset)):
    if Dataset[i]['Anomaly Check'] == 'No':
        j = j+1 
j
# Out:
# 271

# %%
#Shuffling Dataset and Shuffle Check
shuffle(Dataset)
for i in range(len(Dataset)):
    print(Dataset[i]['Anomaly Check'])
# Out:
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# Yes
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# No
# No
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# Yes
# No
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# Yes
# No
# Yes
# No
# No
# Yes
# No
# No
# No
# No
# No
# No
# Yes
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# No
# No
# No
# Yes
# No
# No
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# Yes
# No
# No
# No
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# No
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# No
# No
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# No
# No
# Yes
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# Yes
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# No
# No
# Yes
# Yes
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# Yes
# No
# No
# No
# Yes
# Yes
# Yes
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# Yes
# No
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# Yes
# Yes
# Yes
# No
# No
# No
# No
# Yes
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# No
# Yes
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# Yes
# Yes
# Yes
# No
# No
# No
# No
# No
# Yes
# Yes
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# No
# Yes
# No
# Yes
# No
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# No

# %%
#Loading .pkl file
a = open('fullanomalydataset.pkl', 'wb')
pickle.dump(Dataset,a)
a.close()
