# %%
import os
from DSSCircuit_Interface import * 
import networkx as nx

# %%
FolderName=os.path.dirname(os.path.realpath("__file__"))
d_obj= DSS(r""+ FolderName+ "\Master.dss")  #creating a DSS object instance

# %%
d_obj.compile_ckt_dss() #compiling the circuit
# d_obj.solve_snapshot_dss(1.0) #solving snapshot power flow
d_obj.dssSolution.Solve()

# %%
edges_dictlist=[] #dictionary for edge information
G_original=nx.Graph() #undirected graph
for e in d_obj.get_AllPDElements():
    if ((e.split('.')[0]=='Line') or (e.split('.')[0]=='Transformer')): #only if its a line or transformer used in graph(capacitors avoided)
        branch_obj=Branch(d_obj,e) #creating  a branch object instance with full name
        sr_node=branch_obj.bus_fr.split('.')[0] #extracting source bus of branch
        tar_node=branch_obj.bus_to.split('.')[0] #extracting target bus of branch
        name=e.split('.')[1] #getting the name of the element(label or id)
        el_type=e.split('.')[0] #getting the type of the element (line or transformer)
        numphases=branch_obj.nphases #extracting number of phases of branch
        Inorm=branch_obj.Cap #extracting the base network (normal operation at max load) current flow in branch
        Imax=branch_obj.MaxCap #extracting the maximum permissible current flow in branch
        Iresid=Imax-Inorm #residual current flow in branch
        if el_type== 'Line':
            R,X=d_obj.get_Line_RX(name)
        else:
            R,X=d_obj.get_Transformer_RX(name)
        edges_dictlist.append({"source":sr_node, "target":tar_node, "label":name, "device":el_type, "resistance":R, "reactance":X, "phases":numphases,"maxcap":Imax,"cap":Inorm,"residue":Iresid})
        G_original.add_edge(sr_node, tar_node, label=name, device=el_type, resistance=R, reactance=X, phases=numphases,maxcap=Imax,cap=Inorm,residue=Iresid)

# %%
buses=list(d_obj.get_AllBuses())
loads=d_obj.get_AllLoads()
buses.remove('sourcebus') #sourcebus not in 8500
for b in buses:
    P_sum=0
    Q_sum=0
    for j in range(len(loads)):
        if loads[j]["Bus"]==b:
            P_sum=P_sum+loads[j].get("Pload")
            Q_sum=Q_sum+loads[j].get("Qload")
    G_original.nodes[b]["Device"]="Bus"
    G_original.nodes[b]["TotConnected_ActiveLoad"]=P_sum
    G_original.nodes[b]["TotConnected_ReactiveLoad"]=Q_sum

# %%
G_original.edges(data=True)
# Out:
# EdgeDataView([('_hvmv_sub_lsb', 'hvmv_sub_48332', {'label': 'hvmv_sub_connector', 'device': 'Line', 'resistance': 1e-06, 'reactance': 9.999999999999999e-06, 'phases': 3, 'maxcap': 600.0, 'cap': 528.5517435318036, 'residue': 71.4482564681964}), ('_hvmv_sub_lsb', 'regxfmr_hvmv_sub_lsb', {'label': 'feeder_regc', 'device': 'Transformer', 'resistance': 0.0009425454545454546, 'reactance': 0.18850909090909093, 'phases': 1, 'maxcap': 5729.166666666667, 'cap': 501.91729481344134, 'residue': 5227.249371853226}), ('hvmv_sub_48332', 'd5710794-3_int', {'label': 'ln5710794-3', 'device': 'Line', 'resistance': 0.0030582314252429995, 'reactance': 0.0071560770870680015, 'phases': 3, 'maxcap': 600.0, 'cap': 528.5517435846572, 'residue': 71.44825641534283}), ('m1009763', 'l2673322', {'label': 'ln5502549-1', 'device': 'Line', 'resistance': 0.01796107068886, 'reactance': 0.010023346961759999, 'phases': 1, 'maxcap': 600.0, 'cap': 1.8847523828396167, 'residue': 598.1152476171604}), ('m1009763', 'l2689691', {'label': 'ln5712507-1', 'device': 'Line', 'resistance': 0.128250844722689, 'reactance': 0.04132284233549334, 'phases': 3, 'maxcap': 600.0, 'cap': 0.9004001339058688, 'residue': 599.0995998660941}), ('m1009763', 'e182733', {'label': 'ln6019480-1', 'device': 'Line', 'resistance': 0.12748710588833398, 'reactance': 0.04107676318095999, 'phases': 3, 'maxcap': 600.0, 'cap': 0.0022487021148526894, 'residue': 599.9977512978852}), ('m1009763', 'l2766730', {'label': 'ln6138616-1', 'device': 'Line', 'resistance': 0.013896611697540001, 'reactance': 0.00775513682064, 'phases': 1, 'maxcap': 600.0, 'cap': 0.8090423719266556, 'residue': 599.1909576280733}), ('l2673322', 'l2859391', {'label': 'ln5818176-1', 'device': 'Line', 'resistance': 0.018472436994000002, 'reactance': 0.014753671911366666, 'phases': 1, 'maxcap': 600.0, 'cap': 1.3454342817400609, 'residue': 598.65456571826}), ('l2673322', 'x2673322b', {'label': 't5355358b', 'device': 'Transformer', 'resistance': 1.728, 'reactance': 2.9375999999999998, 'phases': 1, 'maxcap': 2.0833333333333335, 'cap': 5.707274354330486, 'residue': -3.6239410209971523}), ('m1069148', 'l2673309', {'label': 'ln6259988-1', 'device': 'Line', 'resistance': 0.05986020813759999, 'reactance': 0.0334055606016, 'phases': 1, 'maxcap': 600.0, 'cap': 1.4473346082962506, 'residue': 598.5526653917037}), ('m1069148', 'l2785518', {'label': 'ln5865231-1', 'device': 'Line', 'resistance': 0.01536354519648, 'reactance': 0.00857377306368, 'phases': 1, 'maxcap': 600.0, 'cap': 1.4437216980554035, 'residue': 598.5562783019446}), ('m1069148', 'm1069149', {'label': 'ln5532742-1', 'device': 'Line', 'resistance': 0.03455834125666, 'reactance': 0.01928561224656, 'phases': 1, 'maxcap': 600.0, 'cap': 2.890776296139992, 'residue': 597.10922370386}), ('l2673309', 'x2673309c', {'label': 't5138472c', 'device': 'Transformer', 'resistance': 0.6912, 'reactance': 1.17504, 'phases': 1, 'maxcap': 5.208333333333333, 'cap': 15.331454754618903, 'residue': -10.123121421285571}), ('m1069588', 'l2804270', {'label': 'ln6077796-1', 'device': 'Line', 'resistance': 0.00638957647302, 'reactance': 0.00356576414832, 'phases': 1, 'maxcap': 600.0, 'cap': 1.6779732408170243, 'residue': 598.322026759183}), ('m1069588', 'm1069590', {'label': 'ln5803283-1', 'device': 'Line', 'resistance': 0.0616491692648, 'reactance': 0.034403907436799996, 'phases': 1, 'maxcap': 600.0, 'cap': 25.853893502763313, 'residue': 574.1461064972367}), ('m1069588', 'l3082983', {'label': 'ln6228303-1', 'device': 'Line', 'resistance': 0.01290191054802, 'reactance': 0.007200034348319999, 'phases': 1, 'maxcap': 600.0, 'cap': 27.531763208071276, 'residue': 572.4682367919287}), ('l2804270', 'l3104145', {'label': 'ln5593244-1', 'device': 'Line', 'resistance': 0.049629456765720004, 'reactance': 0.027696192131519998, 'phases': 1, 'maxcap': 600.0, 'cap': 0.8388213225078852, 'residue': 599.1611786774921}), ('l2804270', 'x2804270b', {'label': 't5339013b', 'device': 'Transformer', 'resistance': 1.1520000000000001, 'reactance': ...

# %%
G_original.nodes(data=True)
# Out:
# NodeDataView({'_hvmv_sub_lsb': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'hvmv_sub_48332': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1009763': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l2673322': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1069148': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l2673309': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1069588': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l2804270': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm3036164': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l2935553': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1209749': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l2748840': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1108264': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1108263': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l3085398': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1026891': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l3216367': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1069468': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1142800': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1142799': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1047592': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'p827512': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1047339': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'p895104': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1026915': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1026920': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'n1138596': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l3254207': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1069464': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'p873787': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'n1144665': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1047515': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'n1137002': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1047707': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l2729406': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l2897768': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l3649301': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l3649302': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l2970842': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1089113': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'm1047312': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'p893163': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected_ReactiveLoad': 0}, 'l2822871': {'Device': 'Bus', 'TotConnected_ActiveLoad': 0, 'TotConnected ...

# %%
nx.readwrite.gml.write_gml(G_original,"8500busEx.gml") #Graph undirected with edge features and node features which are constant
