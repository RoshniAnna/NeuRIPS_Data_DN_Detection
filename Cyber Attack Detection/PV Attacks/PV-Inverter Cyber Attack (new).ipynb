# %%
import os
import math
import csv
import pickle
import statistics
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from random import sample,choices,choice,uniform, randint,shuffle
from DSSCircuit_Interface import *

# %%
FolderName=os.path.dirname(os.path.realpath("__file__"))
G_original = nx.read_gml(""+ FolderName+ r"\34busEx.gml")
nodes=list(G_original.nodes())
edges=list(G_original.edges())

# %%
DSSfile=r""+ FolderName+ "\ieee34Mod2.dss" 
d_obj= DSS(DSSfile) #create a circuit object
d_obj.compile_ckt_dss() #compiling the circuit
d_obj.dssText.command = "Set Maxiterations=200" 
d_obj.dssText.command = "Set maxcontroliter=200"
d_obj.AllowForms=False 
# d_obj.dssText.command = "Set controlmode=OFF"

# %%
#Creating Array of Loadshapes
LoadShape = []
input_file = 'LoadShape1.xlsx'
sheet_name = 'LoadShape1'  # Change to the sheet you want to split
df = pd.read_excel(input_file, sheet_name=sheet_name)

# Number of parts to split the file into
num_files = 365  

# Calculate the number of rows per file
rows_per_file = math.ceil(len(df) / num_files)

# Split and save to new Excel files
for i in range(num_files):
    start_row = i * rows_per_file
    end_row = min((i + 1) * rows_per_file, len(df))
    
    # Create a new DataFrame for each chunk
    chunk_df = df[start_row:end_row]
    
    # Convert dataframe to list
    loadshape = []
    value = chunk_df.values.tolist()
    for x in range(len(value)):
        data = float(value[x][0])
        loadshape.append(data)    
    LoadShape.append(loadshape)

# %%
#Loading PV information
PVs = [{'no':1, 'bus':'890', 'numphase':3, 'phaseconn':'.1.2.3', 'size':146, 'kV':4.16, 'KVA':146},
        {'no':2, 'bus':'806', 'numphase':3, 'phaseconn':'.1.2.3', 'size':144, 'kV':24.9, 'KVA':144},
        {'no':3, 'bus':'816', 'numphase':3, 'phaseconn':'.1.2.3', 'size':200, 'kV':24.9, 'KVA':200}]

#Obtaining list of buses connected to PVSystems
PVbuses = []
for pv in range(len(PVs)):
    PVbuses.append(PVs[pv]['bus'])

# %%
temp =[25, 25, 25, 25, 25, 25, 25, 25, 40, 50, 60, 65, 65, 65, 57, 50, 35, 30,  25, 25, 25, 25, 25, 25]
Time = range(0,24)
plt.plot(Time, temp, "-o")

# %%
#Adding PVs to DSS Circuit
d_obj.dssText.command='redirect PVSystem.dss'
# d_obj.dssText.command = f"New LoadShape.MyIrrad0 npts=288 minterval=5 mult={Irradiance[0]} Action=Normalize"
d_obj.dssText.command = f"New Tshape.MyTemp npts=24 interval=1 temp={temp}"
for pv in range(len(PVs)):
        d_obj.dssText.command=f"New PVSystem.PV{PVs[pv]['no']} bus1={PVs[pv]['bus'] + PVs[pv]['phaseconn']} phases={str(PVs[pv]['numphase'])} kv={str(PVs[pv]['kV'])} kVA={str(PVs[pv]['KVA'])} pf=0.8 Pmpp={str(PVs[pv]['size'])} %cutin=0.1 %cutout=0.1 effcurve=Myeff P-TCurve=MyPvsT Daily=PVLoadShape2 TDaily=MyTemp"

# %%
#Generating Normal Scenarios
buses=list(G_original.nodes())
edge_dict=list(G_original.edges(data=True)) 
Prelim_Dataset = []
Nsc_N = 1
count = 0
for i in range(Nsc_N):
    d_obj.dssText.command = f"New LoadShape.Lshape{i} npts=24 interval=1 mult={LoadShape[i]}"
    d_obj.dssText.command = f"Batchedit Load..* Daily=Lshape{i}"
    d_obj.dssText.command = "Set mode=Daily"
    d_obj.dssText.command = "Set stepsize=5m"
    d_obj.dssText.command = "Set number=1"
#     d_obj.dssText.command = f"New LoadShape.MyIrrad{i} npts=288 minterval=5 mult={Irradiance[i]} Action=Normalize"
    Normal_Data = []
    TimeSeries_Data = []
    nbua = randint(1,3)
    dsstime = 0
    while dsstime<24: 
        d_obj.dssText.Command = 'Solve'
        dsstime = d_obj.dssSolution.dblHour
        Branchflow_Data = []
        Bus_Data = []
        for pv in range(len(PVs)):
            d_obj.dssText.command=f"Edit PVSystem.PV{PVs[pv]['no']} bus1={PVs[pv]['bus'] + PVs[pv]['phaseconn']} phases={str(PVs[pv]['numphase'])} kv={str(PVs[pv]['kV'])} kVA={str(PVs[pv]['KVA'])} pf=0.8 Pmpp={str(PVs[pv]['size'])} %cutin=0.1 %cutout=0.1 effcurve=Myeff P-TCurve=MyPvsT Daily=PVLoadShape2 TDaily=MyTemp"
        for b in buses:
            d_obj.dssCircuit.SetActiveBus(b) #Setting Active Bus
            node_num=np.array(d_obj.dssBus.Nodes)
            bus_size = node_num.size
            V=np.array(d_obj.dssBus.puVmagAngle)
            ctidx = 2 * np.array(range(0, min(int(V.size/ 2), 3))) 
            if b in PVbuses:
                j= d_obj.dssCircuit.PVSystems.First
                while j>0:
                    elemName = d_obj.dssCircuit.ActiveCktElement.Name
                    busconnectn = d_obj.dssCircuit.ActiveCktElement.BusNames[0].split('.')[0]
                    if b == busconnectn:
                        S=np.array(d_obj.dssCircuit.ActiveCktElement.Powers)
                        P_Gen = S[ctidx]
                        break
                    j=d_obj.dssCircuit.PVSystems.Next
            else:
                P_Gen=np.empty(bus_size) * np.nan
            Bus_Data.append({'Bus Name':b, 'Voltage Magnitude':V[ctidx], 'Power Generated':P_Gen})
        for e in G_original.edges(data=True):
            name = e[2]['device'] + '.' +e[2]['label']
            d_obj.dssCircuit.SetActiveElement(name) #Setting Active Edge Element
            c=np.array(d_obj.dssCktElement.CurrentsMagAng)
            ctidx = 2 * np.array(range(0, min(int(c.size/ 4), 3)))
            I_mag = c[ctidx]
            I_avg=np.average(I_mag)
            Branchflow_Data.append({'Branch Name':name,'BranchFlow':I_avg}) 
        TimeSeries_Data.append({'Time Step':dsstime, 'Bus_Info': Bus_Data, 'Branchflow':Branchflow_Data})
    count = count + 1
    print(count)
    Scenario_Info={'Scenario_Number':count, 'Anomalous': 'No', 'Attack_Type':'Nil', 'Affected_PV':'Nil', 'TimeSeries_Data':TimeSeries_Data}
    Prelim_Dataset.append(Scenario_Info)
# Out:
# 1

# %%
len(Bus_Data)
# Out:
# 56

# %%
Prelim_Dataset[0]
# Out:
# {'Scenario_Number': 1,
#  'Anomalous': 'No',
#  'Attack_Type': 'Nil',
#  'Affected_PV': 'Nil',
#  'TimeSeries_Data': [{'Time Step': 0.08333333333333333,
#    'Bus_Info': [{'Bus Name': 'sourcebus',
#      'Voltage Magnitude': array([1.04999995, 1.05000046, 1.05000045]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '800',
#      'Voltage Magnitude': array([1.04999976, 1.04999984, 1.05000041]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '802',
#      'Voltage Magnitude': array([1.04900061, 1.04944326, 1.04946984]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid806',
#      'Voltage Magnitude': array([1.04866548, 1.04925665, 1.04929183]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '806',
#      'Voltage Magnitude': array([1.0483263 , 1.0490955 , 1.04912873]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '808',
#      'Voltage Magnitude': array([1.0356394 , 1.04308613, 1.04300151]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid810',
#      'Voltage Magnitude': array([1.04300677]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '810',
#      'Voltage Magnitude': array([1.04300776]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '812',
#      'Voltage Magnitude': array([1.02082734, 1.03663163, 1.03559209]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814',
#      'Voltage Magnitude': array([1.00900029, 1.0314959 , 1.02962148]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814r',
#      'Voltage Magnitude': array([1.02792173, 1.02505398, 1.02962747]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '850',
#      'Voltage Magnitude': array([1.02791586, 1.02505062, 1.02962396]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '816',
#      'Voltage Magnitude': array([1.02773376, 1.02494622, 1.02951495]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '818',
#      'Voltage Magnitude': array([1.02724602]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid824',
#      'Voltage Magnitude': array([1.02580301, 1.02291767, 1.02779629]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '824',
#      'Voltage Magnitude': array([1.02386996, 1.02090236, 1.02609128]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid820',
#      'Voltage Magnitude': array([1.02030758]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '820',
#      'Voltage Magnitude': array([1.01471703]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid822',
#      'Voltage Magnitude': array([1.01309746]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '822',
#      'Voltage Magnitude': array([1.01310284]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid826',
#      'Voltage Magnitude': array([1.0207957]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '826',
#      'Voltage Magnitude': array([1.02079597]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid828',
#      'Voltage Magnitude': array([1.02371239, 1.02075843, 1.02594597]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '828',
#      'Voltage Magnitude': array([1.02355427, 1.0206146 , 1.02580282]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid830',
#      'Voltage Magnitude': array([1.01970119, 1.01711641, 1.02231854]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '830',
#      'Voltage Magnitude': array([1.01592649, 1.01359585, 1.01883864]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '854',
#      'Voltage Magnitude': array([1.01574411, 1.01342183, 1.01867085]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '832',
#      'Voltage Magnitude': array([1.04044514, 1.04491331, 1.04449316]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid858',
#      'Voltage Magnitude': array([1.04001257, 1.04449953, 1.0441223 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '858',
#      'Voltage Magnitude': array([1.03959649, 1.04409711, 1.04376224]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid834',
#      'Voltage Magnitude': array([1.03910686, 1.04361629, 1.04333425]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '834',
#      'Voltage Magnitude': array([1.03864231, 1.0431626 , 1.04294861]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '842',
#      'Voltage Magnitude': array([1.0386402 , 1.04315274, 1.04294966]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '836',
#      'Voltage Magnitude': array([1.03829398, 1.04273601, 1.04267024]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid840',
#      'Voltage Magnitude': array([1.03828509, 1.04272277, 1.0426604 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '840',
#      'Voltage Magnitude': array([1.03828049, 1.04271844, 1.04265575]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid844',
#      'Voltage Magnitude': array([1.03863508, 1.04312894, 1.04295217]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '844',
#      'Voltage Magnitude': array([1.03863787, 1.04310297, 1.04295496]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid846',
#      'Voltage Magnitude': array([1.03880981, 1.04317356, 1.04311932]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '846',
#      'Voltage Magnitude': array([1.03897384, 1.0433022 , 1.04331735]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid848',
#      'Voltage Magnitude': array([1.03899768, 1.0433209 , 1.04334615]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '848',
#      'Voltage Magnitude': array([1.03902205, 1.0433472 , 1.04337318]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid856',
#      'Voltage Magnitude': array([1.01338675]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '856',
#      'Voltage Magnitude': array([1.01340227]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '852',
#      'Voltage Magnitude': array([1.0028376 , 1.0011125 , 1.00673753]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '852r',
#      'Voltage Magnitude': array([1.04044853, 1.04491651, 1.04449629]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '888',
#      'Voltage Magnitude': array([1.02085054, 1.02532911, 1.02493756]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid864',
#      'Voltage Magnitude': array([1.03959395]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '864',
#      'Voltage Magnitude': array([1.03959403]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid860',
#      'Voltage Magnitude': array([1.03848867, 1.04304092, 1.04281103]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '860',
#      'Voltage Magnitude': array([1.03840515, 1.04293486, 1.04274566]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid836',
#      'Voltage Magnitude': array([1.03832507, 1.04282292, 1.04268986]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '862',
#      'Voltage Magnitude': array([1.03829322, 1.04272643, 1.04267249]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid838',
#      'Voltage Magnitude': array([1.04264251]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '838',
#      'Voltage Magnitude': array([1.04264319]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '890',
#      'Voltage Magnitude': array([0.97568619, 0.98452032, 0.97990619]),
#      'Power Generated': array([ 0., -0.,  0.])}],
#    'Branchflow': [{'Branch Name': 'Transformer.subxf',
#      'BranchFlow': 8.981914887561196},
#     {'Branch Name': 'Line.l1', 'BranchFlow': 24.95072957024168},
#     {'Branch Name': 'Line.l2a', 'BranchFlow': 24.937498415813238},
#     {'Branch Name': 'Line.l2b', 'BranchFlow': 24.440156474105546},
#     {'Branch Name': 'Line.l3', 'BranchFlow': 24.435416486233},
#     {'Branch Name': 'Line.l4a', 'BranchFlow': 0.6514978381963513},
#     {'Branch Name': 'Line.l5', 'BranchFlow': 24.09751485336476},
#     {'Branch Name': 'Line.l4b', 'BranchFlow': 0.03481902459122276},
#     {'Branch Name': 'Line.l6', 'BranchFlow': 23.90169660541491},
#     {'Branch Name': 'Transformer.reg1c', 'BranchFlow': 22.362017279609923},
#     {'Branch Name': 'Line.l7', 'BranchFlow': 23.641039405266664},
#     {'Branch Name': 'Line.l24', 'BranchFlow': 23.640992237259187},
#     {'Branch Name': 'Line.l8', 'BranchFlow': 6.866959520235364},
#     {'Branch Name': 'Line.l9a', 'BranchFlow': 21.781607539218687},
#     {'Branch Name': 'Line.l10a', 'BranchFlow': 6.874473490855867},
#     {'Branch Name': 'Line.l9b', 'BranchFlow': 21.703432032233547},
#     {'Branch Name': 'Line.l12a', 'BranchFlow': 1.683528556303885},
#     {'Branch Name': 'Line.l13a', 'BranchFlow': 21.282389908966312},
#     {'Branch Name': 'Line.l10b', 'BranchFlow': 5.513340812737845},
#     {'Branch Name': 'Line.l11a', 'BranchFlow': 5.630925703558948},
#     {'Branch Name': 'Line.l11b', 'BranchFlow': 0.08006468065997004},
#     {'Branch Name': 'Line.l12b', 'BranchFlow': 0.017790304533656234},
#     {'Branch Name': 'Line.l13b', 'BranchFlow': 21.244339641446544},
#     {'Branch Name': 'Line.l14a', 'BranchFlow': 21.24182524177625},
#     {'Branch Name': 'Line.l14b', 'BranchFlow': 21.110982947790703},
#     {'Branch Name': 'Line.l15', 'BranchFlow': 20.605977344798216},
#     {'Branch Name': 'Line.l26a', 'BranchFlow': 0.2475765305961529},
#     {'Branch Name': 'Line.l27', 'BranchFlow': 20.53167248558316},
#     {'Branch Name': 'Line.l16a', 'BranchFlow': 16.134834875013055},
#     {'Branch Name': 'Line.l25', 'BranchFlow': 19.534798355922927},
#     {'Branch Name': 'Transformer.xfm1', 'BranchFlow': 6.3693989400562},
#     {'Branch Name': 'Line.l16b', 'BranchFlow': 16.013732487463834},
#     {'Branch Name': 'Line.l29a', 'BranchFlow': 15.972175701412548},
#     {'Branch Name': 'Line.l28a', 'BranchFlow': 0.0750816065376573},
#     {'Branch Name': 'Line.l29b', 'BranchFlow': 15.780786950228938},
#     {'Branch Name': 'Line.l18', 'BranchFlow': 14.787560984164037},
#     {'Branch Name': 'Line.l17a', 'BranchFlow': 5.589789414439214},
#     {'Branch Name': 'Line.l21a', 'BranchFlow': 14.78342224969542},
#     {'Branch Name': 'Line.l19a', 'BranchFlow': 1.011159403387211},
#     {'Branch Name': 'Line.l30b', 'BranchFlow': 1.3699371602050416},
#     {'Branch Name': 'Line.l20', 'BranchFlow': 0.3743735790549923},
#     {'Branch Name': 'Line.l19b', 'BranchFlow': 0.4288107221848005},
#     {'Branch Name': 'Line.l21b', 'BranchFlow': 14.782241301740186},
#     {'Branch Name': 'Line.l22a', 'BranchFlow': 10.095325695975554},
#     {'Branch Name': 'Line.l22b', 'BranchFlow': 10.252037016787419},
#     {'Branch Name': 'Line.l23a', 'BranchFlow': 10.221617261965536},
#     {'Branch Name': 'Line.l23b', 'BranchFlow': 10.31817829162168},
#     {'Branch Name': 'Line.l26b', 'BranchFlow': 0.1359862980785471},
#     {'Branch Name': 'Transformer.reg2c', 'BranchFlow': 21.234785852253655},
#     {'Branch Name': 'Line.l32', 'BranchFlow': 38.12449432489785},
#     {'Branch Name': 'Line.l28b', 'BranchFlow': 0.009686806846911887},
#     {'Branch Name': 'Line.l17b', 'BranchFlow': 3.373929244970272},
#     {'Branch Name': 'Line.l30a', 'BranchFlow': 2.4622164693075637},
#     {'Branch Name': 'Line.l31a', 'BranchFlow': 1.115119801096766},
#     {'Branch Name': 'Line.l31b', 'BranchFlow': 0.030101757658898814}]},
#   {'Time Step': 0.16666666666666666,
#    'Bus_Info': [{'Bus Name': 'sourcebus',
#      'Voltage Magnitude': array([1.04999995, 1.05000046, 1.05000045]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '800',
#      'Voltage Magnitude': array([1.04999976, 1.04999984, 1.05000041]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '802',
#      'Voltage Magnitude': array([1.04900059, 1.04944325, 1.04946983]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid806',
#      'Voltage Magnitude': array([1.04866545, 1.04925664, 1.04929182]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '806',
#      'Voltage Magnitude': array([1.04832626, 1.04909549, 1.04912872]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '808',
#      'Voltage Magnitude': array([1.03563906, 1.04308603, 1.04300137]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid810',
#      'Voltage Magnitude': array([1.04300667]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '810',
#      'Voltage Magnitude': array([1.04300766]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '812',
#      'Voltage Magnitude': array([1.02082665, 1.03663144, 1.0355918 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814',
#      'Voltage Magnitude': array([1.00899931, 1.03149563, 1.02962108]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814r',
#      'Voltage Magnitude': array([1.02792074, 1.02505372, 1.02962707]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '850',
#      'Voltage Magnitude': array([1.02791486, 1.02505035, 1.02962355]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '816',
#      'Voltage Magnitude': array([1.02773276, 1.02494596, 1.02951455]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '818',
#      'Voltage Magnitude': array([1.02724501]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid824',
#      'Voltage Magnitude': array([1.02580197, 1.02291738, 1.02779586]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '824',
#      'Voltage Magnitude': array([1.02386888, 1.02090204, 1.02609082]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid820',
#      'Voltage Magnitude': array([1.02030642]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '820',
#      'Voltage Magnitude': array([1.01471573]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid822',
#      'Voltage Magnitude': array([1.01309611]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '822',
#      'Voltage Magnitude': array([1.01310149]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid826',
#      'Voltage Magnitude': array([1.02079539]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '826',
#      'Voltage Magnitude': array([1.02079565]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid828',
#      'Voltage Magnitude': array([1.02371131, 1.02075811, 1.02594551]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '828',
#      'Voltage Magnitude': array([1.02355319, 1.02061428, 1.02580235]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid830',
#      'Voltage Magnitude': array([1.01970003, 1.01711604, 1.02231802]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '830',
#      'Voltage Magnitude': array([1.01592525, 1.01359543, 1.01883808]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '854',
#      'Voltage Magnitude': array([1.01574287, 1.0134214 , 1.01867028]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '832',
#      'Voltage Magnitude': array([1.04044358, 1.04491268, 1.04449237]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid858',
#      'Voltage Magnitude': array([1.040011  , 1.04449889, 1.04412151]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '858',
#      'Voltage Magnitude': array([1.0395949 , 1.04409647, 1.04376145]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid834',
#      'Voltage Magnitude': array([1.03910527, 1.04361565, 1.04333345]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '834',
#      'Voltage Magnitude': array([1.03864071, 1.04316195, 1.0429478 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '842',
#      'Voltage Magnitude': array([1.0386386 , 1.04315208, 1.04294885]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '836',
#      'Voltage Magnitude': array([1.03829238, 1.04273535, 1.04266943]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid840',
#      'Voltage Magnitude': array([1.03828348, 1.04272211, 1.04265959]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '840',
#      'Voltage Magnitude': array([1.03827888, 1.04271779, 1.04265494]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid844',
#      'Voltage Magnitude': array([1.03863348, 1.04312829, 1.04295136]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '844',
#      'Voltage Magnitude': array([1.03863627, 1.04310231, 1.04295415]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid846',
#      'Voltage Magnitude': array([1.0388082 , 1.04317291, 1.04311851]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '846',
#      'Voltage Magnitude': array([1.03897223, 1.04330154, 1.04331654]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid848',
#      'Voltage Magnitude': array([1.03899607, 1.04332024, 1.04334534]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '848',
#      'Voltage Magnitude': array([1.03902044, 1.04334654, 1.04337237]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid856',
#      'Voltage Magnitude': array([1.01338633]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '856',
#      'Voltage Magnitude': array([1.01340185]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '852',
#      'Voltage Magnitude': array([1.00283609, 1.00111189, 1.00673677]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '852r',
#      'Voltage Magnitude': array([1.04044696, 1.04491587, 1.0444955 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '888',
#      'Voltage Magnitude': array([1.02084851, 1.02532806, 1.02493643]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid864',
#      'Voltage Magnitude': array([1.03959237]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '864',
#      'Voltage Magnitude': array([1.03959245]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid860',
#      'Voltage Magnitude': array([1.03848707, 1.04304026, 1.04281022]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '860',
#      'Voltage Magnitude': array([1.03840354, 1.04293421, 1.04274485]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid836',
#      'Voltage Magnitude': array([1.03832346, 1.04282226, 1.04268905]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '862',
#      'Voltage Magnitude': array([1.03829161, 1.04272578, 1.04267168]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid838',
#      'Voltage Magnitude': array([1.04264185]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '838',
#      'Voltage Magnitude': array([1.04264253]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '890',
#      'Voltage Magnitude': array([0.97568311, 0.98451849, 0.97990423]),
#      'Power Generated': array([ 0., -0.,  0.])}],
#    'Branchflow': [{'Branch Name': 'Transformer.subxf',
#      'BranchFlow': 8.981978148134367},
#     {'Branch Name': 'Line.l1', 'BranchFlow': 24.950907743453076},
#     {'Branch Name': 'Line.l2a', 'BranchFlow': 24.937676995210058},
#     {'Branch Name': 'Line.l2b', 'BranchFlow': 24.44033075145683},
#     {'Branch Name': 'Line.l3', 'BranchFlow': 24.435590902240815},
#     {'Branch Name': 'Line.l4a', 'BranchFlow': 0.6514982992455397},
#     {'Branch Name': 'Line.l5', 'BranchFlow': 24.097693113564986},
#     {'Branch Name': 'Line.l4b', 'BranchFlow': 0.03481902144816444},
#     {'Branch Name': 'Line.l6', 'BranchFlow': 23.901880799590895},
#     {'Branch Name': 'Transformer.reg1c', 'BranchFlow': 22.36214967163735},
#     {'Branch Name': 'Line.l7', 'BranchFlow': 23.641226522252833},
#     {'Branch Name': 'Line.l24', 'BranchFlow': 23.641179355105717},
#     {'Branch Name': 'Line.l8', 'BranchFlow': 6.867104551762611},
#     {'Branch Name': 'Line.l9a', 'BranchFlow': 21.781742373931635},
#     {'Branch Name': 'Line.l10a', 'BranchFlow': 6.874618556162005},
#     {'Branch Name': 'Line.l9b', 'BranchFlow': 21.703567147383307},
#     {'Branch Name': 'Line.l12a', 'BranchFlow': 1.6835324443161783},
#     {'Branch Name': 'Line.l13a', 'BranchFlow': 21.28252137314342},
#     {'Branch Name': 'Line.l10b', 'BranchFlow': 5.513487762599499},
#     {'Branch Name': 'Line.l11a', 'BranchFlow': 5.631072850006383},
#     {'Branch Name': 'Line.l11b', 'BranchFlow': 0.08006457418708084},
#     {'Branch Name': 'Line.l12b', 'BranchFlow': 0.017790299023348208},
#     {'Branch Name': 'Line.l13b', 'BranchFlow': 21.24447056140163},
#     {'Branch Name': 'Line.l14a', 'BranchFlow': 21.241956225674958},
#     {'Branch Name': 'Line.l14b', 'BranchFlow': 21.11111304144701},
#     {'Branch Name': 'Line.l15', 'BranchFlow': 20.60610471212137},
#     {'Branch Name': 'Line.l26a', 'BranchFlow': 0.2475766448990774},
#     {'Branch Name': 'Line.l27', 'BranchFlow': 20.531800097416607},
#     {'Branch Name': 'Line.l16a', 'BranchFlow': 16.134851921801722},
#     {'Branch Name': 'Line.l25', 'BranchFlow': 19.534926674446712},
#     {'Branch Name': 'Transformer.xfm1', 'BranchFlow': 6.36952912067614},
#     {'Branch Name': 'Line.l16b', 'BranchFlow': 16.013748563244164},
#     {'Branch Name': 'Line.l29a', 'BranchFlow': 15.972191465514237},
#     {'Branch Name': 'Line.l28a', 'BranchFlow': 0.07508427918775112},
#     {'Branch Name': 'Line.l29b', 'BranchFlow': 15.780797665763885},
#     {'Branch Name': 'Line.l18', 'BranchFlow': 14.787543203702013},
#     {'Branch Name': 'Line.l17a', 'BranchFlow': 5.589842740139859},
#     {'Branch Name': 'Line.l21a', 'BranchFlow': 14.783404478663408},
#     {'Branch Name': 'Line.l19a', 'BranchFlow': 1.0111680260874023},
#     {'Branch Name': 'Line.l30b', 'BranchFlow': 1.3699496464759335},
#     {'Branch Name': 'Line.l20', 'BranchFlow': 0.3743774541169122},
#     {'Branch Name': 'Line.l19b', 'BranchFlow': 0.4288147813207687},
#     {'Branch Name': 'Line.l21b', 'BranchFlow': 14.782223609797706},
#     {'Branch Name': 'Line.l22a', 'BranchFlow': 10.095303041790318},
#     {'Branch Name': 'Line.l22b', 'BranchFlow': 10.25201528755678},
#     {'Branch Name': 'Line.l23a', 'BranchFlow': 10.221595568638858},
#     {'Branch Name': 'Line.l23b', 'BranchFlow': 10.3181571366064},
#     {'Branch Name': 'Line.l26b', 'BranchFlow': 0.13598624114071658},
#     {'Branch Name': 'Transformer.reg2c', 'BranchFlow': 21.234920530080608},
#     {'Branch Name': 'Line.l32', 'BranchFlow': 38.12527353102435},
#     {'Branch Name': 'Line.l28b', 'BranchFlow': 0.009686792102396905},
#     {'Branch Name': 'Line.l17b', 'BranchFlow': 3.373984883191216},
#     {'Branch Name': 'Line.l30a', 'BranchFlow': 2.462253986564205},
#     {'Branch Name': 'Line.l31a', 'BranchFlow': 1.1151314391735874},
#     {'Branch Name': 'Line.l31b', 'BranchFlow': 0.03010173865095509}]},
#   {'Time Step': 0.25,
#    'Bus_Info': [{'Bus Name': 'sourcebus',
#      'Voltage Magnitude': array([1.04999995, 1.05000046, 1.05000045]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '800',
#      'Voltage Magnitude': array([1.04999976, 1.04999984, 1.05000041]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '802',
#      'Voltage Magnitude': array([1.04900059, 1.04944325, 1.04946983]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid806',
#      'Voltage Magnitude': array([1.04866545, 1.04925664, 1.04929182]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '806',
#      'Voltage Magnitude': array([1.04832626, 1.04909549, 1.04912872]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '808',
#      'Voltage Magnitude': array([1.03563905, 1.04308603, 1.04300137]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid810',
#      'Voltage Magnitude': array([1.04300667]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '810',
#      'Voltage Magnitude': array([1.04300766]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '812',
#      'Voltage Magnitude': array([1.02082664, 1.03663143, 1.0355918 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814',
#      'Voltage Magnitude': array([1.0089993 , 1.03149563, 1.02962107]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814r',
#      'Voltage Magnitude': array([1.02792073, 1.02505372, 1.02962706]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '850',
#      'Voltage Magnitude': array([1.02791485, 1.02505035, 1.02962355]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '816',
#      'Voltage Magnitude': array([1.02773276, 1.02494596, 1.02951454]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '818',
#      'Voltage Magnitude': array([1.027245]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid824',
#      'Voltage Magnitude': array([1.02580196, 1.02291737, 1.02779585]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '824',
#      'Voltage Magnitude': array([1.02386887, 1.02090204, 1.02609082]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid820',
#      'Voltage Magnitude': array([1.02030641]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '820',
#      'Voltage Magnitude': array([1.01471571]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid822',
#      'Voltage Magnitude': array([1.0130961]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '822',
#      'Voltage Magnitude': array([1.01310148]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid826',
#      'Voltage Magnitude': array([1.02079538]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '826',
#      'Voltage Magnitude': array([1.02079565]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid828',
#      'Voltage Magnitude': array([1.0237113 , 1.02075811, 1.02594551]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '828',
#      'Voltage Magnitude': array([1.02355318, 1.02061428, 1.02580235]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid830',
#      'Voltage Magnitude': array([1.01970002, 1.01711603, 1.02231802]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '830',
#      'Voltage Magnitude': array([1.01592524, 1.01359542, 1.01883807]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '854',
#      'Voltage Magnitude': array([1.01574286, 1.0134214 , 1.01867027]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '832',
#      'Voltage Magnitude': array([1.04044356, 1.04491267, 1.04449236]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid858',
#      'Voltage Magnitude': array([1.04001099, 1.04449888, 1.0441215 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '858',
#      'Voltage Magnitude': array([1.03959489, 1.04409646, 1.04376144]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid834',
#      'Voltage Magnitude': array([1.03910525, 1.04361564, 1.04333344]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '834',
#      'Voltage Magnitude': array([1.03864069, 1.04316194, 1.04294779]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '842',
#      'Voltage Magnitude': array([1.03863858, 1.04315207, 1.04294884]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '836',
#      'Voltage Magnitude': array([1.03829236, 1.04273534, 1.04266942]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid840',
#      'Voltage Magnitude': array([1.03828346, 1.0427221 , 1.04265958]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '840',
#      'Voltage Magnitude': array([1.03827887, 1.04271778, 1.04265493]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid844',
#      'Voltage Magnitude': array([1.03863346, 1.04312828, 1.04295135]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '844',
#      'Voltage Magnitude': array([1.03863625, 1.0431023 , 1.04295415]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid846',
#      'Voltage Magnitude': array([1.03880819, 1.0431729 , 1.0431185 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '846',
#      'Voltage Magnitude': array([1.03897222, 1.04330153, 1.04331653]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid848',
#      'Voltage Magnitude': array([1.03899606, 1.04332023, 1.04334533]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '848',
#      'Voltage Magnitude': array([1.03902043, 1.04334653, 1.04337236]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid856',
#      'Voltage Magnitude': array([1.01338632]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '856',
#      'Voltage Magnitude': array([1.01340184]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '852',
#      'Voltage Magnitude': array([1.00283607, 1.00111188, 1.00673676]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '852r',
#      'Voltage Magnitude': array([1.04044695, 1.04491587, 1.04449549]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '888',
#      'Voltage Magnitude': array([1.0208485 , 1.02532805, 1.02493642]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid864',
#      'Voltage Magnitude': array([1.03959236]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '864',
#      'Voltage Magnitude': array([1.03959243]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid860',
#      'Voltage Magnitude': array([1.03848706, 1.04304026, 1.04281021]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '860',
#      'Voltage Magnitude': array([1.03840353, 1.0429342 , 1.04274484]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid836',
#      'Voltage Magnitude': array([1.03832345, 1.04282226, 1.04268904]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '862',
#      'Voltage Magnitude': array([1.0382916 , 1.04272577, 1.04267168]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid838',
#      'Voltage Magnitude': array([1.04264184]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '838',
#      'Voltage Magnitude': array([1.04264253]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '890',
#      'Voltage Magnitude': array([0.97568308, 0.98451847, 0.97990421]),
#      'Power Generated': array([ 0., -0.,  0.])}],
#    'Branchflow': [{'Branch Name': 'Transformer.subxf',
#      'BranchFlow': 8.981978786928998},
#     {'Branch Name': 'Line.l1', 'BranchFlow': 24.95090953066422},
#     {'Branch Name': 'Line.l2a', 'BranchFlow': 24.9376787865085},
#     {'Branch Name': 'Line.l2b', 'BranchFlow': 24.440332495635058},
#     {'Branch Name': 'Line.l3', 'BranchFlow': 24.43559264782198},
#     {'Branch Name': 'Line.l4a', 'BranchFlow': 0.6514983059218912},
#     {'Branch Name': 'Line.l5', 'BranchFlow': 24.09769489661083},
#     {'Branch Name': 'Line.l4b', 'BranchFlow': 0.03481902140695258},
#     {'Branch Name': 'Line.l6', 'BranchFlow': 23.90188264268822},
#     {'Branch Name': 'Transformer.reg1c', 'BranchFlow': 22.36215093217133},
#     {'Branch Name': 'Line.l7', 'BranchFlow': 23.641228397156098},
#     {'Branch Name': 'Line.l24', 'BranchFlow': 23.641181229909932},
#     {'Branch Name': 'Line.l8', 'BranchFlow': 6.867105945746836},
#     {'Branch Name': 'Line.l9a', 'BranchFlow': 21.781743752550582},
#     {'Branch Name': 'Line.l10a', 'BranchFlow': 6.874619950469632},
#     {'Branch Name': 'Line.l9b', 'BranchFlow': 21.703568528108264},
#     {'Branch Name': 'Line.l12a', 'BranchFlow': 1.6835324999295531},
#     {'Branch Name': 'Line.l13a', 'BranchFlow': 21.282522710750154},
#     {'Branch Name': 'Line.l10b', 'BranchFlow': 5.5134891745974715},
#     {'Branch Name': 'Line.l11a', 'BranchFlow': 5.6310742639199605},
#     {'Branch Name': 'Line.l11b', 'BranchFlow': 0.08006457318808236},
#     {'Branch Name': 'Line.l12b', 'BranchFlow': 0.017790298949812378},
#     {'Branch Name': 'Line.l13b', 'BranchFlow': 21.244471893046185},
#     {'Branch Name': 'Line.l14a', 'BranchFlow': 21.24195755797102},
#     {'Branch Name': 'Line.l14b', 'BranchFlow': 21.11111436761418},
#     {'Branch Name': 'Line.l15', 'BranchFlow': 20.606106011521593},
#     {'Branch Name': 'Line.l26a', 'BranchFlow': 0.24757664664952925},
#     {'Branch Name': 'Line.l27', 'BranchFlow': 20.53180139863159},
#     {'Branch Name': 'Line.l16a', 'BranchFlow': 16.134852100844963},
#     {'Branch Name': 'Line.l25', 'BranchFlow': 19.534927981549433},
#     {'Branch Name': 'Transformer.xfm1', 'BranchFlow': 6.369530443346348},
#     {'Branch Name': 'Line.l16b', 'BranchFlow': 16.013748732568},
#     {'Branch Name': 'Line.l29a', 'BranchFlow': 15.972191632468219},
#     {'Branch Name': 'Line.l28a', 'BranchFlow': 0.07508430197962754},
#     {'Branch Name': 'Line.l29b', 'BranchFlow': 15.780797781520027},
#     {'Branch Name': 'Line.l18', 'BranchFlow': 14.787543027374092},
#     {'Branch Name': 'Line.l17a', 'BranchFlow': 5.5898432736104695},
#     {'Branch Name': 'Line.l21a', 'BranchFlow': 14.783404302443266},
#     {'Branch Name': 'Line.l19a', 'BranchFlow': 1.0111681161352666},
#     {'Branch Name': 'Line.l30b', 'BranchFlow': 1.3699497903124989},
#     {'Branch Name': 'Line.l20', 'BranchFlow': 0.37437750791575014},
#     {'Branch Name': 'Line.l19b', 'BranchFlow': 0.4288148215746786},
#     {'Branch Name': 'Line.l21b', 'BranchFlow': 14.782223434140997},
#     {'Branch Name': 'Line.l22a', 'BranchFlow': 10.095302809608835},
#     {'Branch Name': 'Line.l22b', 'BranchFlow': 10.25201506621622},
#     {'Branch Name': 'Line.l23a', 'BranchFlow': 10.22159534765465},
#     {'Branch Name': 'Line.l23b', 'BranchFlow': 10.318156923762869},
#     {'Branch Name': 'Line.l26b', 'BranchFlow': 0.13598624041955995},
#     {'Branch Name': 'Transformer.reg2c', 'BranchFlow': 21.23492181559478},
#     {'Branch Name': 'Line.l32', 'BranchFlow': 38.12528144796874},
#     {'Branch Name': 'Line.l28b', 'BranchFlow': 0.009686791966733534},
#     {'Branch Name': 'Line.l17b', 'BranchFlow': 3.3739854415372093},
#     {'Branch Name': 'Line.l30a', 'BranchFlow': 2.4622543648144397},
#     {'Branch Name': 'Line.l31a', 'BranchFlow': 1.1151316007377325},
#     {'Branch Name': 'Line.l31b', 'BranchFlow': 0.0301017384164672}]},
#   {'Time Step': 0.3333333333333333,
#    'Bus_Info': [{'Bus Name': 'sourcebus',
#      'Voltage Magnitude': array([1.04999995, 1.05000046, 1.05000045]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '800',
#      'Voltage Magnitude': array([1.04999976, 1.04999984, 1.05000041]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '802',
#      'Voltage Magnitude': array([1.04900059, 1.04944325, 1.04946983]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid806',
#      'Voltage Magnitude': array([1.04866545, 1.04925664, 1.04929182]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '806',
#      'Voltage Magnitude': array([1.04832626, 1.04909549, 1.04912872]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '808',
#      'Voltage Magnitude': array([1.03563905, 1.04308603, 1.04300137]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid810',
#      'Voltage Magnitude': array([1.04300667]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '810',
#      'Voltage Magnitude': array([1.04300766]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '812',
#      'Voltage Magnitude': array([1.02082664, 1.03663143, 1.0355918 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814',
#      'Voltage Magnitude': array([1.0089993 , 1.03149563, 1.02962107]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814r',
#      'Voltage Magnitude': array([1.02792073, 1.02505372, 1.02962706]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '850',
#      'Voltage Magnitude': array([1.02791485, 1.02505035, 1.02962355]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '816',
#      'Voltage Magnitude': array([1.02773276, 1.02494596, 1.02951454]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '818',
#      'Voltage Magnitude': array([1.027245]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid824',
#      'Voltage Magnitude': array([1.02580196, 1.02291737, 1.02779585]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '824',
#      'Voltage Magnitude': array([1.02386887, 1.02090204, 1.02609082]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid820',
#      'Voltage Magnitude': array([1.02030641]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '820',
#      'Voltage Magnitude': array([1.01471571]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid822',
#      'Voltage Magnitude': array([1.0130961]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '822',
#      'Voltage Magnitude': array([1.01310148]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid826',
#      'Voltage Magnitude': array([1.02079538]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '826',
#      'Voltage Magnitude': array([1.02079565]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid828',
#      'Voltage Magnitude': array([1.0237113 , 1.02075811, 1.02594551]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '828',
#      'Voltage Magnitude': array([1.02355318, 1.02061428, 1.02580235]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid830',
#      'Voltage Magnitude': array([1.01970002, 1.01711603, 1.02231802]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '830',
#      'Voltage Magnitude': array([1.01592524, 1.01359542, 1.01883807]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '854',
#      'Voltage Magnitude': array([1.01574286, 1.0134214 , 1.01867027]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '832',
#      'Voltage Magnitude': array([1.04044356, 1.04491267, 1.04449236]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid858',
#      'Voltage Magnitude': array([1.04001099, 1.04449888, 1.0441215 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '858',
#      'Voltage Magnitude': array([1.03959489, 1.04409646, 1.04376144]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid834',
#      'Voltage Magnitude': array([1.03910525, 1.04361564, 1.04333344]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '834',
#      'Voltage Magnitude': array([1.03864069, 1.04316194, 1.04294779]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '842',
#      'Voltage Magnitude': array([1.03863858, 1.04315207, 1.04294884]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '836',
#      'Voltage Magnitude': array([1.03829236, 1.04273534, 1.04266942]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid840',
#      'Voltage Magnitude': array([1.03828346, 1.0427221 , 1.04265958]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '840',
#      'Voltage Magnitude': array([1.03827887, 1.04271778, 1.04265493]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid844',
#      'Voltage Magnitude': array([1.03863346, 1.04312828, 1.04295135]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '844',
#      'Voltage Magnitude': array([1.03863625, 1.0431023 , 1.04295415]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid846',
#      'Voltage Magnitude': array([1.03880819, 1.0431729 , 1.0431185 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '846',
#      'Voltage Magnitude': array([1.03897222, 1.04330153, 1.04331653]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid848',
#      'Voltage Magnitude': array([1.03899606, 1.04332023, 1.04334533]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '848',
#      'Voltage Magnitude': array([1.03902043, 1.04334653, 1.04337236]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid856',
#      'Voltage Magnitude': array([1.01338632]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '856',
#      'Voltage Magnitude': array([1.01340184]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '852',
#      'Voltage Magnitude': array([1.00283607, 1.00111188, 1.00673676]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '852r',
#      'Voltage Magnitude': array([1.04044695, 1.04491587, 1.04449549]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '888',
#      'Voltage Magnitude': array([1.0208485 , 1.02532805, 1.02493642]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid864',
#      'Voltage Magnitude': array([1.03959236]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '864',
#      'Voltage Magnitude': array([1.03959243]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid860',
#      'Voltage Magnitude': array([1.03848706, 1.04304026, 1.04281021]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '860',
#      'Voltage Magnitude': array([1.03840353, 1.0429342 , 1.04274484]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid836',
#      'Voltage Magnitude': array([1.03832345, 1.04282226, 1.04268904]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '862',
#      'Voltage Magnitude': array([1.0382916 , 1.04272577, 1.04267168]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid838',
#      'Voltage Magnitude': array([1.04264184]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '838',
#      'Voltage Magnitude': array([1.04264253]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '890',
#      'Voltage Magnitude': array([0.97568308, 0.98451847, 0.97990421]),
#      'Power Generated': array([ 0., -0.,  0.])}],
#    'Branchflow': [{'Branch Name': 'Transformer.subxf',
#      'BranchFlow': 8.981978793905819},
#     {'Branch Name': 'Line.l1', 'BranchFlow': 24.95090954875886},
#     {'Branch Name': 'Line.l2a', 'BranchFlow': 24.937678804646968},
#     {'Branch Name': 'Line.l2b', 'BranchFlow': 24.440332513271994},
#     {'Branch Name': 'Line.l3', 'BranchFlow': 24.43559266547368},
#     {'Branch Name': 'Line.l4a', 'BranchFlow': 0.651498306004648},
#     {'Branch Name': 'Line.l5', 'BranchFlow': 24.09769491463498},
#     {'Branch Name': 'Line.l4b', 'BranchFlow': 0.034819021407883566},
#     {'Branch Name': 'Line.l6', 'BranchFlow': 23.90188266132363},
#     {'Branch Name': 'Transformer.reg1c', 'BranchFlow': 22.362150944827807},
#     {'Branch Name': 'Line.l7', 'BranchFlow': 23.641228415902415},
#     {'Branch Name': 'Line.l24', 'BranchFlow': 23.641181248876276},
#     {'Branch Name': 'Line.l8', 'BranchFlow': 6.8671059589542285},
#     {'Branch Name': 'Line.l9a', 'BranchFlow': 21.781743766769495},
#     {'Branch Name': 'Line.l10a', 'BranchFlow': 6.874619963680483},
#     {'Branch Name': 'Line.l9b', 'BranchFlow': 21.703568542346634},
#     {'Branch Name': 'Line.l12a', 'BranchFlow': 1.6835325005990516},
#     {'Branch Name': 'Line.l13a', 'BranchFlow': 21.28252272450629},
#     {'Branch Name': 'Line.l10b', 'BranchFlow': 5.513489187978817},
#     {'Branch Name': 'Line.l11a', 'BranchFlow': 5.631074277319576},
#     {'Branch Name': 'Line.l11b', 'BranchFlow': 0.08006457317857268},
#     {'Branch Name': 'Line.l12b', 'BranchFlow': 0.017790298948837106},
#     {'Branch Name': 'Line.l13b', 'BranchFlow': 21.244471906734272},
#     {'Branch Name': 'Line.l14a', 'BranchFlow': 21.24195757167611},
#     {'Branch Name': 'Line.l14b', 'BranchFlow': 21.111114381269847},
#     {'Branch Name': 'Line.l15', 'BranchFlow': 20.606106024904236},
#     {'Branch Name': 'Line.l26a', 'BranchFlow': 0.24757664667119128},
#     {'Branch Name': 'Line.l27', 'BranchFlow': 20.53180141202971},
#     {'Branch Name': 'Line.l16a', 'BranchFlow': 16.13485210274708},
#     {'Branch Name': 'Line.l25', 'BranchFlow': 19.53492799519391},
#     {'Branch Name': 'Transformer.xfm1', 'BranchFlow': 6.369530456849641},
#     {'Branch Name': 'Line.l16b', 'BranchFlow': 16.013748734366583},
#     {'Branch Name': 'Line.l29a', 'BranchFlow': 15.972191634249628},
#     {'Branch Name': 'Line.l28a', 'BranchFlow': 0.0750843021976867},
#     {'Branch Name': 'Line.l29b', 'BranchFlow': 15.780797782773817},
#     {'Branch Name': 'Line.l18', 'BranchFlow': 14.787543025619586},
#     {'Branch Name': 'Line.l17a', 'BranchFlow': 5.589843279117436},
#     {'Branch Name': 'Line.l21a', 'BranchFlow': 14.783404300663916},
#     {'Branch Name': 'Line.l19a', 'BranchFlow': 1.0111681170518763},
#     {'Branch Name': 'Line.l30b', 'BranchFlow': 1.369949791878596},
#     {'Branch Name': 'Line.l20', 'BranchFlow': 0.3743775085449153},
#     {'Branch Name': 'Line.l19b', 'BranchFlow': 0.4288148219889134},
#     {'Branch Name': 'Line.l21b', 'BranchFlow': 14.782223432361066},
#     {'Branch Name': 'Line.l22a', 'BranchFlow': 10.095302807215942},
#     {'Branch Name': 'Line.l22b', 'BranchFlow': 10.25201506393312},
#     {'Branch Name': 'Line.l23a', 'BranchFlow': 10.22159534538527},
#     {'Branch Name': 'Line.l23b', 'BranchFlow': 10.318156921595973},
#     {'Branch Name': 'Line.l26b', 'BranchFlow': 0.13598624041147525},
#     {'Branch Name': 'Transformer.reg2c', 'BranchFlow': 21.234921828544262},
#     {'Branch Name': 'Line.l32', 'BranchFlow': 38.125281528793835},
#     {'Branch Name': 'Line.l28b', 'BranchFlow': 0.009686791966949434},
#     {'Branch Name': 'Line.l17b', 'BranchFlow': 3.373985447299287},
#     {'Branch Name': 'Line.l30a', 'BranchFlow': 2.4622543687259415},
#     {'Branch Name': 'Line.l31a', 'BranchFlow': 1.1151316026266043},
#     {'Branch Name': 'Line.l31b', 'BranchFlow': 0.030101738412926498}]},
#   {'Time Step': 0.4166666666666667,
#    'Bus_Info': [{'Bus Name': 'sourcebus',
#      'Voltage Magnitude': array([1.04999995, 1.05000046, 1.05000045]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '800',
#      'Voltage Magnitude': array([1.04999976, 1.04999984, 1.05000041]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '802',
#      'Voltage Magnitude': array([1.04900059, 1.04944325, 1.04946983]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid806',
#      'Voltage Magnitude': array([1.04866545, 1.04925664, 1.04929182]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '806',
#      'Voltage Magnitude': array([1.04832626, 1.04909549, 1.04912872]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '808',
#      'Voltage Magnitude': array([1.03563905, 1.04308603, 1.04300137]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid810',
#      'Voltage Magnitude': array([1.04300667]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '810',
#      'Voltage Magnitude': array([1.04300766]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '812',
#      'Voltage Magnitude': array([1.02082664, 1.03663143, 1.0355918 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814',
#      'Voltage Magnitude': array([1.0089993 , 1.03149563, 1.02962107]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814r',
#      'Voltage Magnitude': array([1.02792073, 1.02505372, 1.02962706]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '850',
#      'Voltage Magnitude': array([1.02791485, 1.02505035, 1.02962355]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '816',
#      'Voltage Magnitude': array([1.02773276, 1.02494596, 1.02951454]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '818',
#      'Voltage Magnitude': array([1.027245]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid824',
#      'Voltage Magnitude': array([1.02580196, 1.02291737, 1.02779585]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '824',
#      'Voltage Magnitude': array([1.02386887, 1.02090204, 1.02609082]),
# ...
#     {'Bus Name': '860',
#      'Voltage Magnitude': array([1.03840353, 1.0429342 , 1.04274484]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid836',
#      'Voltage Magnitude': array([1.03832345, 1.04282226, 1.04268904]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '862',
#      'Voltage Magnitude': array([1.0382916 , 1.04272577, 1.04267168]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid838',
#      'Voltage Magnitude': array([1.04264184]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '838',
#      'Voltage Magnitude': array([1.04264253]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '890',
#      'Voltage Magnitude': array([0.97568308, 0.98451847, 0.97990421]),
#      'Power Generated': array([ 0., -0.,  0.])}],
#    'Branchflow': [{'Branch Name': 'Transformer.subxf',
#      'BranchFlow': 8.981978793150516},
#     {'Branch Name': 'Line.l1', 'BranchFlow': 24.950909548882148},
#     {'Branch Name': 'Line.l2a', 'BranchFlow': 24.93767880477409},
#     {'Branch Name': 'Line.l2b', 'BranchFlow': 24.440332513395948},
#     {'Branch Name': 'Line.l3', 'BranchFlow': 24.435592665594616},
#     {'Branch Name': 'Line.l4a', 'BranchFlow': 0.6514983060060787},
#     {'Branch Name': 'Line.l5', 'BranchFlow': 24.097694914764105},
#     {'Branch Name': 'Line.l4b', 'BranchFlow': 0.03481902140741808},
#     {'Branch Name': 'Line.l6', 'BranchFlow': 23.901882661466544},
#     {'Branch Name': 'Transformer.reg1c', 'BranchFlow': 22.362150945120167},
#     {'Branch Name': 'Line.l7', 'BranchFlow': 23.641228416034323},
#     {'Branch Name': 'Line.l24', 'BranchFlow': 23.64118124902264},
#     {'Branch Name': 'Line.l8', 'BranchFlow': 6.867105959094022},
#     {'Branch Name': 'Line.l9a', 'BranchFlow': 21.781743766833262},
#     {'Branch Name': 'Line.l10a', 'BranchFlow': 6.874619963816807},
#     {'Branch Name': 'Line.l9b', 'BranchFlow': 21.703568542410896},
#     {'Branch Name': 'Line.l12a', 'BranchFlow': 1.683532500606665},
#     {'Branch Name': 'Line.l13a', 'BranchFlow': 21.2825227245704},
#     {'Branch Name': 'Line.l10b', 'BranchFlow': 5.513489188118797},
#     {'Branch Name': 'Line.l11a', 'BranchFlow': 5.631074277459532},
#     {'Branch Name': 'Line.l11b', 'BranchFlow': 0.08006457317811826},
#     {'Branch Name': 'Line.l12b', 'BranchFlow': 0.01779029894932474},
#     {'Branch Name': 'Line.l13b', 'BranchFlow': 21.244471906807927},
#     {'Branch Name': 'Line.l14a', 'BranchFlow': 21.24195757173213},
#     {'Branch Name': 'Line.l14b', 'BranchFlow': 21.111114381326214},
#     {'Branch Name': 'Line.l15', 'BranchFlow': 20.60610602494834},
#     {'Branch Name': 'Line.l26a', 'BranchFlow': 0.24757664667153803},
#     {'Branch Name': 'Line.l27', 'BranchFlow': 20.531801412078426},
#     {'Branch Name': 'Line.l16a', 'BranchFlow': 16.134852102767933},
#     {'Branch Name': 'Line.l25', 'BranchFlow': 19.534927995346507},
#     {'Branch Name': 'Transformer.xfm1', 'BranchFlow': 6.369530456989174},
#     {'Branch Name': 'Line.l16b', 'BranchFlow': 16.013748734388173},
#     {'Branch Name': 'Line.l29a', 'BranchFlow': 15.972191634266855},
#     {'Branch Name': 'Line.l28a', 'BranchFlow': 0.07508430220117264},
#     {'Branch Name': 'Line.l29b', 'BranchFlow': 15.780797782786218},
#     {'Branch Name': 'Line.l18', 'BranchFlow': 14.787543025574257},
#     {'Branch Name': 'Line.l17a', 'BranchFlow': 5.5898432791629515},
#     {'Branch Name': 'Line.l21a', 'BranchFlow': 14.783404300628918},
#     {'Branch Name': 'Line.l19a', 'BranchFlow': 1.0111681170693403},
#     {'Branch Name': 'Line.l30b', 'BranchFlow': 1.36994979189405},
#     {'Branch Name': 'Line.l20', 'BranchFlow': 0.37437750855835233},
#     {'Branch Name': 'Line.l19b', 'BranchFlow': 0.42881482198928983},
#     {'Branch Name': 'Line.l21b', 'BranchFlow': 14.782223432332927},
#     {'Branch Name': 'Line.l22a', 'BranchFlow': 10.095302807181959},
#     {'Branch Name': 'Line.l22b', 'BranchFlow': 10.252015063901718},
#     {'Branch Name': 'Line.l23a', 'BranchFlow': 10.221595345355952},
#     {'Branch Name': 'Line.l23b', 'BranchFlow': 10.318156921545748},
#     {'Branch Name': 'Line.l26b', 'BranchFlow': 0.1359862404108409},
#     {'Branch Name': 'Transformer.reg2c', 'BranchFlow': 21.234921828797667},
#     {'Branch Name': 'Line.l32', 'BranchFlow': 38.125281529628936},
#     {'Branch Name': 'Line.l28b', 'BranchFlow': 0.009686791967165334},
#     {'Branch Name': 'Line.l17b', 'BranchFlow': 3.3739854473435913},
#     {'Branch Name': 'Line.l30a', 'BranchFlow': 2.462254368755463},
#     {'Branch Name': 'Line.l31a', 'BranchFlow': 1.1151316026448175},
#     {'Branch Name': 'Line.l31b', 'BranchFlow': 0.030101738411925618}]},
#   {'Time Step': 24.0,
#    'Bus_Info': [{'Bus Name': 'sourcebus',
#      'Voltage Magnitude': array([1.04999995, 1.05000046, 1.05000045]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '800',
#      'Voltage Magnitude': array([1.04999976, 1.04999984, 1.05000041]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '802',
#      'Voltage Magnitude': array([1.04900059, 1.04944325, 1.04946983]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid806',
#      'Voltage Magnitude': array([1.04866545, 1.04925664, 1.04929182]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '806',
#      'Voltage Magnitude': array([1.04832626, 1.04909549, 1.04912872]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '808',
#      'Voltage Magnitude': array([1.03563905, 1.04308603, 1.04300137]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid810',
#      'Voltage Magnitude': array([1.04300667]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '810',
#      'Voltage Magnitude': array([1.04300766]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '812',
#      'Voltage Magnitude': array([1.02082664, 1.03663143, 1.0355918 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814',
#      'Voltage Magnitude': array([1.0089993 , 1.03149563, 1.02962107]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '814r',
#      'Voltage Magnitude': array([1.02792073, 1.02505372, 1.02962706]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '850',
#      'Voltage Magnitude': array([1.02791485, 1.02505035, 1.02962355]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '816',
#      'Voltage Magnitude': array([1.02773276, 1.02494596, 1.02951454]),
#      'Power Generated': array([ 0., -0.,  0.])},
#     {'Bus Name': '818',
#      'Voltage Magnitude': array([1.027245]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid824',
#      'Voltage Magnitude': array([1.02580196, 1.02291737, 1.02779585]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '824',
#      'Voltage Magnitude': array([1.02386887, 1.02090204, 1.02609082]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid820',
#      'Voltage Magnitude': array([1.02030641]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '820',
#      'Voltage Magnitude': array([1.01471571]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid822',
#      'Voltage Magnitude': array([1.0130961]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '822',
#      'Voltage Magnitude': array([1.01310148]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid826',
#      'Voltage Magnitude': array([1.02079538]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '826',
#      'Voltage Magnitude': array([1.02079565]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid828',
#      'Voltage Magnitude': array([1.0237113 , 1.02075811, 1.02594551]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '828',
#      'Voltage Magnitude': array([1.02355318, 1.02061428, 1.02580235]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid830',
#      'Voltage Magnitude': array([1.01970002, 1.01711603, 1.02231802]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '830',
#      'Voltage Magnitude': array([1.01592524, 1.01359542, 1.01883807]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '854',
#      'Voltage Magnitude': array([1.01574286, 1.0134214 , 1.01867027]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '832',
#      'Voltage Magnitude': array([1.04044356, 1.04491267, 1.04449236]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid858',
#      'Voltage Magnitude': array([1.04001099, 1.04449888, 1.0441215 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '858',
#      'Voltage Magnitude': array([1.03959489, 1.04409646, 1.04376144]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid834',
#      'Voltage Magnitude': array([1.03910525, 1.04361564, 1.04333344]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '834',
#      'Voltage Magnitude': array([1.03864069, 1.04316194, 1.04294779]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '842',
#      'Voltage Magnitude': array([1.03863858, 1.04315207, 1.04294884]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '836',
#      'Voltage Magnitude': array([1.03829236, 1.04273534, 1.04266942]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid840',
#      'Voltage Magnitude': array([1.03828346, 1.0427221 , 1.04265958]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '840',
#      'Voltage Magnitude': array([1.03827887, 1.04271778, 1.04265493]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid844',
#      'Voltage Magnitude': array([1.03863346, 1.04312828, 1.04295135]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '844',
#      'Voltage Magnitude': array([1.03863625, 1.0431023 , 1.04295415]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid846',
#      'Voltage Magnitude': array([1.03880819, 1.0431729 , 1.0431185 ]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '846',
#      'Voltage Magnitude': array([1.03897222, 1.04330153, 1.04331653]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid848',
#      'Voltage Magnitude': array([1.03899606, 1.04332023, 1.04334533]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '848',
#      'Voltage Magnitude': array([1.03902043, 1.04334653, 1.04337236]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid856',
#      'Voltage Magnitude': array([1.01338632]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '856',
#      'Voltage Magnitude': array([1.01340184]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '852',
#      'Voltage Magnitude': array([1.00283607, 1.00111188, 1.00673676]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '852r',
#      'Voltage Magnitude': array([1.04044695, 1.04491587, 1.04449549]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '888',
#      'Voltage Magnitude': array([1.0208485 , 1.02532805, 1.02493642]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid864',
#      'Voltage Magnitude': array([1.03959236]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '864',
#      'Voltage Magnitude': array([1.03959243]),
#      'Power Generated': array([nan])},
#     {'Bus Name': 'mid860',
#      'Voltage Magnitude': array([1.03848706, 1.04304026, 1.04281021]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '860',
#      'Voltage Magnitude': array([1.03840353, 1.0429342 , 1.04274484]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid836',
#      'Voltage Magnitude': array([1.03832345, 1.04282226, 1.04268904]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': '862',
#      'Voltage Magnitude': array([1.0382916 , 1.04272577, 1.04267168]),
#      'Power Generated': array([nan, nan, nan])},
#     {'Bus Name': 'mid838',
#      'Voltage Magnitude': array([1.04264184]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '838',
#      'Voltage Magnitude': array([1.04264253]),
#      'Power Generated': array([nan])},
#     {'Bus Name': '890',
#      'Voltage Magnitude': array([0.97568308, 0.98451847, 0.97990421]),
#      'Power Generated': array([ 0., -0.,  0.])}],
#    'Branchflow': [{'Branch Name': 'Transformer.subxf',
#      'BranchFlow': 8.981978793150516},
#     {'Branch Name': 'Line.l1', 'BranchFlow': 24.950909548882148},
#     {'Branch Name': 'Line.l2a', 'BranchFlow': 24.93767880477409},
#     {'Branch Name': 'Line.l2b', 'BranchFlow': 24.440332513395948},
#     {'Branch Name': 'Line.l3', 'BranchFlow': 24.435592665594754},
#     {'Branch Name': 'Line.l4a', 'BranchFlow': 0.6514983060049554},
#     {'Branch Name': 'Line.l5', 'BranchFlow': 24.097694914764386},
#     {'Branch Name': 'Line.l4b', 'BranchFlow': 0.03481902140695258},
#     {'Branch Name': 'Line.l6', 'BranchFlow': 23.90188266146683},
#     {'Branch Name': 'Transformer.reg1c', 'BranchFlow': 22.362150945120167},
#     {'Branch Name': 'Line.l7', 'BranchFlow': 23.641228415968087},
#     {'Branch Name': 'Line.l24', 'BranchFlow': 23.641181249028985},
#     {'Branch Name': 'Line.l8', 'BranchFlow': 6.867105959089029},
#     {'Branch Name': 'Line.l9a', 'BranchFlow': 21.781743766833177},
#     {'Branch Name': 'Line.l10a', 'BranchFlow': 6.874619963816934},
#     {'Branch Name': 'Line.l9b', 'BranchFlow': 21.703568542411887},
#     {'Branch Name': 'Line.l12a', 'BranchFlow': 1.6835325006092638},
#     {'Branch Name': 'Line.l13a', 'BranchFlow': 21.282522724565567},
#     {'Branch Name': 'Line.l10b', 'BranchFlow': 5.5134891881187436},
#     {'Branch Name': 'Line.l11a', 'BranchFlow': 5.631074277459745},
#     {'Branch Name': 'Line.l11b', 'BranchFlow': 0.08006457317876638},
#     {'Branch Name': 'Line.l12b', 'BranchFlow': 0.01779029895037254},
#     {'Branch Name': 'Line.l13b', 'BranchFlow': 21.244471906800953},
#     {'Branch Name': 'Line.l14a', 'BranchFlow': 21.24195757173238},
#     {'Branch Name': 'Line.l14b', 'BranchFlow': 21.111114381326164},
#     {'Branch Name': 'Line.l15', 'BranchFlow': 20.606106024945024},
#     {'Branch Name': 'Line.l26a', 'BranchFlow': 0.24757664667121712},
#     {'Branch Name': 'Line.l27', 'BranchFlow': 20.53180141207861},
#     {'Branch Name': 'Line.l16a', 'BranchFlow': 16.134852102767432},
#     {'Branch Name': 'Line.l25', 'BranchFlow': 19.53492799482704},
#     {'Branch Name': 'Transformer.xfm1', 'BranchFlow': 6.369530456989242},
#     {'Branch Name': 'Line.l16b', 'BranchFlow': 16.013748734388546},
#     {'Branch Name': 'Line.l29a', 'BranchFlow': 15.972191634268386},
#     {'Branch Name': 'Line.l28a', 'BranchFlow': 0.07508430220013185},
#     {'Branch Name': 'Line.l29b', 'BranchFlow': 15.78079778278475},
#     {'Branch Name': 'Line.l18', 'BranchFlow': 14.787543025579494},
#     {'Branch Name': 'Line.l17a', 'BranchFlow': 5.589843279161676},
#     {'Branch Name': 'Line.l21a', 'BranchFlow': 14.783404300636183},
#     {'Branch Name': 'Line.l19a', 'BranchFlow': 1.0111681170675337},
#     {'Branch Name': 'Line.l30b', 'BranchFlow': 1.3699497918981456},
#     {'Branch Name': 'Line.l20', 'BranchFlow': 0.3743775085611806},
#     {'Branch Name': 'Line.l19b', 'BranchFlow': 0.428814821987569},
#     {'Branch Name': 'Line.l21b', 'BranchFlow': 14.782223432328374},
#     {'Branch Name': 'Line.l22a', 'BranchFlow': 10.095302807182785},
#     {'Branch Name': 'Line.l22b', 'BranchFlow': 10.25201506390257},
#     {'Branch Name': 'Line.l23a', 'BranchFlow': 10.221595345348646},
#     {'Branch Name': 'Line.l23b', 'BranchFlow': 10.318156921546041},
#     {'Branch Name': 'Line.l26b', 'BranchFlow': 0.13598624041058827},
#     {'Branch Name': 'Transformer.reg2c', 'BranchFlow': 21.234921828723156},
#     {'Branch Name': 'Line.l32', 'BranchFlow': 38.12528152962928},
#     {'Branch Name': 'Line.l28b', 'BranchFlow': 0.009686791961717983},
#     {'Branch Name': 'Line.l17b', 'BranchFlow': 3.373985447343207},
#     {'Branch Name': 'Line.l30a', 'BranchFlow': 2.46225436876047},
#     {'Branch Name': 'Line.l31a', 'BranchFlow': 1.1151316026498355},
#     {'Branch Name': 'Line.l31b', 'BranchFlow': 0.03010173841040173}]}]}

# %%
#Restructuring Dataset into multi-dimensional array
Dataset = []
Ttot = 288
dim_x = Ttot
dim_Vy = len(buses)
dim_Cy = len(edges)
for d in range (len(Prelim_Dataset)):
    Varray_3d = np.zeros((dim_x,dim_Vy,3))
    Varray_2d = np.zeros((dim_Vy,3))
    Carray_3d = np.zeros((dim_x,dim_Cy,1))
    Carray_2d = np.zeros((dim_Cy,1))
    Parray_3d = np.zeros((dim_x,dim_Vy,3))
    Parray_2d = np.zeros((dim_Vy,3))
    for t in range(Ttot):
        for v in range(len(buses)):
            Varray_2d[v,:] = Prelim_Dataset[d]['TimeSeries_Data'][t]['Bus_Info'][v]['Voltage Magnitude']
            Parray_2d[v,:] = -Prelim_Dataset[d]['TimeSeries_Data'][t]['Bus_Info'][v]['Power Generated']
        Varray_3d[t,:,:]=Varray_2d
        Parray_3d[t,:,:]=Parray_2d
        for c in range(len(edges)):
            Carray_2d[c,:] = Prelim_Dataset[d]['TimeSeries_Data'][t]['Branchflow'][c]['BranchFlow']
        Carray_3d[t,:,:]=Carray_2d       
    Scenario_Data = {'Anomalous':Prelim_Dataset[d]['Anomalous'],'Attack_Type':'Nil','Targeted_PV':Prelim_Dataset[d]['Affected_PV'],'TimeSeries_PowerGen':Parray_3d, 'TimeSeries_Voltage':Varray_3d, 'BranchFlow':Carray_3d}
    Dataset.append(Scenario_Data)

# %%
#Loading .pkl file
a = open('PVanomalydataset_norm(mult).pkl', 'wb')
pickle.dump(Dataset,a)
a.close()

# %%
Dataset[0]
# Out:
# {'Scenario_Number': 0,
#  'Anomalous': 'No',
#  'Targeted_PV': 'Nil',
#  'TimeSeries_PowerGen': array([[[nan, nan, nan],
#          [nan, nan, nan],
#          [nan, nan, nan],
#          ...,
#          [nan, nan, nan],
#          [nan, nan, nan],
#          [-0.,  0., -0.]],
#
#         [[nan, nan, nan],
#          [nan, nan, nan],
#          [nan, nan, nan],
#          ...,
#          [nan, nan, nan],
#          [nan, nan, nan],
#          [-0.,  0., -0.]],
#
#         [[nan, nan, nan],
#          [nan, nan, nan],
#          [nan, nan, nan],
#          ...,
#          [nan, nan, nan],
#          [nan, nan, nan],
#          [-0.,  0., -0.]],
#
#         ...,
#
#         [[nan, nan, nan],
#          [nan, nan, nan],
#          [nan, nan, nan],
#          ...,
#          [nan, nan, nan],
#          [nan, nan, nan],
#          [-0.,  0., -0.]],
#
#         [[nan, nan, nan],
#          [nan, nan, nan],
#          [nan, nan, nan],
#          ...,
#          [nan, nan, nan],
#          [nan, nan, nan],
#          [-0.,  0., -0.]],
#
#         [[nan, nan, nan],
#          [nan, nan, nan],
#          [nan, nan, nan],
#          ...,
#          [nan, nan, nan],
#          [nan, nan, nan],
#          [-0.,  0., -0.]]]),
#  'TimeSeries_Voltage': array([[[1.04999995, 1.05000058, 1.05000063],
#          [1.04999979, 1.04999983, 1.05000059],
#          [1.04888513, 1.04941112, 1.04939213],
#          ...,
#          [1.11274185, 1.11274185, 1.11274185],
#          [1.11274258, 1.11274258, 1.11274258],
#          [1.07312915, 1.05421866, 1.04686682]],
#
#         [[1.04999995, 1.05000058, 1.05000063],
#          [1.04999979, 1.04999983, 1.05000059],
#          [1.04888513, 1.04941112, 1.04939213],
#          ...,
#          [1.11274187, 1.11274187, 1.11274187],
#          [1.1127426 , 1.1127426 , 1.1127426 ],
#          [1.07312916, 1.05421868, 1.04686685]],
#
#         [[1.04999995, 1.05000058, 1.05000063],
#          [1.04999979, 1.04999983, 1.05000059],
#          [1.04888513, 1.04941112, 1.04939213],
#          ...,
#          [1.11274187, 1.11274187, 1.11274187],
#          [1.1127426 , 1.1127426 , 1.1127426 ],
#          [1.07312916, 1.05421868, 1.04686685]],
#
#         ...,
#
#         [[1.04999995, 1.05000058, 1.05000063],
#          [1.04999979, 1.04999983, 1.05000059],
#          [1.04888513, 1.04941112, 1.04939213],
#          ...,
#          [1.11274187, 1.11274187, 1.11274187],
#          [1.1127426 , 1.1127426 , 1.1127426 ],
#          [1.07312916, 1.05421868, 1.04686685]],
#
#         [[1.04999995, 1.05000058, 1.05000063],
#          [1.04999979, 1.04999983, 1.05000059],
#          [1.04888513, 1.04941112, 1.04939213],
#          ...,
#          [1.11274187, 1.11274187, 1.11274187],
#          [1.1127426 , 1.1127426 , 1.1127426 ],
#          [1.07312916, 1.05421868, 1.04686685]],
#
#         [[1.04999995, 1.05000058, 1.05000063],
#          [1.04999979, 1.04999983, 1.05000059],
#          [1.04888513, 1.04941112, 1.04939213],
#          ...,
#          [1.11274187, 1.11274187, 1.11274187],
#          [1.1127426 , 1.1127426 , 1.1127426 ],
#          [1.07312916, 1.05421868, 1.04686685]]]),
#  'BranchFlow': array([[[10.10808764],
#          [28.0595565 ],
#          [28.0458296 ],
#          ...,
#          [ 2.61098141],
#          [ 1.17312585],
#          [ 0.03212557]],
#
#         [[10.10808705],
#          [28.05955489],
#          [28.04582799],
#          ...,
#          [ 2.61098117],
#          [ 1.17312563],
#          [ 0.03212557]],
#
#         [[10.10808705],
#          [28.05955489],
#          [28.04582799],
#          ...,
#          [ 2.61098117],
#          [ 1.17312563],
#          [ 0.03212557]],
#
#         ...,
#
#         [[10.10808705],
#          [28.05955489],
#          [28.04582799],
#          ...,
#          [ 2.61098117],
#          [ 1.17312563],
#          [ 0.03212557]],
#
#         [[10.10808705],
#          [28.05955489],
#          [28.04582799],
#          ...,
#          [ 2.61098117],
#          [ 1.17312563],
#          [ 0.03212557]],
#
#         [[10.10808705],
#          [28.05955489],
#          [28.04582799],
#          ...,
#          [ 2.61098117],
#          [ 1.17312563],
#          [ 0.03212557]]])}

# %%
#Plotting NSRDB Irradiance Profiles
Time = list(range(0,288))
I = []
# P2 = []
# P3 = []
for t in range(len(Time)):
    irr = Irradiance[48][t]
    I.append(irr)

#Creating graph plot of power profile at PV
plt.plot(Time, I, "-b")

# Add title and axis labels
plt.title("Irradiance Profile")
plt.xlabel("Time (in mins)")
plt.ylabel("Irradiance")
# plt.legend()

#Displaying the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 6>()
#       4 # P2 = []
#       5 # P3 = []
#       6 for t in range(len(Time)):
# ----> 7     irr = Irradiance[48][t]
#       8     I.append(irr)
#      10 #Creating graph plot of power profile at PV
#
# NameError: name 'Irradiance' is not defined

# %%
#Plotting PG at a bus before FDIA
Time = list(range(0,1440,5))
P1 = []
# P2 = []
# P3 = []
for t in range(len(Time)):
    p1 = -Prelim_Dataset[0]['TimeSeries_Data'][t]['Bus_Info'][4]['Power Generated']
    P1.append(p1)

#Creating graph plot of power profile at PV
plt.plot(Time, P1, "-b")
# plt.plot(Time, P2, "-r", label="Phase 2")
# plt.plot(Time, P3, "-k", label="Phase 3")

# Add title and axis labels
plt.title("Power Generated at PV before FDIA")
plt.xlabel("Time (in hrs)")
plt.ylabel("Power (in kW)")
# plt.legend()

#Displaying the plot
plt.show()

# %%
#Plotting Voltage at a bus before FDIA
Time = list(range(0,1440,5))
P1 = []
# P2 = []
# P3 = []
for t in range(len(Time)):
    p = Prelim_Dataset[0]['TimeSeries_Data'][t]['Bus_Info'][4]['Voltage Magnitude']
    P1.append(p)

#Creating graph plot of power profile at PV
plt.plot(Time, P1, "-b", label="Phase 1")
# plt.plot(Time, P2, "-r", label="Phase 2")
# plt.plot(Time, P3, "-k", label="Phase 3")

# Add title and axis labels
plt.title("Voltage magnitude at PV bus before FDIA")
plt.xlabel("Time (in mins)")
plt.ylabel("Voltage (in pu)")
plt.legend()

#Displaying the plot
plt.show()

# %%
#Plotting Old Irradiance Profile
Time = list(range(0,86400))

#Creating graph plot of power profile at PV
plt.plot(Time, IrrLoadShape, "-b")

# Add title and axis labels
plt.title("Irradiance Profile")
plt.xlabel("Time (in secs)")
plt.ylabel("Irradiance")
# plt.legend()

#Displaying the plot
plt.show()

# %%
f = open('PVanomalydataset_norm(mult).pkl','rb')
normal=pickle.load(f)
f.close()

# %%
c = open('PVanomalydatasetPF(mult).pkl','rb')
PF=pickle.load(c)
c.close()

# %%
y = open('PVanomalydatasetDOS(mult).pkl','rb')
DOS =pickle.load(y)
y.close()

# %%
v = open('PVanomalydatasetPCA(mult).pkl','rb')
PCA=pickle.load(v)
v.close()

# %%
c = open('MultiplePV_MultipleAttack.pkl','rb')
PF_M=pickle.load(c)
c.close()

# %%
FinalData = normal + DOS + PCA + PF

# %%
shuffle(FinalData)

# %%
x = open('MultiplePV_MultipleAttack.pkl', 'wb')
pickle.dump(FinalData,x)
x.close()

# %%
count = 0
for i in range(len(FinalData)):
    if FinalData[i]['Targeted_PV'] == 'PV 1':
        count = count + 1
    
print(count)
# Out:
# 84

# %%
PV1 = 84
PV2 = 80
PV3 = 61

# %%
len(FinalData)
# Out:
# 500

# %%
for i in range(len(buses)):
    if buses[i]=='816':
        break
        
print(i)
# Out:
# 12
